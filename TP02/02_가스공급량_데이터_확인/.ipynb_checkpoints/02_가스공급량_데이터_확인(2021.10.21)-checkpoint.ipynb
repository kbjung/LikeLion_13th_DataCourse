# %%
import pandas as pd
import numpy as np

# %%
total = pd.read_csv('../data/한국가스공사_시간별 공급량_20181231.csv', encoding='cp949')
total.head()
# Out:
#           연월일  시간 구분       공급량
# 0  2013-01-01   1  A  2497.129
# 1  2013-01-01   2  A  2363.265
# 2  2013-01-01   3  A  2258.505
# 3  2013-01-01   4  A  2243.969
# 4  2013-01-01   5  A  2344.105

# %%
total['구분'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'G', 'H'], dtype=object)

# %%
# 구분 열을 숫자로 바꾸기
d_map = {}
for i, d in enumerate(total['구분'].unique()):
    d_map[d] = i
total['구분'] = total['구분'].map(d_map)

# %%
total
# Out:
#                연월일  시간  구분       공급량
# 0       2013-01-01   1   0  2497.129
# 1       2013-01-01   2   0  2363.265
# 2       2013-01-01   3   0  2258.505
# 3       2013-01-01   4   0  2243.969
# 4       2013-01-01   5   0  2344.105
# ...            ...  ..  ..       ...
# 368083  2018-12-31  20   6   681.033
# 368084  2018-12-31  21   6   669.961
# 368085  2018-12-31  22   6   657.941
# 368086  2018-12-31  23   6   610.953
# 368087  2018-12-31  24   6   560.896
#
# [368088 rows x 4 columns]

# %%
# 연월일 열은 object형이므로 년, 월, 일로 나눈다.
total['연월일'] = pd.to_datetime(total['연월일'])
total['year'] = total['연월일'].dt.year
total['month'] = total['연월일'].dt.month
total['day'] = total['연월일'].dt.day
total['weekday'] = total['연월일'].dt.weekday

# %%
total
# Out:
#               연월일  시간  구분       공급량  year  month  day  weekday
# 0      2013-01-01   1   0  2497.129  2013      1    1        1
# 1      2013-01-01   2   0  2363.265  2013      1    1        1
# 2      2013-01-01   3   0  2258.505  2013      1    1        1
# 3      2013-01-01   4   0  2243.969  2013      1    1        1
# 4      2013-01-01   5   0  2344.105  2013      1    1        1
# ...           ...  ..  ..       ...   ...    ...  ...      ...
# 368083 2018-12-31  20   6   681.033  2018     12   31        0
# 368084 2018-12-31  21   6   669.961  2018     12   31        0
# 368085 2018-12-31  22   6   657.941  2018     12   31        0
# 368086 2018-12-31  23   6   610.953  2018     12   31        0
# 368087 2018-12-31  24   6   560.896  2018     12   31        0
#
# [368088 rows x 8 columns]

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368088 entries, 0 to 368087
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   연월일      368088 non-null  datetime64[ns]
#  1   시간       368088 non-null  int64
#  2   구분       368088 non-null  int64
#  3   공급량      368088 non-null  float64
#  4   year     368088 non-null  int64
#  5   month    368088 non-null  int64
#  6   day      368088 non-null  int64
#  7   weekday  368088 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 22.5 MB

# %%
pd.options.display.max_columns = 500
pd.options.display.max_rows = 3000

# %%
test = total[(total['year'] == 2013) & (total['month']==1)]
test
# Out:
#              연월일  시간  구분       공급량  year  month  day  weekday
# 0     2013-01-01   1   0  2497.129  2013      1    1        1
# 1     2013-01-01   2   0  2363.265  2013      1    1        1
# 2     2013-01-01   3   0  2258.505  2013      1    1        1
# 3     2013-01-01   4   0  2243.969  2013      1    1        1
# 4     2013-01-01   5   0  2344.105  2013      1    1        1
# ...          ...  ..  ..       ...   ...    ...  ...      ...
# 53299 2013-01-31  20   6   495.060  2013      1   31        3
# 53300 2013-01-31  21   6   499.556  2013      1   31        3
# 53301 2013-01-31  22   6   490.292  2013      1   31        3
# 53302 2013-01-31  23   6   486.092  2013      1   31        3
# 53303 2013-01-31  24   6   432.268  2013      1   31        3
#
# [5208 rows x 8 columns]

# %%
test2 = test[test['day']==1]
test2
# Out:
#              연월일  시간  구분       공급량  year  month  day  weekday
# 0     2013-01-01   1   0  2497.129  2013      1    1        1
# 1     2013-01-01   2   0  2363.265  2013      1    1        1
# 2     2013-01-01   3   0  2258.505  2013      1    1        1
# 3     2013-01-01   4   0  2243.969  2013      1    1        1
# 4     2013-01-01   5   0  2344.105  2013      1    1        1
# 5     2013-01-01   6   0  2390.961  2013      1    1        1
# 6     2013-01-01   7   0  2378.457  2013      1    1        1
# 7     2013-01-01   8   0  2518.921  2013      1    1        1
# 8     2013-01-01   9   0  2706.481  2013      1    1        1
# 9     2013-01-01  10   0  2832.057  2013      1    1        1
# 10    2013-01-01  11   0  2895.185  2013      1    1        1
# 11    2013-01-01  12   0  2689.361  2013      1    1        1
# 12    2013-01-01  13   0  2425.537  2013      1    1        1
# 13    2013-01-01  14   0  2254.289  2013      1    1        1
# ...

# %%
test2.groupby(['구분']).count()
# Out:
#     연월일  시간  공급량  year  month  day  weekday
# 구분
# 0    24  24   24    24     24   24       24
# 1    24  24   24    24     24   24       24
# 2    24  24   24    24     24   24       24
# 3    24  24   24    24     24   24       24
# 4    24  24   24    24     24   24       24
# 5    24  24   24    24     24   24       24
# 6    24  24   24    24     24   24       24

# %%
total[total['year']==2013].groupby(['year','month','day','구분']).count()
# Out:
#                    연월일  시간  공급량  weekday
# year month day 구분
# 2013 1     1   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            2   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            3   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
# ...

# %%
total[total['year']==2014].groupby(['year','month','day','구분']).count()
# Out:
#                    연월일  시간  공급량  weekday
# year month day 구분
# 2014 1     1   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            2   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            3   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
# ...

# %%
total[total['year']==2015].groupby(['year','month','day','구분']).count()
# Out:
#                    연월일  시간  공급량  weekday
# year month day 구분
# 2015 1     1   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            2   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            3   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
# ...

# %%
total[total['year']==2016].groupby(['year','month','day','구분']).count()
# Out:
#                    연월일  시간  공급량  weekday
# year month day 구분
# 2016 1     1   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            2   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            3   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
# ...

# %%
total[total['year']==2017].groupby(['year','month','day','구분']).count()
# Out:
#                    연월일  시간  공급량  weekday
# year month day 구분
# 2017 1     1   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            2   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            3   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
# ...

# %%
total[total['year']==2018].groupby(['year','month','day','구분']).count()
# Out:
#                    연월일  시간  공급량  weekday
# year month day 구분
# 2018 1     1   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            2   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
#            3   0    24  24   24       24
#                1    24  24   24       24
#                2    24  24   24       24
#                3    24  24   24       24
#                4    24  24   24       24
#                5    24  24   24       24
#                6    24  24   24       24
# ...
