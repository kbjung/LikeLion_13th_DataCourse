# %% [markdown]
# # pycaret을 이용한 가스공급량 예측
# * 2019년 test 데이터 : '../data/test.csv'
# * 2019년 제출 파일 : '../data/sample_submission.csv'
# * 2013-2018년 가스공급량과 기온 자료 : '../2013-2018년_가스공급량_기온_습도_기압01.csv'
# * 사용 특성 : 'month', 'day', '시간', '구분', '기온','습도','기압'
# * log적용
# * 3개 모델

# %%
# 제출 점수 : 0.1230232924

# %% [markdown]
# ## 데이터 가져오기
# * 2019년 test 데이터 : '../data/test.csv'
# * 2019년 제출 파일 : '../data/sample_submission.csv'
# * 2013-2018년 가스공급량과 기온 자료 : '../2013-2018년_가스공급량_기온_습도_기압01.csv'

# %%
import pandas as pd

# %% [markdown]
# ### 2013-2018년 가스공급량과 기온 자료

# %%
total = pd.read_csv('../2013-2018년_가스공급량_기온_습도_기압01.csv')
total.head()
# Out:
#    year  month  day  weekday  시간  구분       공급량   기온    습도      기압
# 0  2013      1    1        1   1   0  2497.129 -8.5  57.0  1010.0
# 1  2013      1    1        1   1   1  2169.093 -8.5  57.0  1010.0
# 2  2013      1    1        1   1   2   226.178 -8.5  57.0  1010.0
# 3  2013      1    1        1   1   3  1434.516 -8.5  57.0  1010.0
# 4  2013      1    1        1   1   4  3272.837 -8.5  57.0  1010.0

# %% [markdown]
# #### 2019년 데이터

# %%
test2019 = pd.read_csv('../data/test.csv')
test2019.head()
# Out:
#           일자|시간|구분
# 0  2019-01-01 01 A
# 1  2019-01-01 02 A
# 2  2019-01-01 03 A
# 3  2019-01-01 04 A
# 4  2019-01-01 05 A

# %%
test2019[['연월일', '시간', '구분']] = test2019['일자|시간|구분'].str.split(' ').tolist()
test2019.head()
# Out:
#           일자|시간|구분         연월일  시간 구분
# 0  2019-01-01 01 A  2019-01-01  01  A
# 1  2019-01-01 02 A  2019-01-01  02  A
# 2  2019-01-01 03 A  2019-01-01  03  A
# 3  2019-01-01 04 A  2019-01-01  04  A
# 4  2019-01-01 05 A  2019-01-01  05  A

# %%
# 구분 열을 숫자로 바꾸기
d_map = {}
for i, d in enumerate(test2019['구분'].unique()):
    d_map[d] = i
test2019['구분'] = test2019['구분'].map(d_map)
test2019.head()
# Out:
#           일자|시간|구분         연월일  시간  구분
# 0  2019-01-01 01 A  2019-01-01  01   0
# 1  2019-01-01 02 A  2019-01-01  02   0
# 2  2019-01-01 03 A  2019-01-01  03   0
# 3  2019-01-01 04 A  2019-01-01  04   0
# 4  2019-01-01 05 A  2019-01-01  05   0

# %%
# 연월일 열은 object형이므로 년, 월, 일로 나눈다.
test2019['연월일'] = pd.to_datetime(test2019['연월일'])
test2019['year'] = test2019['연월일'].dt.year
test2019['month'] = test2019['연월일'].dt.month
test2019['day'] = test2019['연월일'].dt.day
test2019['weekday'] = test2019['연월일'].dt.weekday
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1

# %% [markdown]
# ## 2019년 기온 예측하기
# * 습도 예측
# * 기압 예측

# %%
from pycaret.regression import *

# %% [markdown]
# #### 습도(Humidity) 예측

# %%
# 학습 특성 : 'month', 'day', 'weekday', '시간', '구분'
# 타겟 특성 : '습도'

humidity_prediction_model = load_model('humidity_prediction_model_01')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# %%time
df_for_temp = test2019[['month', 'day', 'weekday', '시간', '구분']]
humidity2019_pred = predict_model(humidity_prediction_model, data=df_for_temp)
# Out:
# Wall time: 3.04 s

# %%
humidity_pred.head()
# Out:
#    month  day  weekday  시간  구분      Label
# 0      1    1        1  01   0  64.463024
# 1      1    1        1  02   0  65.664050
# 2      1    1        1  03   0  65.659699
# 3      1    1        1  04   0  66.320690
# 4      1    1        1  05   0  67.903796

# %%
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1

# %%
test2019['습도'] = humidity2019_pred['Label']
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday         습도
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1  64.463024
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1  65.664050
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1  65.659699
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1  66.320690
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1  67.903796

# %% [markdown]
# #### 기압 예측

# %%
# 학습 특성 : 'month', 'day', 'weekday', '시간', '구분'
# 타겟 특성 : '기압'

exp = setup(total, target='기압', ignore_features=['공급량', 'year', '기온', '습도'])
# Out:
# <style  type="text/css" >
# #T_45b5a_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_45b5a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45b5a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_45b5a_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_45b5a_row0_col1" class="data row0 col1" >6480</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_45b5a_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_45b5a_row1_col1" class="data row1 col1" >기압</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_45b5a_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_45b5a_row2_col1" class="data row2 col1" >(368088, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_45b5a_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_45b5a_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_45b5a_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_45b5a_row4_col1" class="data row4 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_45b5a_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_45b5a_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_45b5a_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_45b5a_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_45b5a_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_45b5a_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_45b5a_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_45b5a_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_45b5a_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_45b5a_row9_col1" class="data row9 col1" >(257661, 28)</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_45b5a_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_45b5a_row10_col1" class="data row10 col1" >(110427, 28)</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_45b5a_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_45b5a_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_45b5a_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_45b5a_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_45b5a_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_45b5a_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_45b5a_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_45b5a_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_45b5a_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_45b5a_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_45b5a_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_45b5a_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_45b5a_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_45b5a_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_45b5a_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_45b5a_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_45b5a_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_45b5a_row19_col1" class="data row19 col1" >be18</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_45b5a_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_45b5a_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_45b5a_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_45b5a_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_45b5a_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_45b5a_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_45b5a_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_45b5a_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5a_level0_row24" class="row_heading level0 r

# %%
# %%time
pressure_model3 = compare_models(sort='MAPE', n_select=3)
# Out:
# <style  type="text/css" >
#     #T_efea3_ th {
#           text-align: left;
#     }#T_efea3_row0_col0,#T_efea3_row0_col2,#T_efea3_row0_col3,#T_efea3_row0_col4,#T_efea3_row0_col5,#T_efea3_row1_col0,#T_efea3_row1_col1,#T_efea3_row2_col0,#T_efea3_row2_col1,#T_efea3_row2_col2,#T_efea3_row2_col3,#T_efea3_row2_col4,#T_efea3_row2_col5,#T_efea3_row2_col6,#T_efea3_row3_col0,#T_efea3_row3_col1,#T_efea3_row3_col2,#T_efea3_row3_col3,#T_efea3_row3_col4,#T_efea3_row3_col5,#T_efea3_row3_col6,#T_efea3_row4_col0,#T_efea3_row4_col1,#T_efea3_row4_col2,#T_efea3_row4_col3,#T_efea3_row4_col4,#T_efea3_row4_col5,#T_efea3_row4_col6,#T_efea3_row5_col0,#T_efea3_row5_col1,#T_efea3_row5_col2,#T_efea3_row5_col3,#T_efea3_row5_col4,#T_efea3_row5_col5,#T_efea3_row5_col6,#T_efea3_row6_col0,#T_efea3_row6_col1,#T_efea3_row6_col2,#T_efea3_row6_col3,#T_efea3_row6_col4,#T_efea3_row6_col5,#T_efea3_row6_col6,#T_efea3_row7_col0,#T_efea3_row7_col1,#T_efea3_row7_col2,#T_efea3_row7_col3,#T_efea3_row7_col4,#T_efea3_row7_col5,#T_efea3_row7_col6,#T_efea3_row8_col0,#T_efea3_row8_col1,#T_efea3_row8_col2,#T_efea3_row8_col3,#T_efea3_row8_col4,#T_efea3_row8_col5,#T_efea3_row8_col6,#T_efea3_row9_col0,#T_efea3_row9_col1,#T_efea3_row9_col2,#T_efea3_row9_col3,#T_efea3_row9_col4,#T_efea3_row9_col5,#T_efea3_row9_col6,#T_efea3_row10_col0,#T_efea3_row10_col1,#T_efea3_row10_col2,#T_efea3_row10_col3,#T_efea3_row10_col4,#T_efea3_row10_col5,#T_efea3_row10_col6,#T_efea3_row11_col0,#T_efea3_row11_col1,#T_efea3_row11_col2,#T_efea3_row11_col3,#T_efea3_row11_col4,#T_efea3_row11_col5,#T_efea3_row11_col6,#T_efea3_row12_col0,#T_efea3_row12_col1,#T_efea3_row12_col2,#T_efea3_row12_col3,#T_efea3_row12_col4,#T_efea3_row12_col5,#T_efea3_row12_col6,#T_efea3_row13_col0,#T_efea3_row13_col1,#T_efea3_row13_col2,#T_efea3_row13_col3,#T_efea3_row13_col4,#T_efea3_row13_col5,#T_efea3_row13_col6,#T_efea3_row14_col0,#T_efea3_row14_col1,#T_efea3_row14_col2,#T_efea3_row14_col3,#T_efea3_row14_col4,#T_efea3_row14_col5,#T_efea3_row14_col6,#T_efea3_row15_col0,#T_efea3_row15_col1,#T_efea3_row15_col2,#T_efea3_row15_col3,#T_efea3_row15_col4,#T_efea3_row15_col5,#T_efea3_row15_col6,#T_efea3_row16_col0,#T_efea3_row16_col1,#T_efea3_row16_col2,#T_efea3_row16_col3,#T_efea3_row16_col4,#T_efea3_row16_col5,#T_efea3_row16_col6,#T_efea3_row17_col0,#T_efea3_row17_col1,#T_efea3_row17_col2,#T_efea3_row17_col3,#T_efea3_row17_col4,#T_efea3_row17_col5,#T_efea3_row17_col6,#T_efea3_row18_col0,#T_efea3_row18_col1,#T_efea3_row18_col2,#T_efea3_row18_col3,#T_efea3_row18_col4,#T_efea3_row18_col5,#T_efea3_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_efea3_row0_col1,#T_efea3_row0_col6,#T_efea3_row1_col2,#T_efea3_row1_col3,#T_efea3_row1_col4,#T_efea3_row1_col5,#T_efea3_row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_efea3_row0_col7,#T_efea3_row1_col7,#T_efea3_row2_col7,#T_efea3_row3_col7,#T_efea3_row4_col7,#T_efea3_row5_col7,#T_efea3_row6_col7,#T_efea3_row7_col7,#T_efea3_row8_col7,#T_efea3_row9_col7,#T_efea3_row10_col7,#T_efea3_row11_col7,#T_efea3_row12_col7,#T_efea3_row13_col7,#T_efea3_row14_col7,#T_efea3_row15_col7,#T_efea3_row16_col7,#T_efea3_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_efea3_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_efea3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_efea3_level0_row0" class="row_heading level0 row0" >dt</th>
#                         <td id="T_efea3_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#                         <td id="T_efea3_row0_col1" class="data row0 col1" >0.0088</td>
#                         <td id="T_efea3_row0_col2" class="data row0 col2" >0.0460</td>
#                         <td id="T_efea3_row0_col3" class="data row0 col3" >0.2088</td>
#                         <td id="T_efea3_row0_col4" class="data row0 col4" >0.9993</td>
#                         <td id="T_efea3_row0_col5" class="data row0 col5" >0.0002</td>
#                         <td id="T_efea3_row0_col6" class="data row0 col6" >0.0000</td>
#                         <td id="T_efea3_row0_col7" class="data row0 col7" >0.7970</td>
#             </tr>
#             <tr>
#                         <th id="T_efea3_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_efea3_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#                         <td id="T_efea3_row1_col1" class="data row1 col1" >0.0453</td>
#                         <td id="T_efea3_row1_col2" class="data row1 col2" >0.0096</td>
#                         <td id="T_efea3_row1_col3" class="data row1 col3" >0.0980</td>
#                         <td id="T_efea3_row1_col4" class="data row1 col4" >0.9999</td>
#                         <td id="T_efea3_row1_col5" class="data row1 col5" >0.0001</td>
#                         <td id="T_efea3_row1_col6" class="data row1 col6" >0.0000</td>
#                         <td id="T_efea3_row1_col7" class="data row1 col7" >48.7540</td>
#             </tr>
#             <tr>
#                         <th id="T_efea3_level0_row2" class="row_heading level0 row2" >et</th>
#                         <td id="T_efea3_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#                         <td id="T_efea3_row2_col1" class="data row2 col1" >0.0790</td>
#                         <td id="T_efea3_row2_col2" class="data row2 col2" >0.0250</td>
#                         <td id="T_efea3_row2_col3" class="data row2 col3" >0.1580</td>
#                         <td id="T_efea3_row2_col4" class="data row2 col4" >0.9996</td>
#                         <td id="T_efea3_row2_col5" class="data row2 col5" >0.0002</td>
#                         <td id="T_efea3_row2_col6" class="data row2 col6" >0.0001</td>
#                         <td id="T_efea3_row2_col7" class="data row2 col7" >60.4460</td>
#             </tr>
#             <tr>
#                         <th id="T_efea3_level0_row3" class="row_heading level0 row3" >xgboost</th>
#                         <td id="T_efea3_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_efea3_row3_col1" class="data row3 col1" >2.0973</td>
#                         <td id="T_efea3_row3_col2" class="data row3 col2" >7.3468</td>
#                         <td id="T_efea3_row3_col3" class="data row3 col3" >2.7101</td>
#                         <td id="T_efea3_row3_col4" class="data row3 col4" >0.8872</td>
#                         <td id="T_efea3_row3_col5" class="data row3 col5" >0.0027</td>
#                         <td id="T_efea3_row3_col6" class="data row3 col6" >0.0021</td>
#                         <td id="T_efea3_row3_col7" class="data row3 col7" >12.6010</td>
#             </tr>
#             <tr>
#                         <th id="T_efea3_level0_row4" class="row_heading level0 row4" >catboost</th>
#                         <td id="T_efea3_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#                         <td id="T_efea3_row4_col1" class="data row4 col1" >2.3382</td>
#                         <td id="T_efea3_row4_col2" class="data row4 col2" >8.7624</td>
#                         <td id="T_efea3_row4_col3" class="data row4 col3" >2.9601</td>
#                         <td id="T_efea3_row4_col4" class="data row4 col4" >0.8655</td>
#                         <
# Wall time: 33min 8s

# %%
# %%time
blended_pressure_model3 = blend_models(estimator_list=pressure_model3)
# Out:
# <style  type="text/css" >
# #T_2209d_row10_col0,#T_2209d_row10_col1,#T_2209d_row10_col2,#T_2209d_row10_col3,#T_2209d_row10_col4,#T_2209d_row10_col5{
#             background:  yellow;
#         }</style><table id="T_2209d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2209d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2209d_row0_col0" class="data row0 col0" >0.0391</td>
#                         <td id="T_2209d_row0_col1" class="data row0 col1" >0.0093</td>
#                         <td id="T_2209d_row0_col2" class="data row0 col2" >0.0965</td>
#                         <td id="T_2209d_row0_col3" class="data row0 col3" >0.9999</td>
#                         <td id="T_2209d_row0_col4" class="data row0 col4" >0.0001</td>
#                         <td id="T_2209d_row0_col5" class="data row0 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2209d_row1_col0" class="data row1 col0" >0.0403</td>
#                         <td id="T_2209d_row1_col1" class="data row1 col1" >0.0088</td>
#                         <td id="T_2209d_row1_col2" class="data row1 col2" >0.0941</td>
#                         <td id="T_2209d_row1_col3" class="data row1 col3" >0.9999</td>
#                         <td id="T_2209d_row1_col4" class="data row1 col4" >0.0001</td>
#                         <td id="T_2209d_row1_col5" class="data row1 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2209d_row2_col0" class="data row2 col0" >0.0390</td>
#                         <td id="T_2209d_row2_col1" class="data row2 col1" >0.0104</td>
#                         <td id="T_2209d_row2_col2" class="data row2 col2" >0.1017</td>
#                         <td id="T_2209d_row2_col3" class="data row2 col3" >0.9998</td>
#                         <td id="T_2209d_row2_col4" class="data row2 col4" >0.0001</td>
#                         <td id="T_2209d_row2_col5" class="data row2 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2209d_row3_col0" class="data row3 col0" >0.0388</td>
#                         <td id="T_2209d_row3_col1" class="data row3 col1" >0.0065</td>
#                         <td id="T_2209d_row3_col2" class="data row3 col2" >0.0808</td>
#                         <td id="T_2209d_row3_col3" class="data row3 col3" >0.9999</td>
#                         <td id="T_2209d_row3_col4" class="data row3 col4" >0.0001</td>
#                         <td id="T_2209d_row3_col5" class="data row3 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2209d_row4_col0" class="data row4 col0" >0.0425</td>
#                         <td id="T_2209d_row4_col1" class="data row4 col1" >0.0142</td>
#                         <td id="T_2209d_row4_col2" class="data row4 col2" >0.1192</td>
#                         <td id="T_2209d_row4_col3" class="data row4 col3" >0.9998</td>
#                         <td id="T_2209d_row4_col4" class="data row4 col4" >0.0001</td>
#                         <td id="T_2209d_row4_col5" class="data row4 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2209d_row5_col0" class="data row5 col0" >0.0401</td>
#                         <td id="T_2209d_row5_col1" class="data row5 col1" >0.0115</td>
#                         <td id="T_2209d_row5_col2" class="data row5 col2" >0.1073</td>
#                         <td id="T_2209d_row5_col3" class="data row5 col3" >0.9998</td>
#                         <td id="T_2209d_row5_col4" class="data row5 col4" >0.0001</td>
#                         <td id="T_2209d_row5_col5" class="data row5 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2209d_row6_col0" class="data row6 col0" >0.0419</td>
#                         <td id="T_2209d_row6_col1" class="data row6 col1" >0.0152</td>
#                         <td id="T_2209d_row6_col2" class="data row6 col2" >0.1232</td>
#                         <td id="T_2209d_row6_col3" class="data row6 col3" >0.9998</td>
#                         <td id="T_2209d_row6_col4" class="data row6 col4" >0.0001</td>
#                         <td id="T_2209d_row6_col5" class="data row6 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2209d_row7_col0" class="data row7 col0" >0.0399</td>
#                         <td id="T_2209d_row7_col1" class="data row7 col1" >0.0087</td>
#                         <td id="T_2209d_row7_col2" class="data row7 col2" >0.0931</td>
#                         <td id="T_2209d_row7_col3" class="data row7 col3" >0.9999</td>
#                         <td id="T_2209d_row7_col4" class="data row7 col4" >0.0001</td>
#                         <td id="T_2209d_row7_col5" class="data row7 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2209d_row8_col0" class="data row8 col0" >0.0418</td>
#                         <td id="T_2209d_row8_col1" class="data row8 col1" >0.0148</td>
#                         <td id="T_2209d_row8_col2" class="data row8 col2" >0.1217</td>
#                         <td id="T_2209d_row8_col3" class="data row8 col3" >0.9998</td>
#                         <td id="T_2209d_row8_col4" class="data row8 col4" >0.0001</td>
#                         <td id="T_2209d_row8_col5" class="data row8 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2209d_row9_col0" class="data row9 col0" >0.0401</td>
#                         <td id="T_2209d_row9_col1" class="data row9 col1" >0.0102</td>
#                         <td id="T_2209d_row9_col2" class="data row9 col2" >0.1008</td>
#                         <td id="T_2209d_row9_col3" class="data row9 col3" >0.9998</td>
#                         <td id="T_2209d_row9_col4" class="data row9 col4" >0.0001</td>
#                         <td id="T_2209d_row9_col5" class="data row9 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_2209d_row10_col0" class="data row10 col0" >0.0404</td>
#                         <td id="T_2209d_row10_col1" class="data row10 col1" >0.0110</td>
#                         <td id="T_2209d_row10_col2" class="data row10 col2" >0.1039</td>
#                         <td id="T_2209d_row10_col3" class="data row10 col3" >0.9998</td>
#                         <td id="T_2209d_row10_col4" class="data row10 col4" >0.0001</td>
#                         <td id="T_2209d_row10_col5" class="data row10 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_2209d_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_2209d_row11_col0" class="data row11 col0" >0.0012</td>
# Wall time: 21min 6s

# %%
# %%time
final_pressure_model3 = finalize_model(blended_pressure_model3)
# Out:
# Wall time: 14min 19s

# %%
save_model(final_pressure_model3, 'final_pressure_model01')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['year', '공급량'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='log_공급량',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  nume...
#                                                                    criterion='mse',
#                                                                    max_depth=None,
#                                                                    max_features='auto',
#                                                                    max_leaf_nodes=None,
#                                                                    max_samples=None,
#                                                                    min_impurity_decrease=0.0,
#                                                                    min_impurity_split=None,
#                                                                    min_samples_leaf=1,
#                                                                    min_samples_split=2,
#                                                                    min_weight_fraction_leaf=0.0,
#                                                                    n_estimators=100,
#                                                                    n_jobs=-1,
#                                                                    oob_score=False,
#                                                                    random_state=6480,
#                                                                    verbose=0,
#                                                                    warm_start=False))],
#                                   n_jobs=-1, verbose=False, weights=None)]],
#           verbose=False),
#  'final_pressure_model01.pkl')

# %%
pressure2019_pred = predict_model(final_pressure_model3, data=test2019)

# %%
pressure2019_pred.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday         습도  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1  64.463024
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1  65.664050
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1  65.659699
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1  66.320690
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1  67.903796
#
#          Label
# 0  1010.000000
# 1  1009.400024
# 2  1009.200012
# 3  1008.200012
# 4  1007.297321

# %%
test2019['기압'] = pressure2019_pred['Label']
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday         습도  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1  64.463024
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1  65.664050
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1  65.659699
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1  66.320690
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1  67.903796
#
#             기압
# 0  1010.000000
# 1  1009.400024
# 2  1009.200012
# 3  1008.200012
# 4  1007.297321

# %% [markdown]
# #### 기온예측

# %%
# 학습 특성 : 'month', 'day', 'weekday', '시간', '구분', '습도', '기압'
# 타겟 특성 : '기온'

exp = setup(total, target='기온', ignore_features=['공급량', 'year'])
# Out:
# <style  type="text/css" >
# #T_72550_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_72550_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72550_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_72550_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_72550_row0_col1" class="data row0 col1" >3903</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_72550_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_72550_row1_col1" class="data row1 col1" >기온</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_72550_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_72550_row2_col1" class="data row2 col1" >(368088, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_72550_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_72550_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_72550_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_72550_row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_72550_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_72550_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_72550_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_72550_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_72550_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_72550_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_72550_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_72550_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_72550_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_72550_row9_col1" class="data row9 col1" >(257661, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_72550_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_72550_row10_col1" class="data row10 col1" >(110427, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_72550_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_72550_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_72550_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_72550_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_72550_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_72550_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_72550_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_72550_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_72550_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_72550_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_72550_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_72550_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_72550_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_72550_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_72550_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_72550_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_72550_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_72550_row19_col1" class="data row19 col1" >5d45</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_72550_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_72550_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_72550_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_72550_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_72550_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_72550_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_72550_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_72550_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_72550_level0_row24" class="row_heading level0 r

# %%
# %%time
# 07-05_결과_출력(pycaret)_ver0.1(2021.11.15) 참고 모델 선택(결정트리모델은 과대적합으로 판단되어 제외)
temp_models3 = compare_models(sort='MAPE',n_select=3, include=['knn','catboost','lightgbm'])
# Out:
# <style  type="text/css" >
#     #T_246c8_ th {
#           text-align: left;
#     }#T_246c8_row0_col0,#T_246c8_row1_col0,#T_246c8_row1_col1,#T_246c8_row1_col2,#T_246c8_row1_col3,#T_246c8_row1_col4,#T_246c8_row1_col5,#T_246c8_row1_col6,#T_246c8_row2_col0,#T_246c8_row2_col1,#T_246c8_row2_col2,#T_246c8_row2_col3,#T_246c8_row2_col4,#T_246c8_row2_col5,#T_246c8_row2_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_246c8_row0_col1,#T_246c8_row0_col2,#T_246c8_row0_col3,#T_246c8_row0_col4,#T_246c8_row0_col5,#T_246c8_row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_246c8_row0_col7,#T_246c8_row1_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_246c8_row2_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_246c8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_246c8_level0_row0" class="row_heading level0 row0" >knn</th>
#                         <td id="T_246c8_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#                         <td id="T_246c8_row0_col1" class="data row0 col1" >0.7226</td>
#                         <td id="T_246c8_row0_col2" class="data row0 col2" >2.8834</td>
#                         <td id="T_246c8_row0_col3" class="data row0 col3" >1.6979</td>
#                         <td id="T_246c8_row0_col4" class="data row0 col4" >0.9773</td>
#                         <td id="T_246c8_row0_col5" class="data row0 col5" >0.2204</td>
#                         <td id="T_246c8_row0_col6" class="data row0 col6" >0.2164</td>
#                         <td id="T_246c8_row0_col7" class="data row0 col7" >2.8540</td>
#             </tr>
#             <tr>
#                         <th id="T_246c8_level0_row1" class="row_heading level0 row1" >catboost</th>
#                         <td id="T_246c8_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#                         <td id="T_246c8_row1_col1" class="data row1 col1" >1.4373</td>
#                         <td id="T_246c8_row1_col2" class="data row1 col2" >3.5221</td>
#                         <td id="T_246c8_row1_col3" class="data row1 col3" >1.8767</td>
#                         <td id="T_246c8_row1_col4" class="data row1 col4" >0.9723</td>
#                         <td id="T_246c8_row1_col5" class="data row1 col5" >0.3087</td>
#                         <td id="T_246c8_row1_col6" class="data row1 col6" >0.3990</td>
#                         <td id="T_246c8_row1_col7" class="data row1 col7" >21.1440</td>
#             </tr>
#             <tr>
#                         <th id="T_246c8_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#                         <td id="T_246c8_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_246c8_row2_col1" class="data row2 col1" >2.0176</td>
#                         <td id="T_246c8_row2_col2" class="data row2 col2" >6.8165</td>
#                         <td id="T_246c8_row2_col3" class="data row2 col3" >2.6108</td>
#                         <td id="T_246c8_row2_col4" class="data row2 col4" >0.9463</td>
#                         <td id="T_246c8_row2_col5" class="data row2 col5" >0.3990</td>
#                         <td id="T_246c8_row2_col6" class="data row2 col6" >0.5588</td>
#                         <td id="T_246c8_row2_col7" class="data row2 col7" >1.2620</td>
#             </tr>
#     </tbody></table>
# Wall time: 4min 47s

# %%
# %%time
tuned_temp_models3 = [tune_model(model) for model in temp_models3]
# Out:
# <style  type="text/css" >
# #T_25649_row10_col0,#T_25649_row10_col1,#T_25649_row10_col2,#T_25649_row10_col3,#T_25649_row10_col4,#T_25649_row10_col5{
#             background:  yellow;
#         }</style><table id="T_25649_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_25649_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_25649_row0_col0" class="data row0 col0" >1.2291</td>
#                         <td id="T_25649_row0_col1" class="data row0 col1" >2.5729</td>
#                         <td id="T_25649_row0_col2" class="data row0 col2" >1.6040</td>
#                         <td id="T_25649_row0_col3" class="data row0 col3" >0.9798</td>
#                         <td id="T_25649_row0_col4" class="data row0 col4" >0.2619</td>
#                         <td id="T_25649_row0_col5" class="data row0 col5" >0.3332</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_25649_row1_col0" class="data row1 col0" >1.2282</td>
#                         <td id="T_25649_row1_col1" class="data row1 col1" >2.5765</td>
#                         <td id="T_25649_row1_col2" class="data row1 col2" >1.6051</td>
#                         <td id="T_25649_row1_col3" class="data row1 col3" >0.9797</td>
#                         <td id="T_25649_row1_col4" class="data row1 col4" >0.2640</td>
#                         <td id="T_25649_row1_col5" class="data row1 col5" >0.3399</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_25649_row2_col0" class="data row2 col0" >1.2085</td>
#                         <td id="T_25649_row2_col1" class="data row2 col1" >2.5066</td>
#                         <td id="T_25649_row2_col2" class="data row2 col2" >1.5832</td>
#                         <td id="T_25649_row2_col3" class="data row2 col3" >0.9803</td>
#                         <td id="T_25649_row2_col4" class="data row2 col4" >0.2618</td>
#                         <td id="T_25649_row2_col5" class="data row2 col5" >0.3273</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_25649_row3_col0" class="data row3 col0" >1.2283</td>
#                         <td id="T_25649_row3_col1" class="data row3 col1" >2.5727</td>
#                         <td id="T_25649_row3_col2" class="data row3 col2" >1.6040</td>
#                         <td id="T_25649_row3_col3" class="data row3 col3" >0.9797</td>
#                         <td id="T_25649_row3_col4" class="data row3 col4" >0.2616</td>
#                         <td id="T_25649_row3_col5" class="data row3 col5" >0.3256</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_25649_row4_col0" class="data row4 col0" >1.2210</td>
#                         <td id="T_25649_row4_col1" class="data row4 col1" >2.5544</td>
#                         <td id="T_25649_row4_col2" class="data row4 col2" >1.5983</td>
#                         <td id="T_25649_row4_col3" class="data row4 col3" >0.9800</td>
#                         <td id="T_25649_row4_col4" class="data row4 col4" >0.2640</td>
#                         <td id="T_25649_row4_col5" class="data row4 col5" >0.3397</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_25649_row5_col0" class="data row5 col0" >1.2222</td>
#                         <td id="T_25649_row5_col1" class="data row5 col1" >2.5419</td>
#                         <td id="T_25649_row5_col2" class="data row5 col2" >1.5943</td>
#                         <td id="T_25649_row5_col3" class="data row5 col3" >0.9800</td>
#                         <td id="T_25649_row5_col4" class="data row5 col4" >0.2640</td>
#                         <td id="T_25649_row5_col5" class="data row5 col5" >0.3271</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_25649_row6_col0" class="data row6 col0" >1.2162</td>
#                         <td id="T_25649_row6_col1" class="data row6 col1" >2.5218</td>
#                         <td id="T_25649_row6_col2" class="data row6 col2" >1.5880</td>
#                         <td id="T_25649_row6_col3" class="data row6 col3" >0.9801</td>
#                         <td id="T_25649_row6_col4" class="data row6 col4" >0.2647</td>
#                         <td id="T_25649_row6_col5" class="data row6 col5" >0.3375</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_25649_row7_col0" class="data row7 col0" >1.2321</td>
#                         <td id="T_25649_row7_col1" class="data row7 col1" >2.6113</td>
#                         <td id="T_25649_row7_col2" class="data row7 col2" >1.6159</td>
#                         <td id="T_25649_row7_col3" class="data row7 col3" >0.9793</td>
#                         <td id="T_25649_row7_col4" class="data row7 col4" >0.2677</td>
#                         <td id="T_25649_row7_col5" class="data row7 col5" >0.3463</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_25649_row8_col0" class="data row8 col0" >1.2142</td>
#                         <td id="T_25649_row8_col1" class="data row8 col1" >2.5125</td>
#                         <td id="T_25649_row8_col2" class="data row8 col2" >1.5851</td>
#                         <td id="T_25649_row8_col3" class="data row8 col3" >0.9801</td>
#                         <td id="T_25649_row8_col4" class="data row8 col4" >0.2591</td>
#                         <td id="T_25649_row8_col5" class="data row8 col5" >0.3353</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_25649_row9_col0" class="data row9 col0" >1.2052</td>
#                         <td id="T_25649_row9_col1" class="data row9 col1" >2.4881</td>
#                         <td id="T_25649_row9_col2" class="data row9 col2" >1.5774</td>
#                         <td id="T_25649_row9_col3" class="data row9 col3" >0.9804</td>
#                         <td id="T_25649_row9_col4" class="data row9 col4" >0.2654</td>
#                         <td id="T_25649_row9_col5" class="data row9 col5" >0.3308</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_25649_row10_col0" class="data row10 col0" >1.2205</td>
#                         <td id="T_25649_row10_col1" class="data row10 col1" >2.5459</td>
#                         <td id="T_25649_row10_col2" class="data row10 col2" >1.5955</td>
#                         <td id="T_25649_row10_col3" class="data row10 col3" >0.9799</td>
#                         <td id="T_25649_row10_col4" class="data row10 col4" >0.2634</td>
#                         <td id="T_25649_row10_col5" class="data row10 col5" >0.3343</td>
#             </tr>
#             <tr>
#                         <th id="T_25649_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_25649_row11_col0" class="data row11 col0" >0.0088</td>
# Wall time: 17min 31s

# %%
# %%time
blend_models3 = blend_models(estimator_list=tuned_temp_models3)
# Out:
# <style  type="text/css" >
# #T_9453c_row10_col0,#T_9453c_row10_col1,#T_9453c_row10_col2,#T_9453c_row10_col3,#T_9453c_row10_col4,#T_9453c_row10_col5{
#             background:  yellow;
#         }</style><table id="T_9453c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9453c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9453c_row0_col0" class="data row0 col0" >0.8610</td>
#                         <td id="T_9453c_row0_col1" class="data row0 col1" >1.2964</td>
#                         <td id="T_9453c_row0_col2" class="data row0 col2" >1.1386</td>
#                         <td id="T_9453c_row0_col3" class="data row0 col3" >0.9898</td>
#                         <td id="T_9453c_row0_col4" class="data row0 col4" >0.1950</td>
#                         <td id="T_9453c_row0_col5" class="data row0 col5" >0.2352</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9453c_row1_col0" class="data row1 col0" >0.8623</td>
#                         <td id="T_9453c_row1_col1" class="data row1 col1" >1.2928</td>
#                         <td id="T_9453c_row1_col2" class="data row1 col2" >1.1370</td>
#                         <td id="T_9453c_row1_col3" class="data row1 col3" >0.9898</td>
#                         <td id="T_9453c_row1_col4" class="data row1 col4" >0.1978</td>
#                         <td id="T_9453c_row1_col5" class="data row1 col5" >0.2382</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9453c_row2_col0" class="data row2 col0" >0.8579</td>
#                         <td id="T_9453c_row2_col1" class="data row2 col1" >1.2973</td>
#                         <td id="T_9453c_row2_col2" class="data row2 col2" >1.1390</td>
#                         <td id="T_9453c_row2_col3" class="data row2 col3" >0.9898</td>
#                         <td id="T_9453c_row2_col4" class="data row2 col4" >0.1993</td>
#                         <td id="T_9453c_row2_col5" class="data row2 col5" >0.2273</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9453c_row3_col0" class="data row3 col0" >0.8698</td>
#                         <td id="T_9453c_row3_col1" class="data row3 col1" >1.3315</td>
#                         <td id="T_9453c_row3_col2" class="data row3 col2" >1.1539</td>
#                         <td id="T_9453c_row3_col3" class="data row3 col3" >0.9895</td>
#                         <td id="T_9453c_row3_col4" class="data row3 col4" >0.1981</td>
#                         <td id="T_9453c_row3_col5" class="data row3 col5" >0.2284</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9453c_row4_col0" class="data row4 col0" >0.8637</td>
#                         <td id="T_9453c_row4_col1" class="data row4 col1" >1.3135</td>
#                         <td id="T_9453c_row4_col2" class="data row4 col2" >1.1461</td>
#                         <td id="T_9453c_row4_col3" class="data row4 col3" >0.9897</td>
#                         <td id="T_9453c_row4_col4" class="data row4 col4" >0.2032</td>
#                         <td id="T_9453c_row4_col5" class="data row4 col5" >0.2400</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9453c_row5_col0" class="data row5 col0" >0.8644</td>
#                         <td id="T_9453c_row5_col1" class="data row5 col1" >1.3158</td>
#                         <td id="T_9453c_row5_col2" class="data row5 col2" >1.1471</td>
#                         <td id="T_9453c_row5_col3" class="data row5 col3" >0.9896</td>
#                         <td id="T_9453c_row5_col4" class="data row5 col4" >0.1939</td>
#                         <td id="T_9453c_row5_col5" class="data row5 col5" >0.2287</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9453c_row6_col0" class="data row6 col0" >0.8546</td>
#                         <td id="T_9453c_row6_col1" class="data row6 col1" >1.2960</td>
#                         <td id="T_9453c_row6_col2" class="data row6 col2" >1.1384</td>
#                         <td id="T_9453c_row6_col3" class="data row6 col3" >0.9898</td>
#                         <td id="T_9453c_row6_col4" class="data row6 col4" >0.1962</td>
#                         <td id="T_9453c_row6_col5" class="data row6 col5" >0.2323</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9453c_row7_col0" class="data row7 col0" >0.8649</td>
#                         <td id="T_9453c_row7_col1" class="data row7 col1" >1.3043</td>
#                         <td id="T_9453c_row7_col2" class="data row7 col2" >1.1421</td>
#                         <td id="T_9453c_row7_col3" class="data row7 col3" >0.9897</td>
#                         <td id="T_9453c_row7_col4" class="data row7 col4" >0.2009</td>
#                         <td id="T_9453c_row7_col5" class="data row7 col5" >0.2458</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9453c_row8_col0" class="data row8 col0" >0.8522</td>
#                         <td id="T_9453c_row8_col1" class="data row8 col1" >1.2792</td>
#                         <td id="T_9453c_row8_col2" class="data row8 col2" >1.1310</td>
#                         <td id="T_9453c_row8_col3" class="data row8 col3" >0.9899</td>
#                         <td id="T_9453c_row8_col4" class="data row8 col4" >0.1925</td>
#                         <td id="T_9453c_row8_col5" class="data row8 col5" >0.2326</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9453c_row9_col0" class="data row9 col0" >0.8566</td>
#                         <td id="T_9453c_row9_col1" class="data row9 col1" >1.2929</td>
#                         <td id="T_9453c_row9_col2" class="data row9 col2" >1.1371</td>
#                         <td id="T_9453c_row9_col3" class="data row9 col3" >0.9898</td>
#                         <td id="T_9453c_row9_col4" class="data row9 col4" >0.1999</td>
#                         <td id="T_9453c_row9_col5" class="data row9 col5" >0.2371</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_9453c_row10_col0" class="data row10 col0" >0.8607</td>
#                         <td id="T_9453c_row10_col1" class="data row10 col1" >1.3020</td>
#                         <td id="T_9453c_row10_col2" class="data row10 col2" >1.1410</td>
#                         <td id="T_9453c_row10_col3" class="data row10 col3" >0.9897</td>
#                         <td id="T_9453c_row10_col4" class="data row10 col4" >0.1977</td>
#                         <td id="T_9453c_row10_col5" class="data row10 col5" >0.2346</td>
#             </tr>
#             <tr>
#                         <th id="T_9453c_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_9453c_row11_col0" class="data row11 col0" >0.0051</td>
# Wall time: 2min 51s

# %%
# %%time
temp_prediction_model = finalize_model(blend_models3)
# Out:
# Wall time: 3min 34s

# %%
save_model(temp_prediction_model, 'temp_prediction_model01')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['공급량', 'year'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='기온',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_s...
#                                                              importance_type='split',
#                                                              learning_rate=0.1,
#                                                              max_depth=-1,
#                                                              min_child_samples=46,
#                                                              min_child_weight=0.001,
#                                                              min_split_gain=0.9,
#                                                              n_estimators=260,
#                                                              n_jobs=-1,
#                                                              num_leaves=200,
#                                                              objective=None,
#                                                              random_state=3903,
#                                                              reg_alpha=0.01,
#                                                              reg_lambda=1e-06,
#                                                              silent='warn',
#                                                              subsample=1.0,
#                                                              subsample_for_bin=200000,
#                                                              subsample_freq=0))],
#                                   n_jobs=-1, verbose=False, weights=None)]],
#           verbose=False),
#  'temp_prediction_model01.pkl')

# %%
temp_pred = predict_model(temp_prediction_model, data=test2019)
temp_pred.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday         습도  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1  64.463024
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1  65.664050
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1  65.659699
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1  66.320690
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1  67.903796
#
#             기압     Label
# 0  1010.000000 -0.742530
# 1  1009.400024 -1.873191
# 2  1009.200012 -2.116468
# 3  1008.200012 -0.642952
# 4  1007.297321  1.665344

# %%
test2019['기온'] = temp_pred['Label']
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday         습도  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1  64.463024
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1  65.664050
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1  65.659699
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1  66.320690
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1  67.903796
#
#             기압        기온
# 0  1010.000000 -0.742530
# 1  1009.400024 -1.873191
# 2  1009.200012 -2.116468
# 3  1008.200012 -0.642952
# 4  1007.297321  1.665344

# %% [markdown]
# ### 가스 공급량 예측

# %%
import numpy as np

# %%
total['log_공급량'] = np.log1p(total['공급량'])
total.head()
# Out:
#    year  month  day  weekday  시간  구분       공급량   기온    습도      기압   log_공급량
# 0  2013      1    1        1   1   0  2497.129 -8.5  57.0  1010.0  7.823297
# 1  2013      1    1        1   1   1  2169.093 -8.5  57.0  1010.0  7.682525
# 2  2013      1    1        1   1   2   226.178 -8.5  57.0  1010.0  5.425734
# 3  2013      1    1        1   1   3  1434.516 -8.5  57.0  1010.0  7.269280
# 4  2013      1    1        1   1   4  3272.837 -8.5  57.0  1010.0  8.093718

# %%
# 학습 특성 : 'month', 'day', 'weekday', '시간', '구분', '습도', '기압', '기온'
exp = setup(total, target='log_공급량', ignore_features=['year', '공급량'])
# Out:
# <style  type="text/css" >
# #T_4c663_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_4c663_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c663_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c663_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4c663_row0_col1" class="data row0 col1" >2117</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c663_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_4c663_row1_col1" class="data row1 col1" >log_공급량</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4c663_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_4c663_row2_col1" class="data row2 col1" >(368088, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4c663_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_4c663_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4c663_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_4c663_row4_col1" class="data row4 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4c663_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_4c663_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4c663_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_4c663_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4c663_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_4c663_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4c663_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_4c663_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4c663_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_4c663_row9_col1" class="data row9 col1" >(257661, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4c663_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_4c663_row10_col1" class="data row10 col1" >(110427, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4c663_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_4c663_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4c663_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_4c663_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4c663_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_4c663_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4c663_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_4c663_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4c663_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_4c663_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4c663_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_4c663_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4c663_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_4c663_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4c663_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_4c663_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_4c663_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_4c663_row19_col1" class="data row19 col1" >90b0</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_4c663_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_4c663_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_4c663_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_4c663_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_4c663_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_4c663_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_4c663_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_4c663_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4c663_level0_row24" class="row_heading lev

# %%
# 모델 비교

# compare_models(sort='MAPE', exclude=['lr','lasso','ridge','rf','dt','et'])

# %%
cat = create_model('catboost')
lgbm = create_model('lightgbm')
xgb = create_model('xgboost')
# Out:
# <style  type="text/css" >
# #T_6e250_row10_col0,#T_6e250_row10_col1,#T_6e250_row10_col2,#T_6e250_row10_col3,#T_6e250_row10_col4,#T_6e250_row10_col5{
#             background:  yellow;
#         }</style><table id="T_6e250_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e250_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e250_row0_col0" class="data row0 col0" >0.1053</td>
#                         <td id="T_6e250_row0_col1" class="data row0 col1" >0.0618</td>
#                         <td id="T_6e250_row0_col2" class="data row0 col2" >0.2486</td>
#                         <td id="T_6e250_row0_col3" class="data row0 col3" >0.9572</td>
#                         <td id="T_6e250_row0_col4" class="data row0 col4" >0.0701</td>
#                         <td id="T_6e250_row0_col5" class="data row0 col5" >0.0328</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6e250_row1_col0" class="data row1 col0" >0.1042</td>
#                         <td id="T_6e250_row1_col1" class="data row1 col1" >0.0569</td>
#                         <td id="T_6e250_row1_col2" class="data row1 col2" >0.2386</td>
#                         <td id="T_6e250_row1_col3" class="data row1 col3" >0.9597</td>
#                         <td id="T_6e250_row1_col4" class="data row1 col4" >0.0671</td>
#                         <td id="T_6e250_row1_col5" class="data row1 col5" >0.0315</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6e250_row2_col0" class="data row2 col0" >0.1058</td>
#                         <td id="T_6e250_row2_col1" class="data row2 col1" >0.0616</td>
#                         <td id="T_6e250_row2_col2" class="data row2 col2" >0.2482</td>
#                         <td id="T_6e250_row2_col3" class="data row2 col3" >0.9574</td>
#                         <td id="T_6e250_row2_col4" class="data row2 col4" >0.0703</td>
#                         <td id="T_6e250_row2_col5" class="data row2 col5" >0.0331</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6e250_row3_col0" class="data row3 col0" >0.1046</td>
#                         <td id="T_6e250_row3_col1" class="data row3 col1" >0.0568</td>
#                         <td id="T_6e250_row3_col2" class="data row3 col2" >0.2384</td>
#                         <td id="T_6e250_row3_col3" class="data row3 col3" >0.9606</td>
#                         <td id="T_6e250_row3_col4" class="data row3 col4" >0.0656</td>
#                         <td id="T_6e250_row3_col5" class="data row3 col5" >0.0307</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6e250_row4_col0" class="data row4 col0" >0.1075</td>
#                         <td id="T_6e250_row4_col1" class="data row4 col1" >0.0660</td>
#                         <td id="T_6e250_row4_col2" class="data row4 col2" >0.2568</td>
#                         <td id="T_6e250_row4_col3" class="data row4 col3" >0.9540</td>
#                         <td id="T_6e250_row4_col4" class="data row4 col4" >0.0718</td>
#                         <td id="T_6e250_row4_col5" class="data row4 col5" >0.0336</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6e250_row5_col0" class="data row5 col0" >0.1074</td>
#                         <td id="T_6e250_row5_col1" class="data row5 col1" >0.0642</td>
#                         <td id="T_6e250_row5_col2" class="data row5 col2" >0.2533</td>
#                         <td id="T_6e250_row5_col3" class="data row5 col3" >0.9550</td>
#                         <td id="T_6e250_row5_col4" class="data row5 col4" >0.0707</td>
#                         <td id="T_6e250_row5_col5" class="data row5 col5" >0.0332</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6e250_row6_col0" class="data row6 col0" >0.1075</td>
#                         <td id="T_6e250_row6_col1" class="data row6 col1" >0.0661</td>
#                         <td id="T_6e250_row6_col2" class="data row6 col2" >0.2572</td>
#                         <td id="T_6e250_row6_col3" class="data row6 col3" >0.9542</td>
#                         <td id="T_6e250_row6_col4" class="data row6 col4" >0.0713</td>
#                         <td id="T_6e250_row6_col5" class="data row6 col5" >0.0333</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6e250_row7_col0" class="data row7 col0" >0.1044</td>
#                         <td id="T_6e250_row7_col1" class="data row7 col1" >0.0582</td>
#                         <td id="T_6e250_row7_col2" class="data row7 col2" >0.2413</td>
#                         <td id="T_6e250_row7_col3" class="data row7 col3" >0.9590</td>
#                         <td id="T_6e250_row7_col4" class="data row7 col4" >0.0674</td>
#                         <td id="T_6e250_row7_col5" class="data row7 col5" >0.0315</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6e250_row8_col0" class="data row8 col0" >0.1073</td>
#                         <td id="T_6e250_row8_col1" class="data row8 col1" >0.0644</td>
#                         <td id="T_6e250_row8_col2" class="data row8 col2" >0.2538</td>
#                         <td id="T_6e250_row8_col3" class="data row8 col3" >0.9553</td>
#                         <td id="T_6e250_row8_col4" class="data row8 col4" >0.0706</td>
#                         <td id="T_6e250_row8_col5" class="data row8 col5" >0.0331</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6e250_row9_col0" class="data row9 col0" >0.1068</td>
#                         <td id="T_6e250_row9_col1" class="data row9 col1" >0.0666</td>
#                         <td id="T_6e250_row9_col2" class="data row9 col2" >0.2580</td>
#                         <td id="T_6e250_row9_col3" class="data row9 col3" >0.9533</td>
#                         <td id="T_6e250_row9_col4" class="data row9 col4" >0.0721</td>
#                         <td id="T_6e250_row9_col5" class="data row9 col5" >0.0336</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_6e250_row10_col0" class="data row10 col0" >0.1061</td>
#                         <td id="T_6e250_row10_col1" class="data row10 col1" >0.0623</td>
#                         <td id="T_6e250_row10_col2" class="data row10 col2" >0.2494</td>
#                         <td id="T_6e250_row10_col3" class="data row10 col3" >0.9566</td>
#                         <td id="T_6e250_row10_col4" class="data row10 col4" >0.0697</td>
#                         <td id="T_6e250_row10_col5" class="data row10 col5" >0.0326</td>
#             </tr>
#             <tr>
#                         <th id="T_6e250_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_6e250_row11_col0" class="data row11 col0" >0.0013</td>

# %%
# %%time
tuned_cat = tune_model(cat)
tuned_lgbm = tune_model(lgbm)
tuned_xgb = tune_model(xgb)
# Out:
# <style  type="text/css" >
# #T_7eb93_row10_col0,#T_7eb93_row10_col1,#T_7eb93_row10_col2,#T_7eb93_row10_col3,#T_7eb93_row10_col4,#T_7eb93_row10_col5{
#             background:  yellow;
#         }</style><table id="T_7eb93_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7eb93_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7eb93_row0_col0" class="data row0 col0" >0.0609</td>
#                         <td id="T_7eb93_row0_col1" class="data row0 col1" >0.0188</td>
#                         <td id="T_7eb93_row0_col2" class="data row0 col2" >0.1370</td>
#                         <td id="T_7eb93_row0_col3" class="data row0 col3" >0.9870</td>
#                         <td id="T_7eb93_row0_col4" class="data row0 col4" >0.0388</td>
#                         <td id="T_7eb93_row0_col5" class="data row0 col5" >0.0163</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7eb93_row1_col0" class="data row1 col0" >0.0605</td>
#                         <td id="T_7eb93_row1_col1" class="data row1 col1" >0.0185</td>
#                         <td id="T_7eb93_row1_col2" class="data row1 col2" >0.1359</td>
#                         <td id="T_7eb93_row1_col3" class="data row1 col3" >0.9869</td>
#                         <td id="T_7eb93_row1_col4" class="data row1 col4" >0.0397</td>
#                         <td id="T_7eb93_row1_col5" class="data row1 col5" >0.0165</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7eb93_row2_col0" class="data row2 col0" >0.0614</td>
#                         <td id="T_7eb93_row2_col1" class="data row2 col1" >0.0195</td>
#                         <td id="T_7eb93_row2_col2" class="data row2 col2" >0.1396</td>
#                         <td id="T_7eb93_row2_col3" class="data row2 col3" >0.9865</td>
#                         <td id="T_7eb93_row2_col4" class="data row2 col4" >0.0405</td>
#                         <td id="T_7eb93_row2_col5" class="data row2 col5" >0.0169</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7eb93_row3_col0" class="data row3 col0" >0.0613</td>
#                         <td id="T_7eb93_row3_col1" class="data row3 col1" >0.0190</td>
#                         <td id="T_7eb93_row3_col2" class="data row3 col2" >0.1379</td>
#                         <td id="T_7eb93_row3_col3" class="data row3 col3" >0.9868</td>
#                         <td id="T_7eb93_row3_col4" class="data row3 col4" >0.0392</td>
#                         <td id="T_7eb93_row3_col5" class="data row3 col5" >0.0165</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7eb93_row4_col0" class="data row4 col0" >0.0605</td>
#                         <td id="T_7eb93_row4_col1" class="data row4 col1" >0.0199</td>
#                         <td id="T_7eb93_row4_col2" class="data row4 col2" >0.1411</td>
#                         <td id="T_7eb93_row4_col3" class="data row4 col3" >0.9861</td>
#                         <td id="T_7eb93_row4_col4" class="data row4 col4" >0.0404</td>
#                         <td id="T_7eb93_row4_col5" class="data row4 col5" >0.0167</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7eb93_row5_col0" class="data row5 col0" >0.0614</td>
#                         <td id="T_7eb93_row5_col1" class="data row5 col1" >0.0192</td>
#                         <td id="T_7eb93_row5_col2" class="data row5 col2" >0.1384</td>
#                         <td id="T_7eb93_row5_col3" class="data row5 col3" >0.9866</td>
#                         <td id="T_7eb93_row5_col4" class="data row5 col4" >0.0397</td>
#                         <td id="T_7eb93_row5_col5" class="data row5 col5" >0.0167</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7eb93_row6_col0" class="data row6 col0" >0.0617</td>
#                         <td id="T_7eb93_row6_col1" class="data row6 col1" >0.0204</td>
#                         <td id="T_7eb93_row6_col2" class="data row6 col2" >0.1428</td>
#                         <td id="T_7eb93_row6_col3" class="data row6 col3" >0.9859</td>
#                         <td id="T_7eb93_row6_col4" class="data row6 col4" >0.0414</td>
#                         <td id="T_7eb93_row6_col5" class="data row6 col5" >0.0172</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7eb93_row7_col0" class="data row7 col0" >0.0610</td>
#                         <td id="T_7eb93_row7_col1" class="data row7 col1" >0.0201</td>
#                         <td id="T_7eb93_row7_col2" class="data row7 col2" >0.1418</td>
#                         <td id="T_7eb93_row7_col3" class="data row7 col3" >0.9858</td>
#                         <td id="T_7eb93_row7_col4" class="data row7 col4" >0.0416</td>
#                         <td id="T_7eb93_row7_col5" class="data row7 col5" >0.0171</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7eb93_row8_col0" class="data row8 col0" >0.0628</td>
#                         <td id="T_7eb93_row8_col1" class="data row8 col1" >0.0218</td>
#                         <td id="T_7eb93_row8_col2" class="data row8 col2" >0.1476</td>
#                         <td id="T_7eb93_row8_col3" class="data row8 col3" >0.9849</td>
#                         <td id="T_7eb93_row8_col4" class="data row8 col4" >0.0424</td>
#                         <td id="T_7eb93_row8_col5" class="data row8 col5" >0.0176</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7eb93_row9_col0" class="data row9 col0" >0.0626</td>
#                         <td id="T_7eb93_row9_col1" class="data row9 col1" >0.0223</td>
#                         <td id="T_7eb93_row9_col2" class="data row9 col2" >0.1492</td>
#                         <td id="T_7eb93_row9_col3" class="data row9 col3" >0.9844</td>
#                         <td id="T_7eb93_row9_col4" class="data row9 col4" >0.0438</td>
#                         <td id="T_7eb93_row9_col5" class="data row9 col5" >0.0179</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_7eb93_row10_col0" class="data row10 col0" >0.0614</td>
#                         <td id="T_7eb93_row10_col1" class="data row10 col1" >0.0199</td>
#                         <td id="T_7eb93_row10_col2" class="data row10 col2" >0.1411</td>
#                         <td id="T_7eb93_row10_col3" class="data row10 col3" >0.9861</td>
#                         <td id="T_7eb93_row10_col4" class="data row10 col4" >0.0408</td>
#                         <td id="T_7eb93_row10_col5" class="data row10 col5" >0.0169</td>
#             </tr>
#             <tr>
#                         <th id="T_7eb93_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_7eb93_row11_col0" class="data row11 col0" >0.0007</td>
# Wall time: 1h 13min 12s

# %%
# %%time
blend_model = blend_models(estimator_list=[tuned_cat, tuned_lgbm, tuned_xgb])
# Out:
# <style  type="text/css" >
# #T_264ef_row10_col0,#T_264ef_row10_col1,#T_264ef_row10_col2,#T_264ef_row10_col3,#T_264ef_row10_col4,#T_264ef_row10_col5{
#             background:  yellow;
#         }</style><table id="T_264ef_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_264ef_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_264ef_row0_col0" class="data row0 col0" >0.0800</td>
#                         <td id="T_264ef_row0_col1" class="data row0 col1" >0.0328</td>
#                         <td id="T_264ef_row0_col2" class="data row0 col2" >0.1810</td>
#                         <td id="T_264ef_row0_col3" class="data row0 col3" >0.9773</td>
#                         <td id="T_264ef_row0_col4" class="data row0 col4" >0.0542</td>
#                         <td id="T_264ef_row0_col5" class="data row0 col5" >0.0241</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_264ef_row1_col0" class="data row1 col0" >0.0792</td>
#                         <td id="T_264ef_row1_col1" class="data row1 col1" >0.0320</td>
#                         <td id="T_264ef_row1_col2" class="data row1 col2" >0.1790</td>
#                         <td id="T_264ef_row1_col3" class="data row1 col3" >0.9773</td>
#                         <td id="T_264ef_row1_col4" class="data row1 col4" >0.0539</td>
#                         <td id="T_264ef_row1_col5" class="data row1 col5" >0.0239</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_264ef_row2_col0" class="data row2 col0" >0.0802</td>
#                         <td id="T_264ef_row2_col1" class="data row2 col1" >0.0333</td>
#                         <td id="T_264ef_row2_col2" class="data row2 col2" >0.1825</td>
#                         <td id="T_264ef_row2_col3" class="data row2 col3" >0.9769</td>
#                         <td id="T_264ef_row2_col4" class="data row2 col4" >0.0552</td>
#                         <td id="T_264ef_row2_col5" class="data row2 col5" >0.0246</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_264ef_row3_col0" class="data row3 col0" >0.0804</td>
#                         <td id="T_264ef_row3_col1" class="data row3 col1" >0.0326</td>
#                         <td id="T_264ef_row3_col2" class="data row3 col2" >0.1807</td>
#                         <td id="T_264ef_row3_col3" class="data row3 col3" >0.9774</td>
#                         <td id="T_264ef_row3_col4" class="data row3 col4" >0.0534</td>
#                         <td id="T_264ef_row3_col5" class="data row3 col5" >0.0238</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_264ef_row4_col0" class="data row4 col0" >0.0800</td>
#                         <td id="T_264ef_row4_col1" class="data row4 col1" >0.0340</td>
#                         <td id="T_264ef_row4_col2" class="data row4 col2" >0.1844</td>
#                         <td id="T_264ef_row4_col3" class="data row4 col3" >0.9763</td>
#                         <td id="T_264ef_row4_col4" class="data row4 col4" >0.0553</td>
#                         <td id="T_264ef_row4_col5" class="data row4 col5" >0.0245</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_264ef_row5_col0" class="data row5 col0" >0.0798</td>
#                         <td id="T_264ef_row5_col1" class="data row5 col1" >0.0328</td>
#                         <td id="T_264ef_row5_col2" class="data row5 col2" >0.1811</td>
#                         <td id="T_264ef_row5_col3" class="data row5 col3" >0.9770</td>
#                         <td id="T_264ef_row5_col4" class="data row5 col4" >0.0540</td>
#                         <td id="T_264ef_row5_col5" class="data row5 col5" >0.0240</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_264ef_row6_col0" class="data row6 col0" >0.0807</td>
#                         <td id="T_264ef_row6_col1" class="data row6 col1" >0.0358</td>
#                         <td id="T_264ef_row6_col2" class="data row6 col2" >0.1891</td>
#                         <td id="T_264ef_row6_col3" class="data row6 col3" >0.9752</td>
#                         <td id="T_264ef_row6_col4" class="data row6 col4" >0.0567</td>
#                         <td id="T_264ef_row6_col5" class="data row6 col5" >0.0250</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_264ef_row7_col0" class="data row7 col0" >0.0794</td>
#                         <td id="T_264ef_row7_col1" class="data row7 col1" >0.0338</td>
#                         <td id="T_264ef_row7_col2" class="data row7 col2" >0.1838</td>
#                         <td id="T_264ef_row7_col3" class="data row7 col3" >0.9762</td>
#                         <td id="T_264ef_row7_col4" class="data row7 col4" >0.0552</td>
#                         <td id="T_264ef_row7_col5" class="data row7 col5" >0.0242</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_264ef_row8_col0" class="data row8 col0" >0.0824</td>
#                         <td id="T_264ef_row8_col1" class="data row8 col1" >0.0369</td>
#                         <td id="T_264ef_row8_col2" class="data row8 col2" >0.1920</td>
#                         <td id="T_264ef_row8_col3" class="data row8 col3" >0.9744</td>
#                         <td id="T_264ef_row8_col4" class="data row8 col4" >0.0569</td>
#                         <td id="T_264ef_row8_col5" class="data row8 col5" >0.0253</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_264ef_row9_col0" class="data row9 col0" >0.0811</td>
#                         <td id="T_264ef_row9_col1" class="data row9 col1" >0.0372</td>
#                         <td id="T_264ef_row9_col2" class="data row9 col2" >0.1928</td>
#                         <td id="T_264ef_row9_col3" class="data row9 col3" >0.9739</td>
#                         <td id="T_264ef_row9_col4" class="data row9 col4" >0.0578</td>
#                         <td id="T_264ef_row9_col5" class="data row9 col5" >0.0254</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_264ef_row10_col0" class="data row10 col0" >0.0803</td>
#                         <td id="T_264ef_row10_col1" class="data row10 col1" >0.0341</td>
#                         <td id="T_264ef_row10_col2" class="data row10 col2" >0.1846</td>
#                         <td id="T_264ef_row10_col3" class="data row10 col3" >0.9762</td>
#                         <td id="T_264ef_row10_col4" class="data row10 col4" >0.0553</td>
#                         <td id="T_264ef_row10_col5" class="data row10 col5" >0.0245</td>
#             </tr>
#             <tr>
#                         <th id="T_264ef_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_264ef_row11_col0" class="data row11 col0" >0.0009</td>
# Wall time: 14min 51s

# %%
# %%time
gas_prediction_model = finalize_model(blend_model)
# Out:
# Wall time: 16min 50s

# %%
save_model(gas_prediction_model, 'gas_prediction_model02')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['year', '공급량'],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='log_공급량',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  nume...
#                                                             max_depth=11,
#                                                             min_child_weight=4,
#                                                             missing=nan,
#                                                             monotone_constraints='()',
#                                                             n_estimators=210,
#                                                             n_jobs=-1,
#                                                             num_parallel_tree=1,
#                                                             objective='reg:squarederror',
#                                                             predictor='auto',
#                                                             random_state=2117,
#                                                             reg_alpha=1,
#                                                             reg_lambda=0.7,
#                                                             scale_pos_weight=8.9,
#                                                             subsample=1,
#                                                             tree_method='auto',
#                                                             validate_parameters=1,
#                                                             verbosity=0))],
#                                   n_jobs=-1, verbose=False, weights=None)]],
#           verbose=False),
#  'gas_prediction_model02.pkl')

# %%
log_gas_pred = predict_model(gas_prediction_model, data=test2019)
log_gas_pred.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday         습도  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1  64.463024
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1  65.664050
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1  65.659699
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1  66.320690
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1  67.903796
#
#             기압        기온     Label
# 0  1010.000000 -0.742530  7.539387
# 1  1009.400024 -1.873191  7.426608
# 2  1009.200012 -2.116468  7.354074
# 3  1008.200012 -0.642952  7.336640
# 4  1007.297321  1.665344  7.409057

# %% [markdown]
# ### 제출 파일 만들기

# %%
sub = pd.read_csv('../data/sample_submission.csv')
sub.head()
# Out:
#           일자|시간|구분  공급량
# 0  2019-01-01 01 A    0
# 1  2019-01-01 02 A    0
# 2  2019-01-01 03 A    0
# 3  2019-01-01 04 A    0
# 4  2019-01-01 05 A    0

# %%
pred = np.expm1(log_gas_pred['Label'])

# %%
sub['공급량'] = pred
sub.head()
# Out:
#           일자|시간|구분          공급량
# 0  2019-01-01 01 A  1879.677671
# 1  2019-01-01 02 A  1679.098661
# 2  2019-01-01 03 A  1561.549214
# 3  2019-01-01 04 A  1534.543857
# 4  2019-01-01 05 A  1649.868094

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15120 entries, 0 to 15119
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   일자|시간|구분  15120 non-null  object
#  1   공급량       15120 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 236.4+ KB

# %%
sub.to_csv("sub14_pycaret02.csv", index=False)
