# %% [markdown]
# # pycaret을 이용한 가스공급량 예측
# * 2019년 test 데이터 : '../data/test.csv'
# * 2013-2018년 가스공급량자료 : '../data/한국가스공사_시간별 공급량_20181231.csv'
# * 2013-2018년 기상청기온자료 : '../기상청기온자료/2013-2018년_기상청기온자료02.csv'
# * 사용 특성 : 'month', 'day', '시간', '구분', '기온','습도','기압'
# * log, poly 적용
# * top3 모델 결과 평균으로 제출

# %% [markdown]
# ## 데이터 가져오기
# * 2019년 test 데이터 : '../data/test.csv'
# * 2013-2018년 가스공급량자료 : '../data/한국가스공사_시간별 공급량_20181231.csv'
# * 2013-2018년 기상청기온자료 : '../기상청기온자료/2013-2018년_기상청기온자료02.csv'

# %%
import pandas as pd

# %% [markdown]
# #### 기온데이터

# %%
raw_temp_data = pd.read_csv('../기상청기온자료/2013-2018년_기상청기온자료02.csv')
raw_temp_data.head()
# Out:
#     지점             일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  \
# 0  108  2013-01-01 01    -8.5      NaN      4.0      50.0   57.0       1.8
# 1  108  2013-01-01 02    -8.4      NaN      4.0      70.0   60.0       2.0
# 2  108  2013-01-01 03    -8.1      NaN      3.4      70.0   58.0       1.9
# 3  108  2013-01-01 04    -8.2      NaN      3.8      70.0   58.0       1.9
# 4  108  2013-01-01 05    -8.2      NaN      4.4      70.0   61.0       2.0
#
#    이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  3시간신적설(cm)  \
# 0      -15.5     1010.0     1021.2     NaN        NaN     6.4         NaN
# 1      -14.7     1009.4     1020.6     NaN        NaN     6.4         NaN
# 2      -14.9     1009.2     1020.4     NaN        NaN     6.4         NaN
# 3      -15.0     1008.2     1019.4     NaN        NaN     6.4         NaN
# 4      -14.4     1007.3     1018.5     NaN        NaN     6.4         NaN
#
#    전운량(10분위)  중하층운량(10분위) 운형(운형약어)  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  \
# 0        NaN          NaN      NaN          NaN      NaN           NaN
# 1        NaN          NaN      NaN          NaN      NaN           NaN
# 2        6.0          6.0       Ac         35.0   2000.0          13.0
# 3        6.0          6.0       Ac         35.0   2000.0           NaN
# 4       10.0          5.0     ScAs         10.0   1000.0           NaN
#
#    현상번호(국내식)  지면온도(°C)  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# 0        NaN      -3.4          -2.9           -1.6           -0.5
# 1        NaN      -3.4          -3.0           -1.6           -0.5
# 2        NaN      -3.4          -3.0           -1.6           -0.5
# 3        NaN      -3.4          -2.9           -1.7           -0.5
# 4        5.0      -3.3          -2.9           -1.7           -0.5
#
#    30cm 지중온도(°C)
# 0            0.3
# 1            0.4
# 2            0.3
# 3            0.3
# 4            0.3

# %%
raw_temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52584 entries, 0 to 52583
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지점             52584 non-null  int64
#  1   일시             52584 non-null  object
#  2   기온(°C)         52584 non-null  float64
#  3   강수량(mm)        4944 non-null   float64
#  4   풍속(m/s)        52538 non-null  float64
#  5   풍향(16방위)       52538 non-null  float64
#  6   습도(%)          52584 non-null  float64
#  7   증기압(hPa)       52572 non-null  float64
#  8   이슬점온도(°C)      52572 non-null  float64
#  9   현지기압(hPa)      52584 non-null  float64
#  10  해면기압(hPa)      52580 non-null  float64
#  11  일조(hr)         28716 non-null  float64
#  12  일사(MJ/m2)      28529 non-null  float64
#  13  적설(cm)         2394 non-null   float64
#  14  3시간신적설(cm)     153 non-null    float64
#  15  전운량(10분위)      41808 non-null  float64
#  16  중하층운량(10분위)    45458 non-null  float64
#  17  운형(운형약어)       29442 non-null  object
#  18  최저운고(100m )    25026 non-null  float64
#  19  시정(10m)        48239 non-null  float64
#  20  지면상태(지면상태코드)   5116 non-null   float64
#  21  현상번호(국내식)      18860 non-null  float64
#  22  지면온도(°C)       52530 non-null  float64
#  23  5cm 지중온도(°C)   52527 non-null  float64
#  24  10cm 지중온도(°C)  52533 non-null  float64
#  25  20cm 지중온도(°C)  52513 non-null  float64
#  26  30cm 지중온도(°C)  52448 non-null  float64
# dtypes: float64(24), int64(1), object(2)
# memory usage: 10.8+ MB

# %%
temp_data = raw_temp_data[['일시', '기온(°C)', '습도(%)', '현지기압(hPa)']]
temp_data.head()
# Out:
#               일시  기온(°C)  습도(%)  현지기압(hPa)
# 0  2013-01-01 01    -8.5   57.0     1010.0
# 1  2013-01-01 02    -8.4   60.0     1009.4
# 2  2013-01-01 03    -8.1   58.0     1009.2
# 3  2013-01-01 04    -8.2   58.0     1008.2
# 4  2013-01-01 05    -8.2   61.0     1007.3

# %%
temp_data.columns = ['일시', '기온', '습도', '기압']
temp_data.head()
# Out:
#               일시   기온    습도      기압
# 0  2013-01-01 01 -8.5  57.0  1010.0
# 1  2013-01-01 02 -8.4  60.0  1009.4
# 2  2013-01-01 03 -8.1  58.0  1009.2
# 3  2013-01-01 04 -8.2  58.0  1008.2
# 4  2013-01-01 05 -8.2  61.0  1007.3

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52584 entries, 0 to 52583
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      52584 non-null  object
#  1   기온      52584 non-null  float64
#  2   습도      52584 non-null  float64
#  3   기압      52584 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 1.6+ MB

# %%
temp_data[['year', 'month', 'day', '시간']] = temp_data['일시'].str.split(r'-| ').tolist()
temp_data.head()
# Out:
#               일시   기온    습도      기압  year month day  시간
# 0  2013-01-01 01 -8.5  57.0  1010.0  2013    01  01  01
# 1  2013-01-01 02 -8.4  60.0  1009.4  2013    01  01  02
# 2  2013-01-01 03 -8.1  58.0  1009.2  2013    01  01  03
# 3  2013-01-01 04 -8.2  58.0  1008.2  2013    01  01  04
# 4  2013-01-01 05 -8.2  61.0  1007.3  2013    01  01  05

# %% [markdown]
# #### 2019년 데이터

# %%
test2019 = pd.read_csv('../data/test.csv')
test2019.head()
# Out:
#           일자|시간|구분
# 0  2019-01-01 01 A
# 1  2019-01-01 02 A
# 2  2019-01-01 03 A
# 3  2019-01-01 04 A
# 4  2019-01-01 05 A

# %%
test2019[['연월일', '시간', '구분']] = test2019['일자|시간|구분'].str.split(' ').tolist()
test2019.head()
# Out:
#           일자|시간|구분  year month day  시간 구분
# 0  2019-01-01 01 A  2019    01  01  01  A
# 1  2019-01-01 02 A  2019    01  01  02  A
# 2  2019-01-01 03 A  2019    01  01  03  A
# 3  2019-01-01 04 A  2019    01  01  04  A
# 4  2019-01-01 05 A  2019    01  01  05  A

# %%
# 구분 열을 숫자로 바꾸기
d_map = {}
for i, d in enumerate(test2019['구분'].unique()):
    d_map[d] = i
test2019['구분'] = test2019['구분'].map(d_map)
test2019.head()
# Out:
#           일자|시간|구분  year month day  시간  구분
# 0  2019-01-01 01 A  2019    01  01  01   0
# 1  2019-01-01 02 A  2019    01  01  02   0
# 2  2019-01-01 03 A  2019    01  01  03   0
# 3  2019-01-01 04 A  2019    01  01  04   0
# 4  2019-01-01 05 A  2019    01  01  05   0

# %%
# 연월일 열은 object형이므로 년, 월, 일로 나눈다.
test2019['연월일'] = pd.to_datetime(test2019['연월일'])
test2019['year'] = test2019['연월일'].dt.year
test2019['month'] = test2019['연월일'].dt.month
test2019['day'] = test2019['연월일'].dt.day
test2019['weekday'] = test2019['연월일'].dt.weekday
test2019.head()

# %% [markdown]
# #### 가스공급량 데이터

# %%
raw_gas_data = pd.read_csv('../data/한국가스공사_시간별 공급량_20181231.csv', encoding='cp949')
raw_gas_data.head()
# Out:
#           연월일  시간 구분       공급량
# 0  2013-01-01   1  A  2497.129
# 1  2013-01-01   2  A  2363.265
# 2  2013-01-01   3  A  2258.505
# 3  2013-01-01   4  A  2243.969
# 4  2013-01-01   5  A  2344.105

# %%
raw_gas_data['구분'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'G', 'H'], dtype=object)

# %%
# 구분 열을 숫자로 바꾸기
d_map = {}
for i, d in enumerate(raw_gas_data['구분'].unique()):
    d_map[d] = i
raw_gas_data['구분'] = raw_gas_data['구분'].map(d_map)
raw_gas_data.head()
# Out:
#           연월일  시간  구분       공급량
# 0  2013-01-01   1   0  2497.129
# 1  2013-01-01   2   0  2363.265
# 2  2013-01-01   3   0  2258.505
# 3  2013-01-01   4   0  2243.969
# 4  2013-01-01   5   0  2344.105

# %%
# 연월일 열은 object형이므로 년, 월, 일로 나눈다.
raw_gas_data['연월일'] = pd.to_datetime(raw_gas_data['연월일'])
raw_gas_data['year'] = raw_gas_data['연월일'].dt.year
raw_gas_data['month'] = raw_gas_data['연월일'].dt.month
raw_gas_data['day'] = raw_gas_data['연월일'].dt.day
raw_gas_data['weekday'] = raw_gas_data['연월일'].dt.weekday
raw_gas_data.head()
# Out:
#          연월일  시간  구분       공급량  year  month  day  weekday
# 0 2013-01-01   1   0  2497.129  2013      1    1        1
# 1 2013-01-01   2   0  2363.265  2013      1    1        1
# 2 2013-01-01   3   0  2258.505  2013      1    1        1
# 3 2013-01-01   4   0  2243.969  2013      1    1        1
# 4 2013-01-01   5   0  2344.105  2013      1    1        1

# %% [markdown]
# #### 2013-2018년 가스공급량과 기온 데이터 합치기

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52584 entries, 0 to 52583
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      52584 non-null  object
#  1   기온      52584 non-null  float64
#  2   습도      52584 non-null  float64
#  3   기압      52584 non-null  float64
#  4   year    52584 non-null  object
#  5   month   52584 non-null  object
#  6   day     52584 non-null  object
#  7   시간      52584 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 3.2+ MB

# %%
temp_data[['year','month','day','시간']] = temp_data[['year','month','day','시간']].astype(int)
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52584 entries, 0 to 52583
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      52584 non-null  object
#  1   기온      52584 non-null  float64
#  2   습도      52584 non-null  float64
#  3   기압      52584 non-null  float64
#  4   year    52584 non-null  int32
#  5   month   52584 non-null  int32
#  6   day     52584 non-null  int32
#  7   시간      52584 non-null  int32
# dtypes: float64(3), int32(4), object(1)
# memory usage: 2.4+ MB

# %%
raw_gas_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368088 entries, 0 to 368087
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   연월일      368088 non-null  datetime64[ns]
#  1   시간       368088 non-null  int64
#  2   구분       368088 non-null  int64
#  3   공급량      368088 non-null  float64
#  4   year     368088 non-null  int64
#  5   month    368088 non-null  int64
#  6   day      368088 non-null  int64
#  7   weekday  368088 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 22.5 MB

# %%
gas_temp = pd.merge(raw_gas_data, temp_data, on=['year', 'month', 'day', '시간'])
gas_temp.head()
# Out:
#          연월일  시간  구분       공급량  year  month  day  weekday             일시   기온  \
# 0 2013-01-01   1   0  2497.129  2013      1    1        1  2013-01-01 01 -8.5
# 1 2013-01-01   1   1  2169.093  2013      1    1        1  2013-01-01 01 -8.5
# 2 2013-01-01   1   2   226.178  2013      1    1        1  2013-01-01 01 -8.5
# 3 2013-01-01   1   3  1434.516  2013      1    1        1  2013-01-01 01 -8.5
# 4 2013-01-01   1   4  3272.837  2013      1    1        1  2013-01-01 01 -8.5
#
#      습도      기압
# 0  57.0  1010.0
# 1  57.0  1010.0
# 2  57.0  1010.0
# 3  57.0  1010.0
# 4  57.0  1010.0

# %%
# 필요없는 열 제거
gas_temp = gas_temp.drop(['연월일', '일시'], axis=1)
gas_temp.head()
# Out:
#    시간  구분       공급량  year  month  day  weekday   기온    습도      기압
# 0   1   0  2497.129  2013      1    1        1 -8.5  57.0  1010.0
# 1   1   1  2169.093  2013      1    1        1 -8.5  57.0  1010.0
# 2   1   2   226.178  2013      1    1        1 -8.5  57.0  1010.0
# 3   1   3  1434.516  2013      1    1        1 -8.5  57.0  1010.0
# 4   1   4  3272.837  2013      1    1        1 -8.5  57.0  1010.0

# %%
# 열 순서 정리
gas_temp = gas_temp[['year','month','day','weekday','시간','구분', '공급량', '기온', '습도','기압']]
gas_temp.head()
# Out:
#    year  month  day  weekday  시간  구분       공급량   기온    습도      기압
# 0  2013      1    1        1   1   0  2497.129 -8.5  57.0  1010.0
# 1  2013      1    1        1   1   1  2169.093 -8.5  57.0  1010.0
# 2  2013      1    1        1   1   2   226.178 -8.5  57.0  1010.0
# 3  2013      1    1        1   1   3  1434.516 -8.5  57.0  1010.0
# 4  2013      1    1        1   1   4  3272.837 -8.5  57.0  1010.0

# %% [markdown]
# ### 상관계수 확인

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import platform
from matplotlib import font_manager, rc

# %%
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")

# %%
plt.figure(figsize=(12,10))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
sns.heatmap(gas_temp[['year','month', 'day', '시간', '구분', '기온','습도','기압','공급량']].corr(), cmap='Blues', annot=True, fmt='.2f', cbar=False, annot_kws={"size": 20})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2019년 기온 예측하기

# %%
from pycaret.regression import *

# %%
# 학습 특성 : 'year','month', 'day', '시간', '구분','습도','기압'
# 타겟 특성 : '기온'
exp = setup(gas_temp, target='기온', ignore_features=['공급량'])
# Out:
# <style  type="text/css" >
# #T_9f337_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_9f337_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f337_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9f337_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_9f337_row0_col1" class="data row0 col1" >4577</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9f337_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_9f337_row1_col1" class="data row1 col1" >기온</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9f337_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_9f337_row2_col1" class="data row2 col1" >(368088, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9f337_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_9f337_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9f337_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_9f337_row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9f337_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_9f337_row5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9f337_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_9f337_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9f337_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_9f337_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9f337_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_9f337_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9f337_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_9f337_row9_col1" class="data row9 col1" >(257661, 36)</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9f337_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_9f337_row10_col1" class="data row10 col1" >(110427, 36)</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_9f337_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_9f337_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_9f337_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_9f337_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_9f337_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_9f337_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_9f337_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_9f337_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_9f337_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_9f337_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_9f337_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_9f337_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_9f337_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_9f337_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_9f337_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_9f337_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_9f337_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_9f337_row19_col1" class="data row19 col1" >5560</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_9f337_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_9f337_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_9f337_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_9f337_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_9f337_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_9f337_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_9f337_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_9f337_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9f337_level0_row24" class="row_heading level0 r

# %%
compare_models(sort='MAPE')
# Out:
# <style  type="text/css" >
#     #T_7720a_ th {
#           text-align: left;
#     }#T_7720a_row0_col0,#T_7720a_row0_col2,#T_7720a_row0_col3,#T_7720a_row0_col4,#T_7720a_row0_col5,#T_7720a_row1_col0,#T_7720a_row1_col1,#T_7720a_row1_col6,#T_7720a_row2_col0,#T_7720a_row2_col1,#T_7720a_row2_col2,#T_7720a_row2_col3,#T_7720a_row2_col4,#T_7720a_row2_col5,#T_7720a_row2_col6,#T_7720a_row3_col0,#T_7720a_row3_col1,#T_7720a_row3_col2,#T_7720a_row3_col3,#T_7720a_row3_col4,#T_7720a_row3_col5,#T_7720a_row3_col6,#T_7720a_row4_col0,#T_7720a_row4_col1,#T_7720a_row4_col2,#T_7720a_row4_col3,#T_7720a_row4_col4,#T_7720a_row4_col5,#T_7720a_row4_col6,#T_7720a_row5_col0,#T_7720a_row5_col1,#T_7720a_row5_col2,#T_7720a_row5_col3,#T_7720a_row5_col4,#T_7720a_row5_col5,#T_7720a_row5_col6,#T_7720a_row6_col0,#T_7720a_row6_col1,#T_7720a_row6_col2,#T_7720a_row6_col3,#T_7720a_row6_col4,#T_7720a_row6_col5,#T_7720a_row6_col6,#T_7720a_row7_col0,#T_7720a_row7_col1,#T_7720a_row7_col2,#T_7720a_row7_col3,#T_7720a_row7_col4,#T_7720a_row7_col5,#T_7720a_row7_col6,#T_7720a_row8_col0,#T_7720a_row8_col1,#T_7720a_row8_col2,#T_7720a_row8_col3,#T_7720a_row8_col4,#T_7720a_row8_col5,#T_7720a_row8_col6,#T_7720a_row9_col0,#T_7720a_row9_col1,#T_7720a_row9_col2,#T_7720a_row9_col3,#T_7720a_row9_col4,#T_7720a_row9_col5,#T_7720a_row9_col6,#T_7720a_row10_col0,#T_7720a_row10_col1,#T_7720a_row10_col2,#T_7720a_row10_col3,#T_7720a_row10_col4,#T_7720a_row10_col5,#T_7720a_row10_col6,#T_7720a_row11_col0,#T_7720a_row11_col1,#T_7720a_row11_col2,#T_7720a_row11_col3,#T_7720a_row11_col4,#T_7720a_row11_col5,#T_7720a_row11_col6,#T_7720a_row12_col0,#T_7720a_row12_col1,#T_7720a_row12_col2,#T_7720a_row12_col3,#T_7720a_row12_col4,#T_7720a_row12_col5,#T_7720a_row12_col6,#T_7720a_row13_col0,#T_7720a_row13_col1,#T_7720a_row13_col2,#T_7720a_row13_col3,#T_7720a_row13_col4,#T_7720a_row13_col5,#T_7720a_row13_col6,#T_7720a_row14_col0,#T_7720a_row14_col1,#T_7720a_row14_col2,#T_7720a_row14_col3,#T_7720a_row14_col4,#T_7720a_row14_col5,#T_7720a_row14_col6,#T_7720a_row15_col0,#T_7720a_row15_col1,#T_7720a_row15_col2,#T_7720a_row15_col3,#T_7720a_row15_col4,#T_7720a_row15_col5,#T_7720a_row15_col6,#T_7720a_row16_col0,#T_7720a_row16_col1,#T_7720a_row16_col2,#T_7720a_row16_col3,#T_7720a_row16_col4,#T_7720a_row16_col5,#T_7720a_row16_col6,#T_7720a_row17_col0,#T_7720a_row17_col1,#T_7720a_row17_col2,#T_7720a_row17_col3,#T_7720a_row17_col4,#T_7720a_row17_col5,#T_7720a_row17_col6,#T_7720a_row18_col0,#T_7720a_row18_col1,#T_7720a_row18_col2,#T_7720a_row18_col3,#T_7720a_row18_col4,#T_7720a_row18_col5,#T_7720a_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_7720a_row0_col1,#T_7720a_row0_col6,#T_7720a_row1_col2,#T_7720a_row1_col3,#T_7720a_row1_col4,#T_7720a_row1_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_7720a_row0_col7,#T_7720a_row1_col7,#T_7720a_row2_col7,#T_7720a_row3_col7,#T_7720a_row4_col7,#T_7720a_row5_col7,#T_7720a_row6_col7,#T_7720a_row7_col7,#T_7720a_row8_col7,#T_7720a_row10_col7,#T_7720a_row11_col7,#T_7720a_row12_col7,#T_7720a_row13_col7,#T_7720a_row14_col7,#T_7720a_row15_col7,#T_7720a_row16_col7,#T_7720a_row17_col7,#T_7720a_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_7720a_row9_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_7720a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7720a_level0_row0" class="row_heading level0 row0" >dt</th>
#                         <td id="T_7720a_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#                         <td id="T_7720a_row0_col1" class="data row0 col1" >0.0040</td>
#                         <td id="T_7720a_row0_col2" class="data row0 col2" >0.0087</td>
#                         <td id="T_7720a_row0_col3" class="data row0 col3" >0.0886</td>
#                         <td id="T_7720a_row0_col4" class="data row0 col4" >0.9999</td>
#                         <td id="T_7720a_row0_col5" class="data row0 col5" >0.0135</td>
#                         <td id="T_7720a_row0_col6" class="data row0 col6" >0.0011</td>
#                         <td id="T_7720a_row0_col7" class="data row0 col7" >1.2190</td>
#             </tr>
#             <tr>
#                         <th id="T_7720a_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_7720a_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_7720a_row1_col1" class="data row1 col1" >0.0084</td>
#                         <td id="T_7720a_row1_col2" class="data row1 col2" >0.0014</td>
#                         <td id="T_7720a_row1_col3" class="data row1 col3" >0.0377</td>
#                         <td id="T_7720a_row1_col4" class="data row1 col4" >1.0000</td>
#                         <td id="T_7720a_row1_col5" class="data row1 col5" >0.0061</td>
#                         <td id="T_7720a_row1_col6" class="data row1 col6" >0.0020</td>
#                         <td id="T_7720a_row1_col7" class="data row1 col7" >103.2020</td>
#             </tr>
#             <tr>
#                         <th id="T_7720a_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_7720a_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_7720a_row2_col1" class="data row2 col1" >0.0458</td>
#                         <td id="T_7720a_row2_col2" class="data row2 col2" >0.0123</td>
#                         <td id="T_7720a_row2_col3" class="data row2 col3" >0.1109</td>
#                         <td id="T_7720a_row2_col4" class="data row2 col4" >0.9999</td>
#                         <td id="T_7720a_row2_col5" class="data row2 col5" >0.0214</td>
#                         <td id="T_7720a_row2_col6" class="data row2 col6" >0.0122</td>
#                         <td id="T_7720a_row2_col7" class="data row2 col7" >74.6820</td>
#             </tr>
#             <tr>
#                         <th id="T_7720a_level0_row3" class="row_heading level0 row3" >knn</th>
#                         <td id="T_7720a_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#                         <td id="T_7720a_row3_col1" class="data row3 col1" >0.6077</td>
#                         <td id="T_7720a_row3_col2" class="data row3 col2" >2.3826</td>
#                         <td id="T_7720a_row3_col3" class="data row3 col3" >1.5434</td>
#                         <td id="T_7720a_row3_col4" class="data row3 col4" >0.9812</td>
#                         <td id="T_7720a_row3_col5" class="data row3 col5" >0.1995</td>
#                         <td id="T_7720a_row3_col6" class="data row3 col6" >0.1881</td>
#                         <td id="T_7720a_row3_col7" class="data row3 col7" >3.4970</td>
#             </tr>
#             <tr>
#                         <th id="T_7720a_level0_row4" class="row_heading level0 row4" >catboost</th>
#                         <td id="T_7720a_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#                         <td id="T_7720a_row4_col1" class="data row4 col1" >1.0416</td>
#                         <td id="T_7720a_row4_col2" class="data row4 col2" >1.8397</td>
#                         <td id="T_7720a_row4_col3" class="data row4 col3" >1.3563</td>
#                         <td id="T_7720a_row4_col4" class="data row4 col4" >0.9855</td>
#                         <td id="T
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=4577, splitter='best')

# %%
# 학습 특성 : 'month', 'day', '시간', '구분','습도','기압'
# 타겟 특성 : '기온'
exp = setup(gas_temp, target='기온', ignore_features=['공급량', 'year'])
# Out:
# <style  type="text/css" >
# #T_70ea2_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_70ea2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70ea2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_70ea2_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_70ea2_row0_col1" class="data row0 col1" >6930</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_70ea2_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_70ea2_row1_col1" class="data row1 col1" >기온</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_70ea2_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_70ea2_row2_col1" class="data row2 col1" >(368088, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_70ea2_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_70ea2_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_70ea2_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_70ea2_row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_70ea2_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_70ea2_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_70ea2_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_70ea2_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_70ea2_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_70ea2_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_70ea2_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_70ea2_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_70ea2_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_70ea2_row9_col1" class="data row9 col1" >(257661, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_70ea2_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_70ea2_row10_col1" class="data row10 col1" >(110427, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_70ea2_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_70ea2_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_70ea2_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_70ea2_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_70ea2_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_70ea2_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_70ea2_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_70ea2_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_70ea2_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_70ea2_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_70ea2_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_70ea2_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_70ea2_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_70ea2_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_70ea2_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_70ea2_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_70ea2_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_70ea2_row19_col1" class="data row19 col1" >099f</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_70ea2_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_70ea2_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_70ea2_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_70ea2_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_70ea2_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_70ea2_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_70ea2_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_70ea2_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_70ea2_level0_row24" class="row_heading level0 r

# %%
compare_models(sort='MAPE')
# Out:
# <style  type="text/css" >
#     #T_30f0e_ th {
#           text-align: left;
#     }#T_30f0e_row0_col0,#T_30f0e_row0_col2,#T_30f0e_row0_col3,#T_30f0e_row0_col4,#T_30f0e_row0_col5,#T_30f0e_row1_col0,#T_30f0e_row1_col1,#T_30f0e_row1_col6,#T_30f0e_row2_col0,#T_30f0e_row2_col1,#T_30f0e_row2_col2,#T_30f0e_row2_col3,#T_30f0e_row2_col4,#T_30f0e_row2_col5,#T_30f0e_row2_col6,#T_30f0e_row3_col0,#T_30f0e_row3_col1,#T_30f0e_row3_col2,#T_30f0e_row3_col3,#T_30f0e_row3_col4,#T_30f0e_row3_col5,#T_30f0e_row3_col6,#T_30f0e_row4_col0,#T_30f0e_row4_col1,#T_30f0e_row4_col2,#T_30f0e_row4_col3,#T_30f0e_row4_col4,#T_30f0e_row4_col5,#T_30f0e_row4_col6,#T_30f0e_row5_col0,#T_30f0e_row5_col1,#T_30f0e_row5_col2,#T_30f0e_row5_col3,#T_30f0e_row5_col4,#T_30f0e_row5_col5,#T_30f0e_row5_col6,#T_30f0e_row6_col0,#T_30f0e_row6_col1,#T_30f0e_row6_col2,#T_30f0e_row6_col3,#T_30f0e_row6_col4,#T_30f0e_row6_col5,#T_30f0e_row6_col6,#T_30f0e_row7_col0,#T_30f0e_row7_col1,#T_30f0e_row7_col2,#T_30f0e_row7_col3,#T_30f0e_row7_col4,#T_30f0e_row7_col5,#T_30f0e_row7_col6,#T_30f0e_row8_col0,#T_30f0e_row8_col1,#T_30f0e_row8_col2,#T_30f0e_row8_col3,#T_30f0e_row8_col4,#T_30f0e_row8_col5,#T_30f0e_row8_col6,#T_30f0e_row9_col0,#T_30f0e_row9_col1,#T_30f0e_row9_col2,#T_30f0e_row9_col3,#T_30f0e_row9_col4,#T_30f0e_row9_col5,#T_30f0e_row9_col6,#T_30f0e_row10_col0,#T_30f0e_row10_col1,#T_30f0e_row10_col2,#T_30f0e_row10_col3,#T_30f0e_row10_col4,#T_30f0e_row10_col5,#T_30f0e_row10_col6,#T_30f0e_row11_col0,#T_30f0e_row11_col1,#T_30f0e_row11_col2,#T_30f0e_row11_col3,#T_30f0e_row11_col4,#T_30f0e_row11_col5,#T_30f0e_row11_col6,#T_30f0e_row12_col0,#T_30f0e_row12_col1,#T_30f0e_row12_col2,#T_30f0e_row12_col3,#T_30f0e_row12_col4,#T_30f0e_row12_col5,#T_30f0e_row12_col6,#T_30f0e_row13_col0,#T_30f0e_row13_col1,#T_30f0e_row13_col2,#T_30f0e_row13_col3,#T_30f0e_row13_col4,#T_30f0e_row13_col5,#T_30f0e_row13_col6,#T_30f0e_row14_col0,#T_30f0e_row14_col1,#T_30f0e_row14_col2,#T_30f0e_row14_col3,#T_30f0e_row14_col4,#T_30f0e_row14_col5,#T_30f0e_row14_col6,#T_30f0e_row15_col0,#T_30f0e_row15_col1,#T_30f0e_row15_col2,#T_30f0e_row15_col3,#T_30f0e_row15_col4,#T_30f0e_row15_col5,#T_30f0e_row15_col6,#T_30f0e_row16_col0,#T_30f0e_row16_col1,#T_30f0e_row16_col2,#T_30f0e_row16_col3,#T_30f0e_row16_col4,#T_30f0e_row16_col5,#T_30f0e_row16_col6,#T_30f0e_row17_col0,#T_30f0e_row17_col1,#T_30f0e_row17_col2,#T_30f0e_row17_col3,#T_30f0e_row17_col4,#T_30f0e_row17_col5,#T_30f0e_row17_col6,#T_30f0e_row18_col0,#T_30f0e_row18_col1,#T_30f0e_row18_col2,#T_30f0e_row18_col3,#T_30f0e_row18_col4,#T_30f0e_row18_col5,#T_30f0e_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_30f0e_row0_col1,#T_30f0e_row0_col6,#T_30f0e_row1_col2,#T_30f0e_row1_col3,#T_30f0e_row1_col4,#T_30f0e_row1_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_30f0e_row0_col7,#T_30f0e_row1_col7,#T_30f0e_row2_col7,#T_30f0e_row3_col7,#T_30f0e_row4_col7,#T_30f0e_row5_col7,#T_30f0e_row6_col7,#T_30f0e_row7_col7,#T_30f0e_row8_col7,#T_30f0e_row9_col7,#T_30f0e_row11_col7,#T_30f0e_row12_col7,#T_30f0e_row13_col7,#T_30f0e_row14_col7,#T_30f0e_row15_col7,#T_30f0e_row16_col7,#T_30f0e_row17_col7,#T_30f0e_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_30f0e_row10_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_30f0e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30f0e_level0_row0" class="row_heading level0 row0" >dt</th>
#                         <td id="T_30f0e_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#                         <td id="T_30f0e_row0_col1" class="data row0 col1" >0.0052</td>
#                         <td id="T_30f0e_row0_col2" class="data row0 col2" >0.0148</td>
#                         <td id="T_30f0e_row0_col3" class="data row0 col3" >0.1190</td>
#                         <td id="T_30f0e_row0_col4" class="data row0 col4" >0.9999</td>
#                         <td id="T_30f0e_row0_col5" class="data row0 col5" >0.0169</td>
#                         <td id="T_30f0e_row0_col6" class="data row0 col6" >0.0013</td>
#                         <td id="T_30f0e_row0_col7" class="data row0 col7" >1.0620</td>
#             </tr>
#             <tr>
#                         <th id="T_30f0e_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_30f0e_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_30f0e_row1_col1" class="data row1 col1" >0.0187</td>
#                         <td id="T_30f0e_row1_col2" class="data row1 col2" >0.0052</td>
#                         <td id="T_30f0e_row1_col3" class="data row1 col3" >0.0717</td>
#                         <td id="T_30f0e_row1_col4" class="data row1 col4" >1.0000</td>
#                         <td id="T_30f0e_row1_col5" class="data row1 col5" >0.0127</td>
#                         <td id="T_30f0e_row1_col6" class="data row1 col6" >0.0047</td>
#                         <td id="T_30f0e_row1_col7" class="data row1 col7" >85.2940</td>
#             </tr>
#             <tr>
#                         <th id="T_30f0e_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_30f0e_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_30f0e_row2_col1" class="data row2 col1" >0.0613</td>
#                         <td id="T_30f0e_row2_col2" class="data row2 col2" >0.0249</td>
#                         <td id="T_30f0e_row2_col3" class="data row2 col3" >0.1577</td>
#                         <td id="T_30f0e_row2_col4" class="data row2 col4" >0.9998</td>
#                         <td id="T_30f0e_row2_col5" class="data row2 col5" >0.0299</td>
#                         <td id="T_30f0e_row2_col6" class="data row2 col6" >0.0160</td>
#                         <td id="T_30f0e_row2_col7" class="data row2 col7" >68.5130</td>
#             </tr>
#             <tr>
#                         <th id="T_30f0e_level0_row3" class="row_heading level0 row3" >knn</th>
#                         <td id="T_30f0e_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#                         <td id="T_30f0e_row3_col1" class="data row3 col1" >0.7236</td>
#                         <td id="T_30f0e_row3_col2" class="data row3 col2" >2.9128</td>
#                         <td id="T_30f0e_row3_col3" class="data row3 col3" >1.7065</td>
#                         <td id="T_30f0e_row3_col4" class="data row3 col4" >0.9770</td>
#                         <td id="T_30f0e_row3_col5" class="data row3 col5" >0.2212</td>
#                         <td id="T_30f0e_row3_col6" class="data row3 col6" >0.2174</td>
#                         <td id="T_30f0e_row3_col7" class="data row3 col7" >2.9190</td>
#             </tr>
#             <tr>
#                         <th id="T_30f0e_level0_row4" class="row_heading level0 row4" >catboost</th>
#                         <td id="T_30f0e_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#                         <td id="T_30f0e_row4_col1" class="data row4 col1" >1.4442</td>
#                         <td id="T_30f0e_row4_col2" class="data row4 col2" >3.5659</td>
#                         <td id="T_30f0e_row4_col3" class="data row4 col3" >1.8883</td>
#                         <td id="T_30f0e_row4_col4" class="data row4 col4" >0.9719</td>
#                         <td id="T_
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=6930, splitter='best')

# %%
models5 = compare_models(sort='MAPE', n_select=5, include=['rf','knn','catboost','xgboost','lightgbm'])
# Out:
# <style  type="text/css" >
#     #T_d41f3_ th {
#           text-align: left;
#     }#T_d41f3_row0_col0,#T_d41f3_row1_col0,#T_d41f3_row1_col1,#T_d41f3_row1_col2,#T_d41f3_row1_col3,#T_d41f3_row1_col4,#T_d41f3_row1_col5,#T_d41f3_row1_col6,#T_d41f3_row2_col0,#T_d41f3_row2_col1,#T_d41f3_row2_col2,#T_d41f3_row2_col3,#T_d41f3_row2_col4,#T_d41f3_row2_col5,#T_d41f3_row2_col6,#T_d41f3_row3_col0,#T_d41f3_row3_col1,#T_d41f3_row3_col2,#T_d41f3_row3_col3,#T_d41f3_row3_col4,#T_d41f3_row3_col5,#T_d41f3_row3_col6,#T_d41f3_row4_col0,#T_d41f3_row4_col1,#T_d41f3_row4_col2,#T_d41f3_row4_col3,#T_d41f3_row4_col4,#T_d41f3_row4_col5,#T_d41f3_row4_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_d41f3_row0_col1,#T_d41f3_row0_col2,#T_d41f3_row0_col3,#T_d41f3_row0_col4,#T_d41f3_row0_col5,#T_d41f3_row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_d41f3_row0_col7,#T_d41f3_row1_col7,#T_d41f3_row2_col7,#T_d41f3_row3_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_d41f3_row4_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_d41f3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d41f3_level0_row0" class="row_heading level0 row0" >rf</th>
#                         <td id="T_d41f3_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#                         <td id="T_d41f3_row0_col1" class="data row0 col1" >0.0613</td>
#                         <td id="T_d41f3_row0_col2" class="data row0 col2" >0.0249</td>
#                         <td id="T_d41f3_row0_col3" class="data row0 col3" >0.1577</td>
#                         <td id="T_d41f3_row0_col4" class="data row0 col4" >0.9998</td>
#                         <td id="T_d41f3_row0_col5" class="data row0 col5" >0.0299</td>
#                         <td id="T_d41f3_row0_col6" class="data row0 col6" >0.0160</td>
#                         <td id="T_d41f3_row0_col7" class="data row0 col7" >67.4790</td>
#             </tr>
#             <tr>
#                         <th id="T_d41f3_level0_row1" class="row_heading level0 row1" >knn</th>
#                         <td id="T_d41f3_row1_col0" class="data row1 col0" >K Neighbors Regressor</td>
#                         <td id="T_d41f3_row1_col1" class="data row1 col1" >0.7236</td>
#                         <td id="T_d41f3_row1_col2" class="data row1 col2" >2.9128</td>
#                         <td id="T_d41f3_row1_col3" class="data row1 col3" >1.7065</td>
#                         <td id="T_d41f3_row1_col4" class="data row1 col4" >0.9770</td>
#                         <td id="T_d41f3_row1_col5" class="data row1 col5" >0.2212</td>
#                         <td id="T_d41f3_row1_col6" class="data row1 col6" >0.2174</td>
#                         <td id="T_d41f3_row1_col7" class="data row1 col7" >2.7330</td>
#             </tr>
#             <tr>
#                         <th id="T_d41f3_level0_row2" class="row_heading level0 row2" >catboost</th>
#                         <td id="T_d41f3_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#                         <td id="T_d41f3_row2_col1" class="data row2 col1" >1.4442</td>
#                         <td id="T_d41f3_row2_col2" class="data row2 col2" >3.5659</td>
#                         <td id="T_d41f3_row2_col3" class="data row2 col3" >1.8883</td>
#                         <td id="T_d41f3_row2_col4" class="data row2 col4" >0.9719</td>
#                         <td id="T_d41f3_row2_col5" class="data row2 col5" >0.3108</td>
#                         <td id="T_d41f3_row2_col6" class="data row2 col6" >0.4041</td>
#                         <td id="T_d41f3_row2_col7" class="data row2 col7" >21.8060</td>
#             </tr>
#             <tr>
#                         <th id="T_d41f3_level0_row3" class="row_heading level0 row3" >xgboost</th>
#                         <td id="T_d41f3_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_d41f3_row3_col1" class="data row3 col1" >1.4895</td>
#                         <td id="T_d41f3_row3_col2" class="data row3 col2" >3.8900</td>
#                         <td id="T_d41f3_row3_col3" class="data row3 col3" >1.9722</td>
#                         <td id="T_d41f3_row3_col4" class="data row3 col4" >0.9693</td>
#                         <td id="T_d41f3_row3_col5" class="data row3 col5" >0.3182</td>
#                         <td id="T_d41f3_row3_col6" class="data row3 col6" >0.4176</td>
#                         <td id="T_d41f3_row3_col7" class="data row3 col7" >15.7150</td>
#             </tr>
#             <tr>
#                         <th id="T_d41f3_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#                         <td id="T_d41f3_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_d41f3_row4_col1" class="data row4 col1" >2.0187</td>
#                         <td id="T_d41f3_row4_col2" class="data row4 col2" >6.8183</td>
#                         <td id="T_d41f3_row4_col3" class="data row4 col3" >2.6111</td>
#                         <td id="T_d41f3_row4_col4" class="data row4 col4" >0.9463</td>
#                         <td id="T_d41f3_row4_col5" class="data row4 col5" >0.3986</td>
#                         <td id="T_d41f3_row4_col6" class="data row4 col6" >0.5618</td>
#                         <td id="T_d41f3_row4_col7" class="data row4 col7" >1.1870</td>
#             </tr>
#     </tbody></table>

# %%
for model in models5:
    print(model)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=6930, verbose=0, warm_start=False)
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                     weights='uniform')
# <catboost.core.CatBoostRegressor object at 0x000001A85D89F2E0>
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=-1,
#              num_parallel_tree=1, objective='reg:squarederror',
#              predictor='auto', random_state=6930, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='auto',
#              validate_parameters=1, verbosity=0)
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=6930, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
tuned_models5 = [tune_model(i) for i in models5]
tuned_models5
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   19:25:41
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .    Random Forest Regressor
# Empty DataFrame
# Columns: [MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.

# %%
# 너무 오래 걸려서 모델 3개로만 진행 : catboost, lightgbm, knn
