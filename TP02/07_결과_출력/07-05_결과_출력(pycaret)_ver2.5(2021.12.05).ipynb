# %% [markdown]
# # pycaret을 이용한 가스공급량 예측
# * 2019년 test 데이터 : '../data/test.csv'
# * 2019년 제출 파일 : '../data/sample_submission.csv'
# * 2013-2018년 가스공급량과 기온 자료 : '../2013-2018년_가스공급량_기온_습도_기압01.csv'
# * 특성
#     * 'month', 'weekay', '시간'으로 기온 예측
#     * 기온, 기압, 습도 순서로 예측
#     * 각 특성 예측 마다 앞에서 예측한 특성 활용
#     * 공급량 예측(7개) : 'month', 'weekday', '시간', '구분', '기온', '기압', '습도'
# * 공급량 log적용
# * top3 모델 블랜드
# * 튜닝X, finalize_model X
# * 구분별 훈련/예측
# * 이상치 제거(outliers_threshold=0.1)

# %%
# 제출 파일명 : sub34_pycaret22(ver2.5).csv
# 최고점 파일과 비교 점수(NMAE/R2) : 0.02539 / 0.96779
# 제출 점수 : X

# %% [markdown]
# ## 데이터 가져오기
# * 2019년 test 데이터 : '../data/test.csv'
# * 2019년 제출 파일 : '../data/sample_submission.csv'
# * 2013-2018년 가스공급량과 기온 자료 : '../2013-2018년_가스공급량_기온_습도_기압01.csv'

# %%
from pycaret.regression import *

# %%
import time
import datetime
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### 2013-2018년 가스공급량과 기온, 기압, 습도 자료

# %%
total = pd.read_csv('../2013-2018년_가스공급량_기온_습도_기압01.csv')
total.head()
# Out:
#           연월일  year  month  day  weekday  시간  구분       공급량   기온    습도      기압
# 0  2013-01-01  2013      1    1        1   1   0  2497.129 -8.5  57.0  1010.0
# 1  2013-01-01  2013      1    1        1   1   1  2169.093 -8.5  57.0  1010.0
# 2  2013-01-01  2013      1    1        1   1   2   226.178 -8.5  57.0  1010.0
# 3  2013-01-01  2013      1    1        1   1   3  1434.516 -8.5  57.0  1010.0
# 4  2013-01-01  2013      1    1        1   1   4  3272.837 -8.5  57.0  1010.0

# %% [markdown]
# ### 2019년 테스트 데이터

# %%
test2019 = pd.read_csv('../data/test.csv')
test2019.head()
# Out:
#           일자|시간|구분
# 0  2019-01-01 01 A
# 1  2019-01-01 02 A
# 2  2019-01-01 03 A
# 3  2019-01-01 04 A
# 4  2019-01-01 05 A

# %%
test2019[['연월일', '시간', '구분']] = test2019['일자|시간|구분'].str.split(' ').tolist()
test2019.head()
# Out:
#           일자|시간|구분         연월일  시간 구분
# 0  2019-01-01 01 A  2019-01-01  01  A
# 1  2019-01-01 02 A  2019-01-01  02  A
# 2  2019-01-01 03 A  2019-01-01  03  A
# 3  2019-01-01 04 A  2019-01-01  04  A
# 4  2019-01-01 05 A  2019-01-01  05  A

# %%
# 구분 열을 숫자로 바꾸기
d_map = {}
for i, d in enumerate(test2019['구분'].unique()):
    d_map[d] = i
test2019['구분'] = test2019['구분'].map(d_map)
test2019.head()
# Out:
#           일자|시간|구분         연월일  시간  구분
# 0  2019-01-01 01 A  2019-01-01  01   0
# 1  2019-01-01 02 A  2019-01-01  02   0
# 2  2019-01-01 03 A  2019-01-01  03   0
# 3  2019-01-01 04 A  2019-01-01  04   0
# 4  2019-01-01 05 A  2019-01-01  05   0

# %%
# 연월일 열은 object형이므로 년, 월, 일로 나눈다.
test2019['연월일'] = pd.to_datetime(test2019['연월일'])
test2019['year'] = test2019['연월일'].dt.year
test2019['month'] = test2019['연월일'].dt.month
test2019['day'] = test2019['연월일'].dt.day
test2019['weekday'] = test2019['연월일'].dt.weekday
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1

# %% [markdown]
# ## 2019년 기온 훈련/예측

# %%
start = time.time()

# 학습 특성 : 'month', 'weekday', '시간'
# 타겟 특성 : '기온'
test_col = ['month', 'weekday', '시간']
target_col = ['기온']
train_col = test_col + target_col

temp_train = total[train_col]
temp_test = test2019[test_col]

# pycaret 설정
exp = setup(temp_train, target=target_col[0], session_id=0, silent=True, fold=7, fold_shuffle=True, verbose=False)

# 모델 생성(lgbm, cat, xgb)
top3_models = compare_models(sort='MAPE', n_select=3)

end = time.time()
sec = end - start
result = datetime.timedelta(seconds=sec)
print(str(result).split('.')[0])
# Out:
# <style  type="text/css" >
#     #T_a2ed9_ th {
#           text-align: left;
#     }#T_a2ed9_row0_col0,#T_a2ed9_row1_col0,#T_a2ed9_row1_col1,#T_a2ed9_row1_col2,#T_a2ed9_row1_col3,#T_a2ed9_row1_col4,#T_a2ed9_row1_col5,#T_a2ed9_row1_col6,#T_a2ed9_row2_col0,#T_a2ed9_row2_col1,#T_a2ed9_row2_col2,#T_a2ed9_row2_col3,#T_a2ed9_row2_col4,#T_a2ed9_row2_col5,#T_a2ed9_row2_col6,#T_a2ed9_row3_col0,#T_a2ed9_row3_col1,#T_a2ed9_row3_col2,#T_a2ed9_row3_col3,#T_a2ed9_row3_col4,#T_a2ed9_row3_col5,#T_a2ed9_row3_col6,#T_a2ed9_row4_col0,#T_a2ed9_row4_col1,#T_a2ed9_row4_col2,#T_a2ed9_row4_col3,#T_a2ed9_row4_col4,#T_a2ed9_row4_col5,#T_a2ed9_row4_col6,#T_a2ed9_row5_col0,#T_a2ed9_row5_col1,#T_a2ed9_row5_col2,#T_a2ed9_row5_col3,#T_a2ed9_row5_col4,#T_a2ed9_row5_col5,#T_a2ed9_row5_col6,#T_a2ed9_row6_col0,#T_a2ed9_row6_col1,#T_a2ed9_row6_col2,#T_a2ed9_row6_col3,#T_a2ed9_row6_col4,#T_a2ed9_row6_col5,#T_a2ed9_row6_col6,#T_a2ed9_row7_col0,#T_a2ed9_row7_col1,#T_a2ed9_row7_col2,#T_a2ed9_row7_col3,#T_a2ed9_row7_col4,#T_a2ed9_row7_col5,#T_a2ed9_row7_col6,#T_a2ed9_row8_col0,#T_a2ed9_row8_col1,#T_a2ed9_row8_col2,#T_a2ed9_row8_col3,#T_a2ed9_row8_col4,#T_a2ed9_row8_col5,#T_a2ed9_row8_col6,#T_a2ed9_row9_col0,#T_a2ed9_row9_col1,#T_a2ed9_row9_col2,#T_a2ed9_row9_col3,#T_a2ed9_row9_col4,#T_a2ed9_row9_col5,#T_a2ed9_row9_col6,#T_a2ed9_row10_col0,#T_a2ed9_row10_col1,#T_a2ed9_row10_col2,#T_a2ed9_row10_col3,#T_a2ed9_row10_col4,#T_a2ed9_row10_col5,#T_a2ed9_row10_col6,#T_a2ed9_row11_col0,#T_a2ed9_row11_col1,#T_a2ed9_row11_col2,#T_a2ed9_row11_col3,#T_a2ed9_row11_col4,#T_a2ed9_row11_col5,#T_a2ed9_row11_col6,#T_a2ed9_row12_col0,#T_a2ed9_row12_col1,#T_a2ed9_row12_col2,#T_a2ed9_row12_col3,#T_a2ed9_row12_col4,#T_a2ed9_row12_col5,#T_a2ed9_row12_col6,#T_a2ed9_row13_col0,#T_a2ed9_row13_col1,#T_a2ed9_row13_col2,#T_a2ed9_row13_col3,#T_a2ed9_row13_col4,#T_a2ed9_row13_col5,#T_a2ed9_row13_col6,#T_a2ed9_row14_col0,#T_a2ed9_row14_col1,#T_a2ed9_row14_col2,#T_a2ed9_row14_col3,#T_a2ed9_row14_col4,#T_a2ed9_row14_col5,#T_a2ed9_row14_col6,#T_a2ed9_row15_col0,#T_a2ed9_row15_col1,#T_a2ed9_row15_col2,#T_a2ed9_row15_col3,#T_a2ed9_row15_col4,#T_a2ed9_row15_col5,#T_a2ed9_row15_col6,#T_a2ed9_row16_col0,#T_a2ed9_row16_col1,#T_a2ed9_row16_col2,#T_a2ed9_row16_col3,#T_a2ed9_row16_col4,#T_a2ed9_row16_col5,#T_a2ed9_row16_col6,#T_a2ed9_row17_col0,#T_a2ed9_row17_col1,#T_a2ed9_row17_col2,#T_a2ed9_row17_col3,#T_a2ed9_row17_col4,#T_a2ed9_row17_col5,#T_a2ed9_row17_col6,#T_a2ed9_row18_col0,#T_a2ed9_row18_col1,#T_a2ed9_row18_col2,#T_a2ed9_row18_col3,#T_a2ed9_row18_col4,#T_a2ed9_row18_col5,#T_a2ed9_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_a2ed9_row0_col1,#T_a2ed9_row0_col2,#T_a2ed9_row0_col3,#T_a2ed9_row0_col4,#T_a2ed9_row0_col5,#T_a2ed9_row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_a2ed9_row0_col7,#T_a2ed9_row1_col7,#T_a2ed9_row2_col7,#T_a2ed9_row3_col7,#T_a2ed9_row4_col7,#T_a2ed9_row5_col7,#T_a2ed9_row6_col7,#T_a2ed9_row7_col7,#T_a2ed9_row8_col7,#T_a2ed9_row9_col7,#T_a2ed9_row10_col7,#T_a2ed9_row11_col7,#T_a2ed9_row12_col7,#T_a2ed9_row13_col7,#T_a2ed9_row14_col7,#T_a2ed9_row16_col7,#T_a2ed9_row17_col7,#T_a2ed9_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_a2ed9_row15_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_a2ed9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2ed9_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#                         <td id="T_a2ed9_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_a2ed9_row0_col1" class="data row0 col1" >2.9867</td>
#                         <td id="T_a2ed9_row0_col2" class="data row0 col2" >14.8477</td>
#                         <td id="T_a2ed9_row0_col3" class="data row0 col3" >3.8532</td>
#                         <td id="T_a2ed9_row0_col4" class="data row0 col4" >0.8831</td>
#                         <td id="T_a2ed9_row0_col5" class="data row0 col5" >0.5169</td>
#                         <td id="T_a2ed9_row0_col6" class="data row0 col6" >0.8000</td>
#                         <td id="T_a2ed9_row0_col7" class="data row0 col7" >1.2314</td>
#             </tr>
#             <tr>
#                         <th id="T_a2ed9_level0_row1" class="row_heading level0 row1" >catboost</th>
#                         <td id="T_a2ed9_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#                         <td id="T_a2ed9_row1_col1" class="data row1 col1" >2.9891</td>
#                         <td id="T_a2ed9_row1_col2" class="data row1 col2" >14.8784</td>
#                         <td id="T_a2ed9_row1_col3" class="data row1 col3" >3.8572</td>
#                         <td id="T_a2ed9_row1_col4" class="data row1 col4" >0.8829</td>
#                         <td id="T_a2ed9_row1_col5" class="data row1 col5" >0.5191</td>
#                         <td id="T_a2ed9_row1_col6" class="data row1 col6" >0.8015</td>
#                         <td id="T_a2ed9_row1_col7" class="data row1 col7" >20.5157</td>
#             </tr>
#             <tr>
#                         <th id="T_a2ed9_level0_row2" class="row_heading level0 row2" >xgboost</th>
#                         <td id="T_a2ed9_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_a2ed9_row2_col1" class="data row2 col1" >2.9924</td>
#                         <td id="T_a2ed9_row2_col2" class="data row2 col2" >14.9107</td>
#                         <td id="T_a2ed9_row2_col3" class="data row2 col3" >3.8614</td>
#                         <td id="T_a2ed9_row2_col4" class="data row2 col4" >0.8826</td>
#                         <td id="T_a2ed9_row2_col5" class="data row2 col5" >0.5186</td>
#                         <td id="T_a2ed9_row2_col6" class="data row2 col6" >0.8024</td>
#                         <td id="T_a2ed9_row2_col7" class="data row2 col7" >11.0229</td>
#             </tr>
#             <tr>
#                         <th id="T_a2ed9_level0_row3" class="row_heading level0 row3" >et</th>
#                         <td id="T_a2ed9_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#                         <td id="T_a2ed9_row3_col1" class="data row3 col1" >2.9998</td>
#                         <td id="T_a2ed9_row3_col2" class="data row3 col2" >14.9850</td>
#                         <td id="T_a2ed9_row3_col3" class="data row3 col3" >3.8710</td>
#                         <td id="T_a2ed9_row3_col4" class="data row3 col4" >0.8820</td>
#                         <td id="T_a2ed9_row3_col5" class="data row3 col5" >0.5199</td>
#                         <td id="T_a2ed9_row3_col6" class="data row3 col6" >0.8038</td>
#                         <td id="T_a2ed9_row3_col7" class="data row3 col7" >33.1100</td>
#             </tr>
#             <tr>
#                         <th id="T_a2ed9_level0_row4" class="row_heading level0 row4" >dt</th>
#                         <td id="T_a2ed9_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#                         <td id="T_a2ed9_row4_col1" class="data row4 col1" >2.9998</td>
#                         <td id="T_a2ed9_row4_col2" class="data row4 col2" >14.9850</td>
#                         <td id="T_a2ed9_row4_col3" class="data row4 col3" >3.8710</td>
#                         <td id="T_a2ed9_row4_col4" class="data row4 col4" >0.8820</td>
# 0:16:25

# %%
start = time.time()

# 블랜드 모델
blended_top3_models = blend_models(estimator_list=top3_models, optimize='MAPE')

# 기온 예측
temp2019_pred_top3 = predict_model(blended_top3_models, data=temp_test)

# 2019년 예측 기온 열 추가
test2019[target_col[0]] = temp2019_pred_top3['Label']

end = time.time()
sec = end - start
result = datetime.timedelta(seconds=sec)
print(str(result).split('.')[0])
# Out:
# <style  type="text/css" >
# #T_39d0c_row7_col0,#T_39d0c_row7_col1,#T_39d0c_row7_col2,#T_39d0c_row7_col3,#T_39d0c_row7_col4,#T_39d0c_row7_col5{
#             background:  yellow;
#         }</style><table id="T_39d0c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39d0c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_39d0c_row0_col0" class="data row0 col0" >2.9731</td>
#                         <td id="T_39d0c_row0_col1" class="data row0 col1" >14.7102</td>
#                         <td id="T_39d0c_row0_col2" class="data row0 col2" >3.8354</td>
#                         <td id="T_39d0c_row0_col3" class="data row0 col3" >0.8833</td>
#                         <td id="T_39d0c_row0_col4" class="data row0 col4" >0.5121</td>
#                         <td id="T_39d0c_row0_col5" class="data row0 col5" >0.8168</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_39d0c_row1_col0" class="data row1 col0" >2.9872</td>
#                         <td id="T_39d0c_row1_col1" class="data row1 col1" >14.8870</td>
#                         <td id="T_39d0c_row1_col2" class="data row1 col2" >3.8584</td>
#                         <td id="T_39d0c_row1_col3" class="data row1 col3" >0.8820</td>
#                         <td id="T_39d0c_row1_col4" class="data row1 col4" >0.5156</td>
#                         <td id="T_39d0c_row1_col5" class="data row1 col5" >0.7825</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_39d0c_row2_col0" class="data row2 col0" >2.9907</td>
#                         <td id="T_39d0c_row2_col1" class="data row2 col1" >14.9187</td>
#                         <td id="T_39d0c_row2_col2" class="data row2 col2" >3.8625</td>
#                         <td id="T_39d0c_row2_col3" class="data row2 col3" >0.8829</td>
#                         <td id="T_39d0c_row2_col4" class="data row2 col4" >0.5202</td>
#                         <td id="T_39d0c_row2_col5" class="data row2 col5" >0.8020</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_39d0c_row3_col0" class="data row3 col0" >2.9861</td>
#                         <td id="T_39d0c_row3_col1" class="data row3 col1" >14.9033</td>
#                         <td id="T_39d0c_row3_col2" class="data row3 col2" >3.8605</td>
#                         <td id="T_39d0c_row3_col3" class="data row3 col3" >0.8824</td>
#                         <td id="T_39d0c_row3_col4" class="data row3 col4" >0.5186</td>
#                         <td id="T_39d0c_row3_col5" class="data row3 col5" >0.8190</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_39d0c_row4_col0" class="data row4 col0" >3.0061</td>
#                         <td id="T_39d0c_row4_col1" class="data row4 col1" >15.0172</td>
#                         <td id="T_39d0c_row4_col2" class="data row4 col2" >3.8752</td>
#                         <td id="T_39d0c_row4_col3" class="data row4 col3" >0.8828</td>
#                         <td id="T_39d0c_row4_col4" class="data row4 col4" >0.5222</td>
#                         <td id="T_39d0c_row4_col5" class="data row4 col5" >0.8082</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_39d0c_row5_col0" class="data row5 col0" >2.9707</td>
#                         <td id="T_39d0c_row5_col1" class="data row5 col1" >14.6959</td>
#                         <td id="T_39d0c_row5_col2" class="data row5 col2" >3.8335</td>
#                         <td id="T_39d0c_row5_col3" class="data row5 col3" >0.8847</td>
#                         <td id="T_39d0c_row5_col4" class="data row5 col4" >0.5184</td>
#                         <td id="T_39d0c_row5_col5" class="data row5 col5" >0.7846</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_39d0c_row6_col0" class="data row6 col0" >3.0057</td>
#                         <td id="T_39d0c_row6_col1" class="data row6 col1" >14.9620</td>
#                         <td id="T_39d0c_row6_col2" class="data row6 col2" >3.8681</td>
#                         <td id="T_39d0c_row6_col3" class="data row6 col3" >0.8825</td>
#                         <td id="T_39d0c_row6_col4" class="data row6 col4" >0.5202</td>
#                         <td id="T_39d0c_row6_col5" class="data row6 col5" >0.7945</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row7" class="row_heading level0 row7" >Mean</th>
#                         <td id="T_39d0c_row7_col0" class="data row7 col0" >2.9885</td>
#                         <td id="T_39d0c_row7_col1" class="data row7 col1" >14.8706</td>
#                         <td id="T_39d0c_row7_col2" class="data row7 col2" >3.8562</td>
#                         <td id="T_39d0c_row7_col3" class="data row7 col3" >0.8829</td>
#                         <td id="T_39d0c_row7_col4" class="data row7 col4" >0.5182</td>
#                         <td id="T_39d0c_row7_col5" class="data row7 col5" >0.8011</td>
#             </tr>
#             <tr>
#                         <th id="T_39d0c_level0_row8" class="row_heading level0 row8" >SD</th>
#                         <td id="T_39d0c_row8_col0" class="data row8 col0" >0.0129</td>
#                         <td id="T_39d0c_row8_col1" class="data row8 col1" >0.1132</td>
#                         <td id="T_39d0c_row8_col2" class="data row8 col2" >0.0147</td>
#                         <td id="T_39d0c_row8_col3" class="data row8 col3" >0.0008</td>
#                         <td id="T_39d0c_row8_col4" class="data row8 col4" >0.0031</td>
#                         <td id="T_39d0c_row8_col5" class="data row8 col5" >0.0135</td>
#             </tr>
#     </tbody></table>
# 0:04:01

# %%
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday        기온
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1 -3.894176
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1 -4.363952
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1 -4.476645
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1 -4.922204
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1 -5.048251

# %% [markdown]
# ## 2019년 기압 훈련/예측

# %%
start = time.time()

# 학습 특성 : 'month', 'weekday', '시간', '기온'
# 타겟 특성 : '기압'
test_col = ['month', 'weekday', '시간', '기온']
target_col = ['기압']
train_col = test_col + target_col

temp_train = total[train_col]
temp_test = test2019[test_col]

# pycaret 설정
exp = setup(temp_train, target=target_col[0], session_id=0, silent=True, fold=7, fold_shuffle=True, verbose=False)

# 모델 생성(dt, et, rf)
top3_models = compare_models(sort='MAPE', n_select=3)

end = time.time()
sec = end - start
result = datetime.timedelta(seconds=sec)
print(str(result).split('.')[0])
# Out:
# <style  type="text/css" >
#     #T_80e8e_ th {
#           text-align: left;
#     }#T_80e8e_row0_col0,#T_80e8e_row0_col1,#T_80e8e_row0_col2,#T_80e8e_row0_col3,#T_80e8e_row0_col4,#T_80e8e_row1_col0,#T_80e8e_row2_col0,#T_80e8e_row2_col1,#T_80e8e_row2_col2,#T_80e8e_row2_col3,#T_80e8e_row2_col4,#T_80e8e_row2_col6,#T_80e8e_row3_col0,#T_80e8e_row3_col1,#T_80e8e_row3_col2,#T_80e8e_row3_col3,#T_80e8e_row3_col4,#T_80e8e_row3_col5,#T_80e8e_row3_col6,#T_80e8e_row4_col0,#T_80e8e_row4_col1,#T_80e8e_row4_col2,#T_80e8e_row4_col3,#T_80e8e_row4_col4,#T_80e8e_row4_col5,#T_80e8e_row4_col6,#T_80e8e_row5_col0,#T_80e8e_row5_col1,#T_80e8e_row5_col2,#T_80e8e_row5_col3,#T_80e8e_row5_col4,#T_80e8e_row5_col5,#T_80e8e_row5_col6,#T_80e8e_row6_col0,#T_80e8e_row6_col1,#T_80e8e_row6_col2,#T_80e8e_row6_col3,#T_80e8e_row6_col4,#T_80e8e_row6_col5,#T_80e8e_row6_col6,#T_80e8e_row7_col0,#T_80e8e_row7_col1,#T_80e8e_row7_col2,#T_80e8e_row7_col3,#T_80e8e_row7_col4,#T_80e8e_row7_col5,#T_80e8e_row7_col6,#T_80e8e_row8_col0,#T_80e8e_row8_col1,#T_80e8e_row8_col2,#T_80e8e_row8_col3,#T_80e8e_row8_col4,#T_80e8e_row8_col5,#T_80e8e_row8_col6,#T_80e8e_row9_col0,#T_80e8e_row9_col1,#T_80e8e_row9_col2,#T_80e8e_row9_col3,#T_80e8e_row9_col4,#T_80e8e_row9_col5,#T_80e8e_row9_col6,#T_80e8e_row10_col0,#T_80e8e_row10_col1,#T_80e8e_row10_col2,#T_80e8e_row10_col3,#T_80e8e_row10_col4,#T_80e8e_row10_col5,#T_80e8e_row10_col6,#T_80e8e_row11_col0,#T_80e8e_row11_col1,#T_80e8e_row11_col2,#T_80e8e_row11_col3,#T_80e8e_row11_col4,#T_80e8e_row11_col5,#T_80e8e_row11_col6,#T_80e8e_row12_col0,#T_80e8e_row12_col1,#T_80e8e_row12_col2,#T_80e8e_row12_col3,#T_80e8e_row12_col4,#T_80e8e_row12_col5,#T_80e8e_row12_col6,#T_80e8e_row13_col0,#T_80e8e_row13_col1,#T_80e8e_row13_col2,#T_80e8e_row13_col3,#T_80e8e_row13_col4,#T_80e8e_row13_col5,#T_80e8e_row13_col6,#T_80e8e_row14_col0,#T_80e8e_row14_col1,#T_80e8e_row14_col2,#T_80e8e_row14_col3,#T_80e8e_row14_col4,#T_80e8e_row14_col5,#T_80e8e_row14_col6,#T_80e8e_row15_col0,#T_80e8e_row15_col1,#T_80e8e_row15_col2,#T_80e8e_row15_col3,#T_80e8e_row15_col4,#T_80e8e_row15_col5,#T_80e8e_row15_col6,#T_80e8e_row16_col0,#T_80e8e_row16_col1,#T_80e8e_row16_col2,#T_80e8e_row16_col3,#T_80e8e_row16_col4,#T_80e8e_row16_col5,#T_80e8e_row16_col6,#T_80e8e_row17_col0,#T_80e8e_row17_col1,#T_80e8e_row17_col2,#T_80e8e_row17_col3,#T_80e8e_row17_col4,#T_80e8e_row17_col5,#T_80e8e_row17_col6,#T_80e8e_row18_col0,#T_80e8e_row18_col1,#T_80e8e_row18_col2,#T_80e8e_row18_col3,#T_80e8e_row18_col4,#T_80e8e_row18_col5,#T_80e8e_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_80e8e_row0_col5,#T_80e8e_row0_col6,#T_80e8e_row1_col1,#T_80e8e_row1_col2,#T_80e8e_row1_col3,#T_80e8e_row1_col4,#T_80e8e_row1_col5,#T_80e8e_row1_col6,#T_80e8e_row2_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_80e8e_row0_col7,#T_80e8e_row1_col7,#T_80e8e_row2_col7,#T_80e8e_row3_col7,#T_80e8e_row4_col7,#T_80e8e_row5_col7,#T_80e8e_row6_col7,#T_80e8e_row7_col7,#T_80e8e_row8_col7,#T_80e8e_row10_col7,#T_80e8e_row11_col7,#T_80e8e_row12_col7,#T_80e8e_row13_col7,#T_80e8e_row14_col7,#T_80e8e_row15_col7,#T_80e8e_row16_col7,#T_80e8e_row17_col7,#T_80e8e_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_80e8e_row9_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_80e8e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80e8e_level0_row0" class="row_heading level0 row0" >dt</th>
#                         <td id="T_80e8e_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#                         <td id="T_80e8e_row0_col1" class="data row0 col1" >0.5140</td>
#                         <td id="T_80e8e_row0_col2" class="data row0 col2" >2.4898</td>
#                         <td id="T_80e8e_row0_col3" class="data row0 col3" >1.5778</td>
#                         <td id="T_80e8e_row0_col4" class="data row0 col4" >0.9617</td>
#                         <td id="T_80e8e_row0_col5" class="data row0 col5" >0.0016</td>
#                         <td id="T_80e8e_row0_col6" class="data row0 col6" >0.0005</td>
#                         <td id="T_80e8e_row0_col7" class="data row0 col7" >0.6014</td>
#             </tr>
#             <tr>
#                         <th id="T_80e8e_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_80e8e_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_80e8e_row1_col1" class="data row1 col1" >0.5115</td>
#                         <td id="T_80e8e_row1_col2" class="data row1 col2" >2.4450</td>
#                         <td id="T_80e8e_row1_col3" class="data row1 col3" >1.5636</td>
#                         <td id="T_80e8e_row1_col4" class="data row1 col4" >0.9624</td>
#                         <td id="T_80e8e_row1_col5" class="data row1 col5" >0.0016</td>
#                         <td id="T_80e8e_row1_col6" class="data row1 col6" >0.0005</td>
#                         <td id="T_80e8e_row1_col7" class="data row1 col7" >42.8614</td>
#             </tr>
#             <tr>
#                         <th id="T_80e8e_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_80e8e_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_80e8e_row2_col1" class="data row2 col1" >0.6781</td>
#                         <td id="T_80e8e_row2_col2" class="data row2 col2" >2.6323</td>
#                         <td id="T_80e8e_row2_col3" class="data row2 col3" >1.6224</td>
#                         <td id="T_80e8e_row2_col4" class="data row2 col4" >0.9595</td>
#                         <td id="T_80e8e_row2_col5" class="data row2 col5" >0.0016</td>
#                         <td id="T_80e8e_row2_col6" class="data row2 col6" >0.0007</td>
#                         <td id="T_80e8e_row2_col7" class="data row2 col7" >37.6586</td>
#             </tr>
#             <tr>
#                         <th id="T_80e8e_level0_row3" class="row_heading level0 row3" >knn</th>
#                         <td id="T_80e8e_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#                         <td id="T_80e8e_row3_col1" class="data row3 col1" >1.6070</td>
#                         <td id="T_80e8e_row3_col2" class="data row3 col2" >6.6596</td>
#                         <td id="T_80e8e_row3_col3" class="data row3 col3" >2.5806</td>
#                         <td id="T_80e8e_row3_col4" class="data row3 col4" >0.8975</td>
#                         <td id="T_80e8e_row3_col5" class="data row3 col5" >0.0026</td>
#                         <td id="T_80e8e_row3_col6" class="data row3 col6" >0.0016</td>
#                         <td id="T_80e8e_row3_col7" class="data row3 col7" >2.8343</td>
#             </tr>
#             <tr>
#                         <th id="T_80e8e_level0_row4" class="row_heading level0 row4" >catboost</th>
#                         <td id="T_80e8e_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#                         <td id="T_80e8e_row4_col1" class="data row4 col1" >3.2454</td>
#                         <td id="T_80e8e_row4_col2" class="data row4 col2" >17.6192</td>
#                         <td id="T_80e8e_row4_col3" class="data row4 col3" >4.1975</td>
#                         <td id="T_80e8e_row4_col4" class="data row4 col4" >0.7288</td>
#                         <td id="T
# 0:18:14

# %%
start = time.time()

# 블랜드 모델
blended_top3_models = blend_models(estimator_list=top3_models, optimize='MAPE')

# 기압 예측
pressure2019_pred_top3 = predict_model(blended_top3_models, data=temp_test)

# 2019년 예측 기압 열 추가
test2019[target_col[0]] = pressure2019_pred_top3['Label']

end = time.time()
sec = end - start
result = datetime.timedelta(seconds=sec)
print(str(result).split('.')[0])
# Out:
# <style  type="text/css" >
# #T_c03af_row7_col0,#T_c03af_row7_col1,#T_c03af_row7_col2,#T_c03af_row7_col3,#T_c03af_row7_col4,#T_c03af_row7_col5{
#             background:  yellow;
#         }</style><table id="T_c03af_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c03af_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c03af_row0_col0" class="data row0 col0" >0.5613</td>
#                         <td id="T_c03af_row0_col1" class="data row0 col1" >2.3826</td>
#                         <td id="T_c03af_row0_col2" class="data row0 col2" >1.5436</td>
#                         <td id="T_c03af_row0_col3" class="data row0 col3" >0.9631</td>
#                         <td id="T_c03af_row0_col4" class="data row0 col4" >0.0015</td>
#                         <td id="T_c03af_row0_col5" class="data row0 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c03af_row1_col0" class="data row1 col0" >0.5678</td>
#                         <td id="T_c03af_row1_col1" class="data row1 col1" >2.4687</td>
#                         <td id="T_c03af_row1_col2" class="data row1 col2" >1.5712</td>
#                         <td id="T_c03af_row1_col3" class="data row1 col3" >0.9619</td>
#                         <td id="T_c03af_row1_col4" class="data row1 col4" >0.0016</td>
#                         <td id="T_c03af_row1_col5" class="data row1 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c03af_row2_col0" class="data row2 col0" >0.5602</td>
#                         <td id="T_c03af_row2_col1" class="data row2 col1" >2.5127</td>
#                         <td id="T_c03af_row2_col2" class="data row2 col2" >1.5851</td>
#                         <td id="T_c03af_row2_col3" class="data row2 col3" >0.9614</td>
#                         <td id="T_c03af_row2_col4" class="data row2 col4" >0.0016</td>
#                         <td id="T_c03af_row2_col5" class="data row2 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c03af_row3_col0" class="data row3 col0" >0.5707</td>
#                         <td id="T_c03af_row3_col1" class="data row3 col1" >2.4924</td>
#                         <td id="T_c03af_row3_col2" class="data row3 col2" >1.5787</td>
#                         <td id="T_c03af_row3_col3" class="data row3 col3" >0.9616</td>
#                         <td id="T_c03af_row3_col4" class="data row3 col4" >0.0016</td>
#                         <td id="T_c03af_row3_col5" class="data row3 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c03af_row4_col0" class="data row4 col0" >0.5709</td>
#                         <td id="T_c03af_row4_col1" class="data row4 col1" >2.5535</td>
#                         <td id="T_c03af_row4_col2" class="data row4 col2" >1.5980</td>
#                         <td id="T_c03af_row4_col3" class="data row4 col3" >0.9607</td>
#                         <td id="T_c03af_row4_col4" class="data row4 col4" >0.0016</td>
#                         <td id="T_c03af_row4_col5" class="data row4 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c03af_row5_col0" class="data row5 col0" >0.5727</td>
#                         <td id="T_c03af_row5_col1" class="data row5 col1" >2.4334</td>
#                         <td id="T_c03af_row5_col2" class="data row5 col2" >1.5599</td>
#                         <td id="T_c03af_row5_col3" class="data row5 col3" >0.9629</td>
#                         <td id="T_c03af_row5_col4" class="data row5 col4" >0.0016</td>
#                         <td id="T_c03af_row5_col5" class="data row5 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c03af_row6_col0" class="data row6 col0" >0.5660</td>
#                         <td id="T_c03af_row6_col1" class="data row6 col1" >2.4517</td>
#                         <td id="T_c03af_row6_col2" class="data row6 col2" >1.5658</td>
#                         <td id="T_c03af_row6_col3" class="data row6 col3" >0.9622</td>
#                         <td id="T_c03af_row6_col4" class="data row6 col4" >0.0016</td>
#                         <td id="T_c03af_row6_col5" class="data row6 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row7" class="row_heading level0 row7" >Mean</th>
#                         <td id="T_c03af_row7_col0" class="data row7 col0" >0.5671</td>
#                         <td id="T_c03af_row7_col1" class="data row7 col1" >2.4707</td>
#                         <td id="T_c03af_row7_col2" class="data row7 col2" >1.5718</td>
#                         <td id="T_c03af_row7_col3" class="data row7 col3" >0.9620</td>
#                         <td id="T_c03af_row7_col4" class="data row7 col4" >0.0016</td>
#                         <td id="T_c03af_row7_col5" class="data row7 col5" >0.0006</td>
#             </tr>
#             <tr>
#                         <th id="T_c03af_level0_row8" class="row_heading level0 row8" >SD</th>
#                         <td id="T_c03af_row8_col0" class="data row8 col0" >0.0045</td>
#                         <td id="T_c03af_row8_col1" class="data row8 col1" >0.0516</td>
#                         <td id="T_c03af_row8_col2" class="data row8 col2" >0.0164</td>
#                         <td id="T_c03af_row8_col3" class="data row8 col3" >0.0008</td>
#                         <td id="T_c03af_row8_col4" class="data row8 col4" >0.0000</td>
#                         <td id="T_c03af_row8_col5" class="data row8 col5" >0.0000</td>
#             </tr>
#     </tbody></table>
# 0:11:26

# %%
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday        기온  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1 -3.894176
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1 -4.363952
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1 -4.476645
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1 -4.922204
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1 -5.048251
#
#             기압
# 0  1012.103393
# 1  1015.612686
# 2  1024.535644
# 3  1014.696643
# 4  1006.996327

# %% [markdown]
# ## 2019년 습도(Humidity) 훈련/예측

# %%
start = time.time()

# 학습 특성 : 'month', 'weekday', '시간', '기온', '기압'
# 타겟 특성 : '습도'
test_col = ['month', 'weekday', '시간', '기온', '기압']
target_col = ['습도']
train_col = test_col + target_col

temp_train = total[train_col]
temp_test = test2019[test_col]

# pycaret 설정
exp = setup(temp_train, target=target_col[0], session_id=0, silent=True, fold=7, fold_shuffle=True, verbose=False)

# 모델 생성(et, dt, rf)
top3_models = compare_models(sort='MAPE', n_select=3)

end = time.time()
sec = end - start
result = datetime.timedelta(seconds=sec)
print(str(result).split('.')[0])
# Out:
# <style  type="text/css" >
#     #T_a946c_ th {
#           text-align: left;
#     }#T_a946c_row0_col0,#T_a946c_row1_col0,#T_a946c_row1_col1,#T_a946c_row1_col2,#T_a946c_row1_col3,#T_a946c_row1_col4,#T_a946c_row1_col5,#T_a946c_row1_col6,#T_a946c_row2_col0,#T_a946c_row2_col1,#T_a946c_row2_col2,#T_a946c_row2_col3,#T_a946c_row2_col4,#T_a946c_row2_col5,#T_a946c_row2_col6,#T_a946c_row3_col0,#T_a946c_row3_col1,#T_a946c_row3_col2,#T_a946c_row3_col3,#T_a946c_row3_col4,#T_a946c_row3_col5,#T_a946c_row3_col6,#T_a946c_row4_col0,#T_a946c_row4_col1,#T_a946c_row4_col2,#T_a946c_row4_col3,#T_a946c_row4_col4,#T_a946c_row4_col5,#T_a946c_row4_col6,#T_a946c_row5_col0,#T_a946c_row5_col1,#T_a946c_row5_col2,#T_a946c_row5_col3,#T_a946c_row5_col4,#T_a946c_row5_col5,#T_a946c_row5_col6,#T_a946c_row6_col0,#T_a946c_row6_col1,#T_a946c_row6_col2,#T_a946c_row6_col3,#T_a946c_row6_col4,#T_a946c_row6_col5,#T_a946c_row6_col6,#T_a946c_row7_col0,#T_a946c_row7_col1,#T_a946c_row7_col2,#T_a946c_row7_col3,#T_a946c_row7_col4,#T_a946c_row7_col5,#T_a946c_row7_col6,#T_a946c_row8_col0,#T_a946c_row8_col1,#T_a946c_row8_col2,#T_a946c_row8_col3,#T_a946c_row8_col4,#T_a946c_row8_col5,#T_a946c_row8_col6,#T_a946c_row9_col0,#T_a946c_row9_col1,#T_a946c_row9_col2,#T_a946c_row9_col3,#T_a946c_row9_col4,#T_a946c_row9_col5,#T_a946c_row9_col6,#T_a946c_row10_col0,#T_a946c_row10_col1,#T_a946c_row10_col2,#T_a946c_row10_col3,#T_a946c_row10_col4,#T_a946c_row10_col5,#T_a946c_row10_col6,#T_a946c_row11_col0,#T_a946c_row11_col1,#T_a946c_row11_col2,#T_a946c_row11_col3,#T_a946c_row11_col4,#T_a946c_row11_col5,#T_a946c_row11_col6,#T_a946c_row12_col0,#T_a946c_row12_col1,#T_a946c_row12_col2,#T_a946c_row12_col3,#T_a946c_row12_col4,#T_a946c_row12_col5,#T_a946c_row12_col6,#T_a946c_row13_col0,#T_a946c_row13_col1,#T_a946c_row13_col2,#T_a946c_row13_col3,#T_a946c_row13_col4,#T_a946c_row13_col5,#T_a946c_row13_col6,#T_a946c_row14_col0,#T_a946c_row14_col1,#T_a946c_row14_col2,#T_a946c_row14_col3,#T_a946c_row14_col4,#T_a946c_row14_col5,#T_a946c_row14_col6,#T_a946c_row15_col0,#T_a946c_row15_col1,#T_a946c_row15_col2,#T_a946c_row15_col3,#T_a946c_row15_col4,#T_a946c_row15_col5,#T_a946c_row15_col6,#T_a946c_row16_col0,#T_a946c_row16_col1,#T_a946c_row16_col2,#T_a946c_row16_col3,#T_a946c_row16_col4,#T_a946c_row16_col5,#T_a946c_row16_col6,#T_a946c_row17_col0,#T_a946c_row17_col1,#T_a946c_row17_col2,#T_a946c_row17_col3,#T_a946c_row17_col4,#T_a946c_row17_col5,#T_a946c_row17_col6,#T_a946c_row18_col0,#T_a946c_row18_col1,#T_a946c_row18_col2,#T_a946c_row18_col3,#T_a946c_row18_col4,#T_a946c_row18_col5,#T_a946c_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_a946c_row0_col1,#T_a946c_row0_col2,#T_a946c_row0_col3,#T_a946c_row0_col4,#T_a946c_row0_col5,#T_a946c_row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_a946c_row0_col7,#T_a946c_row1_col7,#T_a946c_row2_col7,#T_a946c_row3_col7,#T_a946c_row4_col7,#T_a946c_row5_col7,#T_a946c_row6_col7,#T_a946c_row7_col7,#T_a946c_row8_col7,#T_a946c_row9_col7,#T_a946c_row11_col7,#T_a946c_row12_col7,#T_a946c_row13_col7,#T_a946c_row14_col7,#T_a946c_row15_col7,#T_a946c_row16_col7,#T_a946c_row17_col7,#T_a946c_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_a946c_row10_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_a946c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a946c_level0_row0" class="row_heading level0 row0" >et</th>
#                         <td id="T_a946c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#                         <td id="T_a946c_row0_col1" class="data row0 col1" >0.0429</td>
#                         <td id="T_a946c_row0_col2" class="data row0 col2" >0.5902</td>
#                         <td id="T_a946c_row0_col3" class="data row0 col3" >0.7675</td>
#                         <td id="T_a946c_row0_col4" class="data row0 col4" >0.9985</td>
#                         <td id="T_a946c_row0_col5" class="data row0 col5" >0.0141</td>
#                         <td id="T_a946c_row0_col6" class="data row0 col6" >0.0008</td>
#                         <td id="T_a946c_row0_col7" class="data row0 col7" >70.2886</td>
#             </tr>
#             <tr>
#                         <th id="T_a946c_level0_row1" class="row_heading level0 row1" >dt</th>
#                         <td id="T_a946c_row1_col0" class="data row1 col0" >Decision Tree Regressor</td>
#                         <td id="T_a946c_row1_col1" class="data row1 col1" >0.0519</td>
#                         <td id="T_a946c_row1_col2" class="data row1 col2" >1.0219</td>
#                         <td id="T_a946c_row1_col3" class="data row1 col3" >1.0083</td>
#                         <td id="T_a946c_row1_col4" class="data row1 col4" >0.9974</td>
#                         <td id="T_a946c_row1_col5" class="data row1 col5" >0.0193</td>
#                         <td id="T_a946c_row1_col6" class="data row1 col6" >0.0010</td>
#                         <td id="T_a946c_row1_col7" class="data row1 col7" >0.7586</td>
#             </tr>
#             <tr>
#                         <th id="T_a946c_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_a946c_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_a946c_row2_col1" class="data row2 col1" >0.4825</td>
#                         <td id="T_a946c_row2_col2" class="data row2 col2" >1.7154</td>
#                         <td id="T_a946c_row2_col3" class="data row2 col3" >1.3096</td>
#                         <td id="T_a946c_row2_col4" class="data row2 col4" >0.9957</td>
#                         <td id="T_a946c_row2_col5" class="data row2 col5" >0.0271</td>
#                         <td id="T_a946c_row2_col6" class="data row2 col6" >0.0099</td>
#                         <td id="T_a946c_row2_col7" class="data row2 col7" >53.1357</td>
#             </tr>
#             <tr>
#                         <th id="T_a946c_level0_row3" class="row_heading level0 row3" >knn</th>
#                         <td id="T_a946c_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#                         <td id="T_a946c_row3_col1" class="data row3 col1" >2.5277</td>
#                         <td id="T_a946c_row3_col2" class="data row3 col2" >25.2091</td>
#                         <td id="T_a946c_row3_col3" class="data row3 col3" >5.0205</td>
#                         <td id="T_a946c_row3_col4" class="data row3 col4" >0.9365</td>
#                         <td id="T_a946c_row3_col5" class="data row3 col5" >0.0996</td>
#                         <td id="T_a946c_row3_col6" class="data row3 col6" >0.0514</td>
#                         <td id="T_a946c_row3_col7" class="data row3 col7" >2.8214</td>
#             </tr>
#             <tr>
#                         <th id="T_a946c_level0_row4" class="row_heading level0 row4" >xgboost</th>
#                         <td id="T_a946c_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_a946c_row4_col1" class="data row4 col1" >9.1373</td>
#                         <td id="T_a946c_row4_col2" class="data row4 col2" >139.3099</td>
#                         <td id="T_a946c_row4_col3" class="data row4 col3" >11.8027</td>
#                         <td id="T_a946c_row4_col4" class="data row4 col4" >0.6491</td>
# 0:27:45

# %%
start = time.time()

# 블랜드 모델
blended_top3_models = blend_models(estimator_list=top3_models, optimize='MAPE')

# 습도 예측
humidity2019_pred_top3 = predict_model(blended_top3_models, data=temp_test)

# 2019년 예측 습도 열 추가
test2019[target_col[0]] = humidity2019_pred_top3['Label']

end = time.time()
sec = end - start
result = datetime.timedelta(seconds=sec)
print(str(result).split('.')[0])
# Out:
# <style  type="text/css" >
# #T_61f87_row7_col0,#T_61f87_row7_col1,#T_61f87_row7_col2,#T_61f87_row7_col3,#T_61f87_row7_col4,#T_61f87_row7_col5{
#             background:  yellow;
#         }</style><table id="T_61f87_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61f87_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61f87_row0_col0" class="data row0 col0" >0.1854</td>
#                         <td id="T_61f87_row0_col1" class="data row0 col1" >0.6559</td>
#                         <td id="T_61f87_row0_col2" class="data row0 col2" >0.8099</td>
#                         <td id="T_61f87_row0_col3" class="data row0 col3" >0.9984</td>
#                         <td id="T_61f87_row0_col4" class="data row0 col4" >0.0156</td>
#                         <td id="T_61f87_row0_col5" class="data row0 col5" >0.0038</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_61f87_row1_col0" class="data row1 col0" >0.1974</td>
#                         <td id="T_61f87_row1_col1" class="data row1 col1" >0.8248</td>
#                         <td id="T_61f87_row1_col2" class="data row1 col2" >0.9082</td>
#                         <td id="T_61f87_row1_col3" class="data row1 col3" >0.9979</td>
#                         <td id="T_61f87_row1_col4" class="data row1 col4" >0.0179</td>
#                         <td id="T_61f87_row1_col5" class="data row1 col5" >0.0040</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_61f87_row2_col0" class="data row2 col0" >0.1894</td>
#                         <td id="T_61f87_row2_col1" class="data row2 col1" >0.7628</td>
#                         <td id="T_61f87_row2_col2" class="data row2 col2" >0.8734</td>
#                         <td id="T_61f87_row2_col3" class="data row2 col3" >0.9981</td>
#                         <td id="T_61f87_row2_col4" class="data row2 col4" >0.0172</td>
#                         <td id="T_61f87_row2_col5" class="data row2 col5" >0.0039</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_61f87_row3_col0" class="data row3 col0" >0.1868</td>
#                         <td id="T_61f87_row3_col1" class="data row3 col1" >0.7193</td>
#                         <td id="T_61f87_row3_col2" class="data row3 col2" >0.8481</td>
#                         <td id="T_61f87_row3_col3" class="data row3 col3" >0.9982</td>
#                         <td id="T_61f87_row3_col4" class="data row3 col4" >0.0155</td>
#                         <td id="T_61f87_row3_col5" class="data row3 col5" >0.0037</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_61f87_row4_col0" class="data row4 col0" >0.1895</td>
#                         <td id="T_61f87_row4_col1" class="data row4 col1" >0.7535</td>
#                         <td id="T_61f87_row4_col2" class="data row4 col2" >0.8681</td>
#                         <td id="T_61f87_row4_col3" class="data row4 col3" >0.9981</td>
#                         <td id="T_61f87_row4_col4" class="data row4 col4" >0.0168</td>
#                         <td id="T_61f87_row4_col5" class="data row4 col5" >0.0039</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_61f87_row5_col0" class="data row5 col0" >0.1905</td>
#                         <td id="T_61f87_row5_col1" class="data row5 col1" >0.7707</td>
#                         <td id="T_61f87_row5_col2" class="data row5 col2" >0.8779</td>
#                         <td id="T_61f87_row5_col3" class="data row5 col3" >0.9981</td>
#                         <td id="T_61f87_row5_col4" class="data row5 col4" >0.0176</td>
#                         <td id="T_61f87_row5_col5" class="data row5 col5" >0.0038</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_61f87_row6_col0" class="data row6 col0" >0.1928</td>
#                         <td id="T_61f87_row6_col1" class="data row6 col1" >0.7904</td>
#                         <td id="T_61f87_row6_col2" class="data row6 col2" >0.8890</td>
#                         <td id="T_61f87_row6_col3" class="data row6 col3" >0.9980</td>
#                         <td id="T_61f87_row6_col4" class="data row6 col4" >0.0168</td>
#                         <td id="T_61f87_row6_col5" class="data row6 col5" >0.0039</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row7" class="row_heading level0 row7" >Mean</th>
#                         <td id="T_61f87_row7_col0" class="data row7 col0" >0.1903</td>
#                         <td id="T_61f87_row7_col1" class="data row7 col1" >0.7539</td>
#                         <td id="T_61f87_row7_col2" class="data row7 col2" >0.8678</td>
#                         <td id="T_61f87_row7_col3" class="data row7 col3" >0.9981</td>
#                         <td id="T_61f87_row7_col4" class="data row7 col4" >0.0168</td>
#                         <td id="T_61f87_row7_col5" class="data row7 col5" >0.0039</td>
#             </tr>
#             <tr>
#                         <th id="T_61f87_level0_row8" class="row_heading level0 row8" >SD</th>
#                         <td id="T_61f87_row8_col0" class="data row8 col0" >0.0037</td>
#                         <td id="T_61f87_row8_col1" class="data row8 col1" >0.0500</td>
#                         <td id="T_61f87_row8_col2" class="data row8 col2" >0.0292</td>
#                         <td id="T_61f87_row8_col3" class="data row8 col3" >0.0001</td>
#                         <td id="T_61f87_row8_col4" class="data row8 col4" >0.0009</td>
#                         <td id="T_61f87_row8_col5" class="data row8 col5" >0.0001</td>
#             </tr>
#     </tbody></table>
# 0:17:42

# %%
test2019.head()
# Out:
#           일자|시간|구분        연월일  시간  구분  year  month  day  weekday        기온  \
# 0  2019-01-01 01 A 2019-01-01  01   0  2019      1    1        1 -3.894176
# 1  2019-01-01 02 A 2019-01-01  02   0  2019      1    1        1 -4.363952
# 2  2019-01-01 03 A 2019-01-01  03   0  2019      1    1        1 -4.476645
# 3  2019-01-01 04 A 2019-01-01  04   0  2019      1    1        1 -4.922204
# 4  2019-01-01 05 A 2019-01-01  05   0  2019      1    1        1 -5.048251
#
#             기압         습도
# 0  1012.103393  59.380000
# 1  1015.612686  61.166667
# 2  1024.535644  54.536667
# 3  1014.696643  60.153333
# 4  1006.996327  61.723333

# %% [markdown]
# ### 2019년 예측 기온, 기압, 습도 데이터 파일로 출력

# %%
test2019.to_csv('2019년_예측_기온_기압_습도.csv', index=False)

# %% [markdown]
# ## 2019년 가스 공급량 훈련/예측

# %% [markdown]
# ### log_공급량으로 진행

# %%
total['log_공급량'] = np.log1p(total['공급량'])
total.head()
# Out:
#           연월일  year  month  day  weekday  시간  구분       공급량   기온    습도      기압  \
# 0  2013-01-01  2013      1    1        1   1   0  2497.129 -8.5  57.0  1010.0
# 1  2013-01-01  2013      1    1        1   1   1  2169.093 -8.5  57.0  1010.0
# 2  2013-01-01  2013      1    1        1   1   2   226.178 -8.5  57.0  1010.0
# 3  2013-01-01  2013      1    1        1   1   3  1434.516 -8.5  57.0  1010.0
# 4  2013-01-01  2013      1    1        1   1   4  3272.837 -8.5  57.0  1010.0
#
#     log_공급량
# 0  7.823297
# 1  7.682525
# 2  5.425734
# 3  7.269280
# 4  8.093718

# %% [markdown]
# ## 2019년 log_공급량 훈련/예측, 구분별

# %%
# 구분에 따라 예측하기
divisions = test2019['구분'].unique()

# 학습 특성 : 'month', 'weekday', '시간', '구분', '기온', '기압', '습도'
# 타겟 특성 : 'log_공급량'
test_col = ['month', 'weekday', '시간', '구분', '기온', '기압', '습도']
target_col = ['log_공급량']
train_col = test_col + target_col

gas2019_pred = pd.DataFrame()
for division in tqdm(divisions):
    # 구분별 훈련, 테스트 셋 설정
    temp_train = total[total['구분'] == division].reset_index(drop=True)
    temp_train = temp_train[train_col]

    temp_test = test2019[test2019['구분'] == division].reset_index(drop=True)
    temp_test = temp_test[test_col]

    # pycaret 설정
    exp = setup(temp_train, target=target_col[0], session_id=0, silent=True, remove_outliers=True, outliers_threshold=0.1, fold=7, fold_shuffle=True)

    # 모델 생성{ (cat, xgb, et) or (cat, xgb, lgbm) or (et, dt, rf) }
    top3_models = compare_models(sort='MAPE', n_select=3)

    # 블랜드 모델
    blended_top3_models = blend_models(estimator_list=top3_models, optimize='MAPE')

    # 기압 예측
    log_gas2019_pred_top3 = predict_model(blended_top3_models, data=temp_test)

    # log_공급량 값을 공급량 값으로 변환
    gas_pred2019_top3 = np.expm1(log_gas2019_pred_top3['Label'])

    # 구분별 예측 값 합치기
    gas2019_pred = pd.concat([gas2019_pred, gas_pred2019_top3])
    gas2019_pred = gas2019_pred.reset_index(drop=True)
# Out:
# <style  type="text/css" >
# #T_9336d_row7_col0,#T_9336d_row7_col1,#T_9336d_row7_col2,#T_9336d_row7_col3,#T_9336d_row7_col4,#T_9336d_row7_col5{
#             background:  yellow;
#         }</style><table id="T_9336d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9336d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9336d_row0_col0" class="data row0 col0" >0.0711</td>
#                         <td id="T_9336d_row0_col1" class="data row0 col1" >0.0101</td>
#                         <td id="T_9336d_row0_col2" class="data row0 col2" >0.1004</td>
#                         <td id="T_9336d_row0_col3" class="data row0 col3" >0.9838</td>
#                         <td id="T_9336d_row0_col4" class="data row0 col4" >0.0179</td>
#                         <td id="T_9336d_row0_col5" class="data row0 col5" >0.0145</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9336d_row1_col0" class="data row1 col0" >0.0719</td>
#                         <td id="T_9336d_row1_col1" class="data row1 col1" >0.0108</td>
#                         <td id="T_9336d_row1_col2" class="data row1 col2" >0.1040</td>
#                         <td id="T_9336d_row1_col3" class="data row1 col3" >0.9823</td>
#                         <td id="T_9336d_row1_col4" class="data row1 col4" >0.0179</td>
#                         <td id="T_9336d_row1_col5" class="data row1 col5" >0.0145</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9336d_row2_col0" class="data row2 col0" >0.0723</td>
#                         <td id="T_9336d_row2_col1" class="data row2 col1" >0.0131</td>
#                         <td id="T_9336d_row2_col2" class="data row2 col2" >0.1143</td>
#                         <td id="T_9336d_row2_col3" class="data row2 col3" >0.9790</td>
#                         <td id="T_9336d_row2_col4" class="data row2 col4" >0.0222</td>
#                         <td id="T_9336d_row2_col5" class="data row2 col5" >0.0150</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9336d_row3_col0" class="data row3 col0" >0.0716</td>
#                         <td id="T_9336d_row3_col1" class="data row3 col1" >0.0106</td>
#                         <td id="T_9336d_row3_col2" class="data row3 col2" >0.1028</td>
#                         <td id="T_9336d_row3_col3" class="data row3 col3" >0.9836</td>
#                         <td id="T_9336d_row3_col4" class="data row3 col4" >0.0183</td>
#                         <td id="T_9336d_row3_col5" class="data row3 col5" >0.0146</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9336d_row4_col0" class="data row4 col0" >0.0724</td>
#                         <td id="T_9336d_row4_col1" class="data row4 col1" >0.0112</td>
#                         <td id="T_9336d_row4_col2" class="data row4 col2" >0.1056</td>
#                         <td id="T_9336d_row4_col3" class="data row4 col3" >0.9819</td>
#                         <td id="T_9336d_row4_col4" class="data row4 col4" >0.0184</td>
#                         <td id="T_9336d_row4_col5" class="data row4 col5" >0.0146</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9336d_row5_col0" class="data row5 col0" >0.0724</td>
#                         <td id="T_9336d_row5_col1" class="data row5 col1" >0.0125</td>
#                         <td id="T_9336d_row5_col2" class="data row5 col2" >0.1119</td>
#                         <td id="T_9336d_row5_col3" class="data row5 col3" >0.9793</td>
#                         <td id="T_9336d_row5_col4" class="data row5 col4" >0.0188</td>
#                         <td id="T_9336d_row5_col5" class="data row5 col5" >0.0146</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9336d_row6_col0" class="data row6 col0" >0.0701</td>
#                         <td id="T_9336d_row6_col1" class="data row6 col1" >0.0096</td>
#                         <td id="T_9336d_row6_col2" class="data row6 col2" >0.0982</td>
#                         <td id="T_9336d_row6_col3" class="data row6 col3" >0.9846</td>
#                         <td id="T_9336d_row6_col4" class="data row6 col4" >0.0173</td>
#                         <td id="T_9336d_row6_col5" class="data row6 col5" >0.0142</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row7" class="row_heading level0 row7" >Mean</th>
#                         <td id="T_9336d_row7_col0" class="data row7 col0" >0.0717</td>
#                         <td id="T_9336d_row7_col1" class="data row7 col1" >0.0111</td>
#                         <td id="T_9336d_row7_col2" class="data row7 col2" >0.1053</td>
#                         <td id="T_9336d_row7_col3" class="data row7 col3" >0.9821</td>
#                         <td id="T_9336d_row7_col4" class="data row7 col4" >0.0187</td>
#                         <td id="T_9336d_row7_col5" class="data row7 col5" >0.0146</td>
#             </tr>
#             <tr>
#                         <th id="T_9336d_level0_row8" class="row_heading level0 row8" >SD</th>
#                         <td id="T_9336d_row8_col0" class="data row8 col0" >0.0008</td>
#                         <td id="T_9336d_row8_col1" class="data row8 col1" >0.0012</td>
#                         <td id="T_9336d_row8_col2" class="data row8 col2" >0.0054</td>
#                         <td id="T_9336d_row8_col3" class="data row8 col3" >0.0020</td>
#                         <td id="T_9336d_row8_col4" class="data row8 col4" >0.0015</td>
#                         <td id="T_9336d_row8_col5" class="data row8 col5" >0.0002</td>
#             </tr>
#     </tbody></table>
# 100%|██████████| 7/7 [41:25<00:00, 355.10s/it]

# %%
# 예측 결과 확인
gas2019_pred.head()
# Out:
#              0
# 0  2010.968452
# 1  1820.834736
# 2  1703.292898
# 3  1696.259298
# 4  1904.915174

# %% [markdown]
# ## 제출 파일 가져오기

# %%
sub = pd.read_csv('../data/sample_submission.csv')
sub.head()
# Out:
#           일자|시간|구분  공급량
# 0  2019-01-01 01 A    0
# 1  2019-01-01 02 A    0
# 2  2019-01-01 03 A    0
# 3  2019-01-01 04 A    0
# 4  2019-01-01 05 A    0

# %%
sub['공급량'] = gas2019_pred
sub.head()
# Out:
#           일자|시간|구분          공급량
# 0  2019-01-01 01 A  2010.968452
# 1  2019-01-01 02 A  1820.834736
# 2  2019-01-01 03 A  1703.292898
# 3  2019-01-01 04 A  1696.259298
# 4  2019-01-01 05 A  1904.915174

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15120 entries, 0 to 15119
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   일자|시간|구분  15120 non-null  object
#  1   공급량       15120 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 236.4+ KB

# %% [markdown]
# ## 제출 파일 출력

# %%
sub.to_csv("sub34_pycaret22(ver2.5).csv", index=False)
