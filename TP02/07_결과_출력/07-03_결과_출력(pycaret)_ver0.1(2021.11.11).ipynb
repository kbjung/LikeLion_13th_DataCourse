# %%
import pandas as pd

# %%
df = pd.read_csv('../2013-2018년_가스공급량과_기온2.csv', index_col=False)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         연월일  시간  구분       공급량  year  month  day  \
# 0           0             0  2013-01-01   1   0  2497.129  2013      1    1
# 1           1             1  2013-01-01   1   1  2169.093  2013      1    1
# 2           2             2  2013-01-01   1   2   226.178  2013      1    1
# 3           3             3  2013-01-01   1   3  1434.516  2013      1    1
# 4           4             4  2013-01-01   1   4  3272.837  2013      1    1
#
#    weekday   기온
# 0        1 -6.4
# 1        1 -6.4
# 2        1 -6.4
# 3        1 -6.4
# 4        1 -6.4

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
df.head()
# Out:
#           연월일  시간  구분       공급량  year  month  day  weekday   기온
# 0  2013-01-01   1   0  2497.129  2013      1    1        1 -6.4
# 1  2013-01-01   1   1  2169.093  2013      1    1        1 -6.4
# 2  2013-01-01   1   2   226.178  2013      1    1        1 -6.4
# 3  2013-01-01   1   3  1434.516  2013      1    1        1 -6.4
# 4  2013-01-01   1   4  3272.837  2013      1    1        1 -6.4

# %% [markdown]
# # pycaret

# %%
# 모든 특성 사용

# %%
from pycaret.regression import *

# %%
exp = setup(df, target='공급량', ignore_features=['연월일'])
# Out:
# <style  type="text/css" >
# #T_b33a7_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_b33a7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b33a7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b33a7_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b33a7_row0_col1" class="data row0 col1" >5123</td>
#             </tr>
#             <tr>
#                         <th id="T_b33a7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b33a7_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_b33a7_row1_col1" class="data row1 col1" >공급량</td>
#             </tr>
#             <tr>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_9887f_ th {
#           text-align: left;
# ...

# %%
# %%time

top5_models = compare_models(n_select=5, sort='MAPE',
                             exclude=['llar', 'ada', 'knn', 'en', 'omp', 'huber', 'lasso', 'lr', 'ridge', 'br', 'lar'])
