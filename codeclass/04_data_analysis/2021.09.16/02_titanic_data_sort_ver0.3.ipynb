# %%
import seaborn as sns
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

t = sns.load_dataset('titanic')

# %%
# 클래스 별 요금의 평균, 최고, 최저 가
fare_by_class = t[["fare","age", "sex", "pclass"]].groupby(["pclass"])
fare_by_class

# %%
# 클래스 별 평균
fare_by_class["fare"].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
# 클래스 별 최댓값
fare_by_class["fare"].max()
# Out:
# pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: fare, dtype: float64

# %%
# 클래스 별 최솟값
fare_by_class["fare"].min()
# Out:
# pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: fare, dtype: float64

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 등석 별 성별, 나이, 요금
sel = ["sex", "age", "fare"]
fare_by_sex_age1 = t[sel].loc[t["pclass"]==1,:]
fare_by_sex_age2 = t[sel].loc[t["pclass"]==2,:]
fare_by_sex_age3 = t[sel].loc[t["pclass"]==3,:]

fare_by_sex_age1.shape, fare_by_sex_age2.shape, fare_by_sex_age3.shape
# Out:
# ((216, 3), (184, 3), (491, 3))

# %%
fare_by_sex_age1.head()
# Out:
#        sex   age     fare
# 1   female  38.0  71.2833
# 3   female  35.0  53.1000
# 6     male  54.0  51.8625
# 11  female  58.0  26.5500
# 23    male  28.0  35.5000

# %%
# 히스토그램(x=나이, y=요금, 비교군=성별)
sns.set_style("whitegrid")
plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
sns.lmplot(x="age", y="fare", hue="sex", data=fare_by_sex_age1)
plt.title("Class1")


plt.subplot(1,3,2)
sns.lmplot(x="age", y="fare", hue="sex", data=fare_by_sex_age2)
plt.title("Class2")


plt.subplot(1,3,3)
sns.lmplot(x="age", y="fare", hue="sex", data=fare_by_sex_age3)
plt.title("Class3")
# Out:
# Text(0.5, 1.0, 'Class3')

# %%
# 히스토그램(x=나이, y=요금, 비교군=성별)
sns.set_style("whitegrid")
plt.figure(figsize=(12,12))
sns.lmplot(x="age", y="fare", hue="sex", data=fare_by_sex_age1)
plt.title("Class1")

sns.lmplot(x="age", y="fare", hue="sex", data=fare_by_sex_age2)
plt.title("Class2")

sns.lmplot(x="age", y="fare", hue="sex", data=fare_by_sex_age3)
plt.title("Class3")
# Out:
# Text(0.5, 1.0, 'Class3')

# %%
# boxplot(x=요금)
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.boxplot(x="fare", data=fare_by_sex_age1)
plt.title("Class1")

plt.subplot(1,3,2)
sns.boxplot(x="fare", data=fare_by_sex_age2)
plt.title("Class2")

plt.subplot(1,3,3)
sns.boxplot(x="fare", data=fare_by_sex_age3)
plt.title("Class3")
# Out:
# Text(0.5, 1.0, 'Class3')

# %%
# boxplot(x=요금)
plt.figure(figsize=(20,5))

sns.boxplot(x="fare", data=fare_by_sex_age1)
plt.title("Class1")

sns.boxplot(x="fare", data=fare_by_sex_age2)
plt.title("Class2")

sns.boxplot(x="fare", data=fare_by_sex_age3)
plt.title("Class3")
# Out:
# Text(0.5, 1.0, 'Class3')
