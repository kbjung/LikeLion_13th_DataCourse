# %%
### 네이버 데이터 랩에서 데이터 가져오기

# %%
filename = "datalab_word.xlsx"
# 해당 시트명 입력
sheetname = input("시트명을 입력해 주세요:")
# Out:
# 시트명을 입력해 주세요:패션의류_0913

# %%
# -*- coding: utf-8 -*-
import os
os.getcwd()
from selenium import webdriver
from bs4 import BeautifulSoup
driver = webdriver.Chrome('chromedriver')

# %%
## http://www.opinet.co.kr/searRgSelect.do 접속
url = "https://datalab.naver.com/"
driver.get(url)

# %%
# 4-6 실습 - 날짜 가져오기
page = driver.page_source
soup = BeautifulSoup(page, 'lxml')
soup.title
# Out:
# <title>네이버 데이터랩</title>

# %%
dates = soup.find_all("span", class_='title_cell')
for one in dates:
    print(one.text)
# Out:
# 2021.09.01.(수)
# 2021.09.02.(목)
# 2021.09.03.(금)
# 2021.09.04.(토)
# 2021.09.05.(일)
# 2021.09.06.(월)
# 2021.09.07.(화)
# 2021.09.08.(수)
# 2021.09.09.(목)
# 2021.09.10.(금)
# 2021.09.11.(토)
# 2021.09.12.(일)

# %%
# 총 데이터 개수
print(len(dates))
# Out:
# 14

# %%
day_list = soup.find_all("ul", class_="rank_list")
day_list[0].find("span", class_="title")
# Out:
# <span class="title">원피스</span>

# %%
lists = day_list[0].find_all("span", class_="title")
lists[0].text
# Out:
# '원피스'

# %%
# 4-7 (추가) 하나의 날짜의 인기 검색어 가져오기 - 댓글
for one in lists:
    print(one.text)
# Out:
# 원피스
# 나이키후드티
# 후드집업
# 나이키바람막이
# 가을원피스
# 바람막이
# 트위드자켓
# 트렌치코트
# 맨투맨
# 가디건

# %%
# selenium 이용해서 가져오기
# xpath : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[1]/div/div/ul/li[1]/a/span
xpath = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[9]/div/div/ul/li[1]/a/span'
one_ele = driver.find_element_by_xpath(xpath)
one_ele
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d551c8fc32942ecc1082631bc1c68896", element="e24ee09e-b0a0-467c-be1d-1c27611a52b6")>

# %%
one_ele.text
# Out:
# '원피스'

# %%
# 2021.09.09
# 검색어1 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[9]/div/div/ul/li[1]/a/span
# 검색어3 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[9]/div/div/ul/li[3]/a/span
# 검색어7 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[9]/div/div/ul/li[7]/a/span
# 검색어10 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[9]/div/div/ul/li[10]/a/span

# %%
pop_word = []
for num in range(1,11):
    xpath_url = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[9]/div/div/ul/li['+str(num)+']/a/span'
    one_ele = driver.find_element_by_xpath(xpath_url)
    # print(one_ele.text)
    pop_word.append(one_ele.text)
pop_word
# Out:
# ['원피스',
#  '가을원피스',
#  '나이키바람막이',
#  '트위드자켓',
#  '나이키후드티',
#  '후드집업',
#  '바람막이',
#  '반팔티',
#  '반바지',
#  '써스데이아일랜드원피스']

# %%
# 2021.09.10
# 검색어1 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[10]/div/div/ul/li[1]/a/span
# 검색어3 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[10]/div/div/ul/li[3]/a/span

# %%
# 5-2 (추가) 4일간의 10개 검색어 가져오기
# my sol.
lists = []
for day in range(9, 13):
    for num in range(1, 11):
        xpath_s = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div['+str(day)+']/div/div/ul/li['+str(num)+']/a/span'
        one_ele = driver.find_element_by_xpath(xpath_s)
        lists.append(one_ele.text)
lists
# Out:
# ['원피스',
#  '가을원피스',
#  '나이키바람막이',
#  '트위드자켓',
#  '나이키후드티',
#  '후드집업',
#  '바람막이',
#  '반팔티',
#  '반바지',
#  '써스데이아일랜드원피스',
#  '원피스',
#  '가을원피스',
#  '트위드자켓',
#  '나이키바람막이',
#  '나이키후드티',
#  '써스데이아일랜드원피스',
#  '반팔티',
#  '반바지',
#  '팬츠',
#  '바람막이',
#  '원피스',
#  '나이키후드티',
#  '트위드자켓',
#  '나이키바람막이',
#  '가을원피스',
#  '써스데이아일랜드원피스',
#  '반팔티',
#  '맨투맨',
#  '후드집업',
#  '반바지',
#  '원피스',
#  '나이키후드티',
#  '써스데이아일랜드원피스',
#  '가을원피스',
#  '트위드자켓',
#  '나이키바람막이',
#  '바람막이',
#  '후드집업',
#  '맨투맨',
#  '블라우스']

# %%
# sol.
page_start = 9
page_end = 12
for page in range(page_start, page_end+1, 1):
    pop_word = []
    for num in range(1, 11, 1):
        xpath_url = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div['+str(page)+']/div/div/ul/li['+str(num)+']/a/span'
        one_ele = driver.find_element_by_xpath(xpath_url)
        pop_word.append(one_ele.text)
    print(pop_word)
# Out:
# ['원피스', '가을원피스', '나이키바람막이', '트위드자켓', '나이키후드티', '후드집업', '바람막이', '반팔티', '반바지', '써스데이아일랜드원피스']
# ['원피스', '가을원피스', '트위드자켓', '나이키바람막이', '나이키후드티', '써스데이아일랜드원피스', '반팔티', '반바지', '팬츠', '바람막이']
# ['원피스', '나이키후드티', '트위드자켓', '나이키바람막이', '가을원피스', '써스데이아일랜드원피스', '반팔티', '맨투맨', '후드집업', '반바지']
# ['원피스', '나이키후드티', '써스데이아일랜드원피스', '가을원피스', '트위드자켓', '나이키바람막이', '바람막이', '후드집업', '맨투맨', '블라우스']

# %%
# 5-2 (추가) 다른 날짜 가져오기

# %%
# 2021.09.08
# 검색어1 : //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[8]/div/div/ul/li[1]/a/span
# 검색어 3: //*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div[8]/div/div/ul/li[3]/a/span

# %%
import time
left_click_xpath= '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/a[1]/span'
right_click_xpath = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/a[2]/span'

left_click = driver.find_element_by_xpath(left_click_xpath)
right_click = driver.find_element_by_xpath(right_click_xpath)

for i in range(8):
    left_click.click()
lists = []
for day in range(1, 13):
    for num in range(1, 11):
        xpath_s = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div['+str(day)+']/div/div/ul/li['+str(num)+']/a/span'
        one_ele = driver.find_element_by_xpath(xpath_s)
        lists.append(one_ele.text)
    print(lists, len(lists))
    right_click.click()
    time.sleep(3)
# Out:
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건'] 10
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티'] 20
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '트위드자켓', '써스데이아일랜드원피스', '반바지', '반팔티', '바람막이'] 30
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '트위드자켓', '써스데이아일랜드원피스', '반바지', '반팔티', '바람막이', '원피스', '트위드자켓', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '써스데이아일랜드원피스', '바람막이', '트렌치코트', '가디건'] 40
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '트위드자켓', '써스데이아일랜드원피스', '반바지', '반팔티', '바람막이', '원피스', '트위드자켓', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '써스데이아일랜드원피스', '바람막이', '트렌치코트', '가디건', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '트위드자켓', '후드집업', '바람막이', '트렌치코트', '맨투맨', '써스데이아일랜드원피스'] 50
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '트위드자켓', '써스데이아일랜드원피스', '반바지', '반팔티', '바람막이', '원피스', '트위드자켓', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '써스데이아일랜드원피스', '바람막이', '트렌치코트', '가디건', '원피스', '나이키후드티', '가을원피스', '나이키바람막이',
'나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '써스데이아일랜드원피스', '바람막이', '트렌치코트', '가디건', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '트위드자켓', '후드집업', '바람막이', '트렌치코트', '맨투맨', '써스데이아일랜드원피스', '원피스', '나이키바람막이', '가을원피스', '후드집업', '나이키후드티', '바람막이', '트위드자켓', '맨투맨', '가디건', '폴로가디건', '원피스', '나이키바람막이', '후드집업', '바람막이', '가을원피스', '나이키후드티', '트위드자켓', '맨투맨', '가디건', '폴로가디건', '원피스', '가을원피스', '나이키바람막이', '나이키후드티', '후드집업', '트위드자켓', '바람막이', '맨투맨', '반팔티', '가디건', '원피스', '가을원피스', '나이키바람막이', '트위드자켓', '나이키후드티', '후드집업', '바람막이', '반팔티', '반바지', '써스데이아일랜드원피스', '원피스', '가을원피스', '트위드자켓', '나이키바람막이', '나이키후드티', '써스데이아일랜드원피스', '반팔티', '반바지', '팬츠', '바람막이', '원피스', '나이키후드티', '트위드자켓', '나이키바람막이', '가을원피스', '써스데이아일랜드원피스', '반팔티', '맨투맨', '후드집업', '반바지', '원피스', '나이키후드티', '써스데이아일랜드원피스', '가을원피스', '트위드자켓', '나이키바람막이', '바람막이', '후드집업', '맨투맨', '블라우스'] 120

# %%
# 5-3 (추가) 전체 날짜를 csv나 xlsx로 만들때, 날짜를 정보를 넣어서 만들기

# %%
import time
# 날짜 화면 왼쪽, 오른쪽 부분 보기 xpath
left_click_xpath= '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/a[1]/span'
right_click_xpath = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/a[2]/span'

left_click = driver.find_element_by_xpath(left_click_xpath)
right_click = driver.find_element_by_xpath(right_click_xpath)


for i in range(8):
    # 화면을 왼쪽 끝으로 이동시키기
    left_click.click()
    time.sleep(3)

# 검색어 리스트로 만들기
lists = []
for day in range(1, 13):
    # 하루의 검색어 10개 입력하기
    for num in range(1, 11):
        xpath_s = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div['+str(day)+']/div/div/ul/li['+str(num)+']/a/span'
        one_ele = driver.find_element_by_xpath(xpath_s)
        lists.append(one_ele.text)
    print(lists, len(lists))
    right_click.click()
    time.sleep(3)
# Out:
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건'] 10
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티'] 20
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건', '원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티', '원피스', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업',
right_click_xpath = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/a[2]/span'

left_click = driver.find_element_by_xpath(left_click_xpath)
right_click = driver.find_element_by_xpath(right_click_xpath)

# 날짜 가져오기
dates = soup.find_all("span", class_='title_cell')

for i in range(8):
    # 화면을 왼쪽 끝으로 이동시키기
    left_click.click()
    time.sleep(3)

# 검색어 리스트로 만들기
lists = []
days = []
for day in range(1, 13):
    # 날짜 기록하기
    tmp_date = dates[day-1].text
    days.append(tmp_date)
    # 하루의 검색어 10개 입력하기
    day_lst = []
    for num in range(1, 11):
        xpath_s = '//*[@id="content"]/div[1]/div[4]/div/div[1]/div/div/div['+str(day)+']/div/div/ul/li['+str(num)+']/a/span'
        one_ele = driver.find_element_by_xpath(xpath_s)
        day_lst.append(one_ele.text)
    print(day_lst, len(day_lst))
    lists.append(day_lst)
    right_click.click()
    time.sleep(3)
    
# 날짜와 검색어 조합하기
all_dict = {}
for i in range(len(days)):
    all_dict[days[i]] = lists[i]
    
# 리스트 파일로 만들기
import pandas as pd

dat = pd.DataFrame(all_dict)
dat.to_csv("네이버 날짜별 검색어.csv", index="False")
dat.to_excel("네이버 날짜별 검색어.xlsx", index="False")
# Out:
# ['원피스', '나이키후드티', '후드집업', '나이키바람막이', '가을원피스', '바람막이', '트위드자켓', '트렌치코트', '맨투맨', '가디건'] 10
# ['원피스', '가을원피스', '나이키후드티', '나이키바람막이', '후드집업', '트위드자켓', '바람막이', '트렌치코트', '맨투맨', '반팔티'] 10
# ['원피스', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '트위드자켓', '써스데이아일랜드원피스', '반바지', '반팔티', '바람막이'] 10
# ['원피스', '트위드자켓', '나이키후드티', '가을원피스', '나이키바람막이', '후드집업', '써스데이아일랜드원피스', '바람막이', '트렌치코트', '가디건'] 10
# ['원피스', '나이키후드티', '가을원피스', '나이키바람막이', '트위드자켓', '후드집업', '바람막이', '트렌치코트', '맨투맨', '써스데이아일랜드원피스'] 10
# ['원피스', '나이키바람막이', '가을원피스', '후드집업', '나이키후드티', '바람막이', '트위드자켓', '맨투맨', '가디건', '폴로가디건'] 10
# ['원피스', '나이키바람막이', '후드집업', '바람막이', '가을원피스', '나이키후드티', '트위드자켓', '맨투맨', '가디건', '폴로가디건'] 10
# ['원피스', '가을원피스', '나이키바람막이', '나이키후드티', '후드집업', '트위드자켓', '바람막이', '맨투맨', '반팔티', '가디건'] 10
# ['원피스', '가을원피스', '나이키바람막이', '트위드자켓', '나이키후드티', '후드집업', '바람막이', '반팔티', '반바지', '써스데이아일랜드원피스'] 10
# ['원피스', '가을원피스', '트위드자켓', '나이키바람막이', '나이키후드티', '써스데이아일랜드원피스', '반팔티', '반바지', '팬츠', '바람막이'] 10
# ['원피스', '나이키후드티', '트위드자켓', '나이키바람막이', '가을원피스', '써스데이아일랜드원피스', '반팔티', '맨투맨', '후드집업', '반바지'] 10
# ['원피스', '나이키후드티', '써스데이아일랜드원피스', '가을원피스', '트위드자켓', '나이키바람막이', '바람막이', '후드집업', '맨투맨', '블라우스'] 10
