# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train2 = train.drop(['Name', 'Cabin'], axis=1)
train2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
train.groupby(['Pclass', 'Sex', 'Survived']).count()
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Sex    Survived
# 1      female 0                   3     3    3      3      3       3     3
#               1                  91    91   82     91     91      91    91
#        male   0                  77    77   61     77     77      77    77
#               1                  45    45   40     45     45      45    45
# 2      female 0                   6     6    6      6      6       6     6
#               1                  70    70   68     70     70      70    70
#        male   0                  91    91   84     91     91      91    91
#               1                  17    17   15     17     17      17    17
# 3      female 0                  72    72   55     72     72      72    72
#               1                  72    72   47     72     72      72    72
#        male   0                 300   300  215    300    300     300   300
# ...

# %%
train.groupby(['Pclass', 'Sex', 'Survived'], as_index=False).count()
# Out:
#     Pclass     Sex  Survived  PassengerId  Name  Age  SibSp  Parch  Ticket  \
# 0        1  female         0            3     3    3      3      3       3
# 1        1  female         1           91    91   82     91     91      91
# 2        1    male         0           77    77   61     77     77      77
# 3        1    male         1           45    45   40     45     45      45
# 4        2  female         0            6     6    6      6      6       6
# 5        2  female         1           70    70   68     70     70      70
# 6        2    male         0           91    91   84     91     91      91
# 7        2    male         1           17    17   15     17     17      17
# 8        3  female         0           72    72   55     72     72      72
# 9        3  female         1           72    72   47     72     72      72
# 10       3    male         0          300   300  215    300    300     300
# ...

# %% [markdown]
# ### 데이터 셋 보여주는 최대 행, 열 값

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 500

# %%
pd.options.display.max_rows
# Out:
# 1000

# %%
train2
# Out:
#      PassengerId  Survived  Pclass     Sex    Age  SibSp  Parch  \
# 0              1         0       3    male  22.00      1      0
# 1              2         1       1  female  38.00      1      0
# 2              3         1       3  female  26.00      0      0
# 3              4         1       1  female  35.00      1      0
# 4              5         0       3    male  35.00      0      0
# 5              6         0       3    male    NaN      0      0
# 6              7         0       1    male  54.00      0      0
# 7              8         0       3    male   2.00      3      1
# 8              9         1       3  female  27.00      0      2
# 9             10         1       2  female  14.00      1      0
# 10            11         1       3  female   4.00      1      1
# 11            12         1       1  female  58.00      0      0
# 12            13         0       3    male  20.00      0      0
# 13            14         0       3    male  39.00      1      5
# ...

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 20

# %%
train2['Age'].isnull().sum()
# Out:
# 177

# %%
train2['Age'].notnull().sum()
# Out:
# 714

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
train2[train2['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass     Sex  Age  SibSp  Parch      Ticket  \
# 5              6         0       3    male  NaN      0      0      330877
# 17            18         1       2    male  NaN      0      0      244373
# 19            20         1       3  female  NaN      0      0        2649
# 26            27         0       3    male  NaN      0      0        2631
# 28            29         1       3  female  NaN      0      0      330959
# ..           ...       ...     ...     ...  ...    ...    ...         ...
# 859          860         0       3    male  NaN      0      0        2629
# 863          864         0       3  female  NaN      8      2    CA. 2343
# 868          869         0       3    male  NaN      0      0      345777
# 878          879         0       3    male  NaN      0      0      349217
# 888          889         0       3  female  NaN      1      2  W./C. 6607
#
#         Fare Embarked
# 5     8.4583        Q
# 17   13.0000        S
# ...

# %%
train2[train2['Age'].notnull()].count()
# Out:
# PassengerId    714
# Survived       714
# Pclass         714
# Sex            714
# Age            714
# SibSp          714
# Parch          714
# Ticket         714
# Fare           714
# Embarked       712
# dtype: int64

# %%
train_age = train2.sort_values(by='Age', ascending=False)
train_age
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 630          631         1       1    male  80.0      0      0       27042
# 851          852         0       3    male  74.0      0      0      347060
# 493          494         0       1    male  71.0      0      0    PC 17609
# 96            97         0       1    male  71.0      0      0    PC 17754
# 116          117         0       3    male  70.5      0      0      370369
# ..           ...       ...     ...     ...   ...    ...    ...         ...
# 859          860         0       3    male   NaN      0      0        2629
# 863          864         0       3  female   NaN      8      2    CA. 2343
# 868          869         0       3    male   NaN      0      0      345777
# 878          879         0       3    male   NaN      0      0      349217
# 888          889         0       3  female   NaN      1      2  W./C. 6607
#
#         Fare Embarked
# 630  30.0000        S
# ...

# %%
train_age.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0      630          631         1       1    male  80.0      0      0
# 1      851          852         0       3    male  74.0      0      0
# 2      493          494         0       1    male  71.0      0      0
# 3       96           97         0       1    male  71.0      0      0
# 4      116          117         0       3    male  70.5      0      0
# ..     ...          ...       ...     ...     ...   ...    ...    ...
# 886    859          860         0       3    male   NaN      0      0
# 887    863          864         0       3  female   NaN      8      2
# 888    868          869         0       3    male   NaN      0      0
# 889    878          879         0       3    male   NaN      0      0
# 890    888          889         0       3  female   NaN      1      2
#
#          Ticket     Fare Embarked
# 0         27042  30.0000        S
# 1        347060   7.7750        S
# ...

# %%
train_age
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 630          631         1       1    male  80.0      0      0       27042
# 851          852         0       3    male  74.0      0      0      347060
# 493          494         0       1    male  71.0      0      0    PC 17609
# 96            97         0       1    male  71.0      0      0    PC 17754
# 116          117         0       3    male  70.5      0      0      370369
# ..           ...       ...     ...     ...   ...    ...    ...         ...
# 859          860         0       3    male   NaN      0      0        2629
# 863          864         0       3  female   NaN      8      2    CA. 2343
# 868          869         0       3    male   NaN      0      0      345777
# 878          879         0       3    male   NaN      0      0      349217
# 888          889         0       3  female   NaN      1      2  W./C. 6607
#
#         Fare Embarked
# 630  30.0000        S
# ...

# %%
print(len(train_age.reset_index().columns), train_age.reset_index().columns)
# Out:
# 11 Index(['index', 'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
print(len(train_age.columns), train_age.columns)
# Out:
# 10 Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
train_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 630 to 888
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 76.6+ KB

# %% [markdown]
# #### [데이터셋]['col'].unique() : 데이터셋에서 'col'열의 유일한 값만 골라낸다.

# %%
train_age['SibSp'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 8], dtype=int64)

# %% [markdown]
# #### [데이터셋]['col'].value_counts() : 데이터셋에서 'col'열의 유일한 값별로 개수를 센다.

# %%
train_age['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
train_age['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train_age['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
