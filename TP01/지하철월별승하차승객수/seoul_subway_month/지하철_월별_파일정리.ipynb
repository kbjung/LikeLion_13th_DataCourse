# %%
# 파일을 순차적으로 불러오기
# 월별 승하차 인원 합계 구하기
# 월별로 데이터 셋으로 만들기 
# 월별 데이터셋 하나로 합치기
# csv 파일로 만들기

# %%
import pandas as pd

# %%
# 파일 불러오기
# 파일을 순차적으로 불러오기
# 월별 승하차 인원 합계 구하기
# 월별로 데이터 셋으로 만들기 

# 2015
sub_in_month_2015 = []
sub_out_month_2015 = []
for i in range(1,13):
    tmp_csv = pd.read_csv(f'./2015/CARD_SUBWAY_MONTH_2015{i:0>2}.csv', encoding='cp949')
    tmp_sum1 = tmp_csv['승차총승객수'].sum()
    tmp_sum2 = tmp_csv['하차총승객수'].sum()
    sub_in_month_2015.append(tmp_sum1)
    sub_out_month_2015.append(tmp_sum2)

# print(len(sub_in_month_2015))
# print(len(sub_out_month_2015))
# sub_in_month_2015

# %%
# 2016
sub_in_month_2016 = []
sub_out_month_2016 = []
for i in range(1,13):
    tmp_csv = pd.read_csv(f'./2016/CARD_SUBWAY_MONTH_2016{i:0>2}.csv', encoding='cp949')
    tmp_sum1 = tmp_csv['승차총승객수'].sum()
    tmp_sum2 = tmp_csv['하차총승객수'].sum()
    sub_in_month_2016.append(tmp_sum1)
    sub_out_month_2016.append(tmp_sum2)

# %%
# 2017
sub_in_month_2017 = []
sub_out_month_2017 = []
for i in range(1,13):
    tmp_csv = pd.read_csv(f'./2017/CARD_SUBWAY_MONTH_2017{i:0>2}.csv', encoding='cp949')
    tmp_sum1 = tmp_csv['승차총승객수'].sum()
    tmp_sum2 = tmp_csv['하차총승객수'].sum()
    sub_in_month_2017.append(tmp_sum1)
    sub_out_month_2017.append(tmp_sum2)

# %%
# 2018
sub_in_month_2018 = []
sub_out_month_2018 = []
for i in range(1,13):
    tmp_csv = pd.read_csv(f'./2018/CARD_SUBWAY_MONTH_2018{i:0>2}.csv', encoding='cp949')
    tmp_sum1 = tmp_csv['승차총승객수'].sum()
    tmp_sum2 = tmp_csv['하차총승객수'].sum()
    sub_in_month_2018.append(tmp_sum1)
    sub_out_month_2018.append(tmp_sum2)

# %%
# 2019
sub_in_month_2019 = []
sub_out_month_2019 = []
for i in range(1,13):
    tmp_csv = pd.read_csv(f'./2019/CARD_SUBWAY_MONTH_2019{i:0>2}.csv', encoding='cp949')
    tmp_sum1 = tmp_csv['승차총승객수'].sum()
    tmp_sum2 = tmp_csv['하차총승객수'].sum()
    sub_in_month_2019.append(tmp_sum1)
    sub_out_month_2019.append(tmp_sum2)

# %%
# 2020
sub_in_month_2020 = []
sub_out_month_2020 = []
for i in range(1,13):
    tmp_csv = pd.read_csv(f'./2020/CARD_SUBWAY_MONTH_2020{i:0>2}.csv', encoding='cp949')
    tmp_sum1 = tmp_csv['승차총승객수'].sum()
    tmp_sum2 = tmp_csv['하차총승객수'].sum()
    sub_in_month_2020.append(tmp_sum1)
    sub_out_month_2020.append(tmp_sum2)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-4989c0754b6c> in <module>
#       3 sub_out_month_2020 = []
#       4 for i in range(1,13):
# ----> 5     tmp_csv = pd.read_csv(f'./2020/CARD_SUBWAY_MONTH_2020{i:0>2}.csv', encoding='cp949')
#       6     tmp_sum1 = tmp_csv['승차총승객수'].sum()
#       7     tmp_sum2 = tmp_csv['하차총승객수'].sum()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1896
#    1897         try:
# -> 1898             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#    1899         except Exception:
#    1900             self.handles.close()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xbf in position 2: illegal multibyte sequence

# %%
all_in_list = []
all_in_list += sub_in_month_2015
all_in_list += sub_in_month_2016
all_in_list += sub_in_month_2017
all_in_list += sub_in_month_2018
all_in_list += sub_in_month_2019

all_in_list
# Out:
# [437278792,
#  376783122,
#  478541350,
#  236022558.0,
#  234296965.0,
#  203119706.0,
#  218172679.0,
#  210102718.0,
#  214486255.0,
#  234349102.0,
#  223497154.0,
#  233155014.0,
#  209273211.0,
#  193647156.0,
#  236377700.0,
#  228348725.0,
#  234166653.0,
#  222611572.0,
#  219465787.0,
#  214193213.0,
#  210698312.0,
#  229681635.0,
#  228122715.0,
#  231777262.0,
#  205502324.0,
#  204936457.0,
#  237179303.0,
#  227780690.0,
#  227836340.0,
#  221308605.0,
#  214815271.0,
#  213776584.0,
#  228240103.0,
#  208204249.0,
#  228254078.0,
#  228619448.0,
#  213710722.0,
#  189110822.0,
#  235296346.0,
#  228971702.0,
#  235253127.0,
#  219426719.0,
#  221632774.0,
#  214216200.0,
#  208561416.0,
#  235739024.0,
#  232960426.0,
#  227834001.0,
#  221848014.0,
#  190335812.0,
#  233813277.0,
#  235928571.0,
#  243338053.0,
#  221547039.0,
#  229254848.0,
#  219672653.0,
#  214006728.0,
#  240101848.0,
#  232284482.0,
#  234574904.0]

# %%
all_out_list = []
all_out_list += sub_out_month_2015
all_out_list += sub_out_month_2016
all_out_list += sub_out_month_2017
all_out_list += sub_out_month_2018
all_out_list += sub_out_month_2019

all_out_list
# Out:
# [435066846,
#  374884262,
#  476451614,
#  234898916.0,
#  233170178.0,
#  202399930.0,
#  217265058.0,
#  209130600.0,
#  213578097.0,
#  233341479.0,
#  222600581.0,
#  232154505.0,
#  208318335.0,
#  192773472.0,
#  235428077.0,
#  227431434.0,
#  233175677.0,
#  221688838.0,
#  218462009.0,
#  213224598.0,
#  209805032.0,
#  228636055.0,
#  227122581.0,
#  230724428.0,
#  204531987.0,
#  203985242.0,
#  236204018.0,
#  226789893.0,
#  226799684.0,
#  220362163.0,
#  213858564.0,
#  212809390.0,
#  227170000.0,
#  207196105.0,
#  227278770.0,
#  227669424.0,
#  212849469.0,
#  188340921.0,
#  234409973.0,
#  228096920.0,
#  234314673.0,
#  218542730.0,
#  220746413.0,
#  213330490.0,
#  207742249.0,
#  234837595.0,
#  232096833.0,
#  226826591.0,
#  220898375.0,
#  189500198.0,
#  232879549.0,
#  235005777.0,
#  242380504.0,
#  220663596.0,
#  228353976.0,
#  218759210.0,
#  213170622.0,
#  239145883.0,
#  231429861.0,
#  233673639.0]

# %%
all_sub_month_list = {'승차총승객수':all_in_list, '하차총승객수':all_out_list}
index = ['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',